# %%
import pandas as pd
import numpy as np
import altair as alt

# %%
MO2019Offenses = pd.read_csv('NIBRS_OFFENSE.csv')
# MO2018Offenses = pd.read_csv('')

# %%
MO2019Offenses
# Out:
#         DATA_YEAR  OFFENSE_ID  INCIDENT_ID  OFFENSE_TYPE_ID  \
# 0            2019   133892120    109265381               45
# 1            2019   133892125    109259840               16
# 2            2019   133887750    109266759               41
# 3            2019   133887762    109265397               35
# 4            2019   133882715    109259897               21
# ...           ...         ...          ...              ...
# 126105       2019   148794439    122990247                5
# 126106       2019   148794458    122990264               45
# 126107       2019   148790736    122990275               51
# 126108       2019   148794501    122985921               23
# 126109       2019   148790779    122990323               49
#
#        ATTEMPT_COMPLETE_FLAG  LOCATION_ID  NUM_PREMISES_ENTERED  \
# 0                          C            7                   NaN
# 1                          C           13                   NaN
# 2                          C           47                   NaN
# 3                          C           12                   NaN
# 4                          C           20                   NaN
# ...                      ...          ...                   ...
# 126105                     C           20                   NaN
# 126106                     C           23                   NaN
# 126107                     C           20                   NaN
# 126108                     C            8                   NaN
# 126109                     C           20                   NaN
#
#        METHOD_ENTRY_CODE
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ...                  ...
# 126105               NaN
# 126106               NaN
# 126107               NaN
# 126108               NaN
# 126109                 N
#
# [126110 rows x 8 columns]

# %%
Arrestees = pd.read_csv('NIBRS_ARRESTEE.csv')

# %%
Arrestees
# Out:
#        DATA_YEAR  ARRESTEE_ID  INCIDENT_ID  ARRESTEE_SEQ_NUM ARREST_DATE  \
# 0           2019     37347156    121842860                 1   01-JAN-20
# 1           2019     37347161    121842873                 1   05-NOV-19
# 2           2019     37347178    121842921                 1   20-NOV-19
# 3           2019     37347182    121846362                 1   01-NOV-19
# 4           2019     37354913    121842972                 1   02-AUG-19
# ...          ...          ...          ...               ...         ...
# 38378       2019     37765530    122997888                 1   30-NOV-19
# 38379       2019     37760928    122997908                 1   25-AUG-19
# 38380       2019     37756182    122977898                 1   01-OCT-19
# 38381       2019     37760936    122997931                 1   19-DEC-19
# 38382       2019     37756185    122997935                 1   21-JUL-19
#
#        ARREST_TYPE_ID MULTIPLE_INDICATOR  OFFENSE_TYPE_ID  AGE_ID  AGE_NUM  \
# 0                   3                  C               51       5       42
# 1                   3                  C               51       5       22
# 2                   1                  N               51       5       26
# 3                   2                  N               23       5       26
# 4                   1                  N               16       5       25
# ...               ...                ...              ...     ...      ...
# 38378               1                  N               16       5       18
# 38379               1                  N               40       5       26
# 38380               1                  N               51       5       43
# 38381               2                  N               16       5       63
# 38382               2                  N                5       5       46
#
#       SEX_CODE  RACE_ID  ETHNICITY_ID RESIDENT_CODE UNDER_18_DISPOSITION_CODE  \
# 0            M        1             2           NaN                       NaN
# 1            M        2             2           NaN                       NaN
# 2            M        1             2           NaN                       NaN
# 3            M        1             2           NaN                       NaN
# 4            F        2             2           NaN                       NaN
# ...        ...      ...           ...           ...                       ...
# 38378        M        1             2           NaN                       NaN
# 38379        M        2             2           NaN                       NaN
# 38380        M        1             2           NaN                       NaN
# 38381        M        1             2           NaN                       NaN
# 38382        M        1             2           NaN                       NaN
#
#        CLEARANCE_IND  AGE_RANGE_LOW_NUM  AGE_RANGE_HIGH_NUM
# 0                NaN                 42                   0
# 1                NaN                 22                   0
# 2                NaN                 26                   0
# 3                NaN                 26                   0
# 4                NaN                 25                   0
# ...              ...                ...                 ...
# 38378            NaN                 18                   0
# 38379            NaN                 26                   0
# 38380            NaN                 43                   0
# 38381            NaN                 63                   0
# 38382            NaN                 46                   0
#
# [38383 rows x 18 columns]

# %%
MO2019Offenses = MO2019Offenses.merge(Arrestees, how='left', on='INCIDENT_ID')

# %%
ArresteeType = pd.read_csv('NIBRS_ARREST_TYPE.csv')

# %%
ArresteeType
# Out:
#    ARREST_TYPE_ID ARREST_TYPE_CODE    ARREST_TYPE_NAME
# 0               1                O             On View
# 1               2                S    Summoned / Cited
# 2               3                T  Taken INTO Custody

# %%
MO2019Offenses = MO2019Offenses.merge(ArresteeType, how='left', on='ARREST_TYPE_ID')

# %%
ArresteeWeapon = pd.read_csv('NIBRS_ARRESTEE_WEAPON.csv')

# %%
ArresteeWeapon
# Out:
#        DATA_YEAR  ARRESTEE_ID  WEAPON_ID  NIBRS_ARRESTEE_WEAPON_ID
# 0           2019     32116382          1                  32142617
# 1           2019     32102541          1                  32128716
# 2           2019     32116432          1                  32142671
# 3           2019     32105584          1                  32142680
# 4           2019     32116455          1                  32128738
# ...          ...          ...        ...                       ...
# 38422       2019     37632015          1                  37965175
# 38423       2019     37635647          1                  37960574
# 38424       2019     37645225          1                  37965219
# 38425       2019     37632066          1                  37965223
# 38426       2019     37635659          1                  37960586
#
# [38427 rows x 4 columns]

# %%
OffenseTypes = pd.read_csv('NIBRS_OFFENSE_TYPE.csv')

# %%
OffenseTypes
# Out:
#     OFFENSE_TYPE_ID OFFENSE_CODE                           OFFENSE_NAME  \
# 0                71          30A   Illegal Entry into the United States
# 1                72          30B                      False Citizenship
# 2                73          30C                       Smuggling Aliens
# 3                74          30D             Re-entry after Deportation
# 4                75          360  Failure to Register as a Sex Offender
# ..              ...          ...                                    ...
# 81               65          90K                      Failure to Appear
# 82               66          90L            Federal Resource Violations
# 83               67          90M                                Perjury
# 84               69          101                                Treason
# 85               70          103                              Espionage
#
#    CRIME_AGAINST CT_FLAG HC_FLAG  HC_CODE OFFENSE_CATEGORY_NAME OFFENSE_GROUP
# 0        Society       N       N      NaN        Other Offenses             A
# 1        Society       N       N      NaN        Other Offenses             A
# 2        Society       N       N      NaN        Other Offenses             A
# 3        Society       N       N      NaN        Other Offenses             A
# 4        Society       N       N      NaN        Other Offenses             A
# ..           ...     ...     ...      ...                   ...           ...
# 81       Society       N       N      NaN        Other Offenses             B
# 82       Society       N       N      NaN        Other Offenses             B
# 83       Society       N       N      NaN        Other Offenses             B
# 84       Society       N       N      NaN        Other Offenses             A
# 85       Society       N       N      NaN        Other Offenses             A
#
# [86 rows x 9 columns]

# %%
OffenseTypesValues = list(OffenseTypes['OFFENSE_NAME'].values)
OffenseTypesValues.sort()
# print(OffenseTypesValues)
STAR_relevant_offenses = ['Trespass of Real Property','Curfew/Loitering/Vagrancy Violations',
                          'Drug/Narcotic Violations','Drunkenness','Disorderly Conduct',
                         'Family Offenses, Nonviolent']

# %%
MO2019Offenses
# Out:
#         DATA_YEAR_x  OFFENSE_ID  INCIDENT_ID  OFFENSE_TYPE_ID_x  \
# 0              2019   133892120    109265381                 45
# 1              2019   133892125    109259840                 16
# 2              2019   133887750    109266759                 41
# 3              2019   133887762    109265397                 35
# 4              2019   133882715    109259897                 21
# ...             ...         ...          ...                ...
# 134060         2019   148794439    122990247                  5
# 134061         2019   148794458    122990264                 45
# 134062         2019   148790736    122990275                 51
# 134063         2019   148794501    122985921                 23
# 134064         2019   148790779    122990323                 49
#
#        ATTEMPT_COMPLETE_FLAG  LOCATION_ID  NUM_PREMISES_ENTERED  \
# 0                          C            7                   NaN
# 1                          C           13                   NaN
# 2                          C           47                   NaN
# 3                          C           12                   NaN
# 4                          C           20                   NaN
# ...                      ...          ...                   ...
# 134060                     C           20                   NaN
# 134061                     C           23                   NaN
# 134062                     C           20                   NaN
# 134063                     C            8                   NaN
# 134064                     C           20                   NaN
#
#        METHOD_ENTRY_CODE  DATA_YEAR_y  ARRESTEE_ID  ...  SEX_CODE RACE_ID  \
# 0                    NaN          NaN          NaN  ...       NaN     NaN
# 1                    NaN       2019.0   32600470.0  ...         F     1.0
# 2                    NaN          NaN          NaN  ...       NaN     NaN
# 3                    NaN          NaN          NaN  ...       NaN     NaN
# 4                    NaN          NaN          NaN  ...       NaN     NaN
# ...                  ...          ...          ...  ...       ...     ...
# 134060               NaN       2019.0   37759864.0  ...         M     1.0
# 134061               NaN          NaN          NaN  ...       NaN     NaN
# 134062               NaN          NaN          NaN  ...       NaN     NaN
# 134063               NaN          NaN          NaN  ...       NaN     NaN
# 134064                 N       2019.0   37764688.0  ...         M     1.0
#
#         ETHNICITY_ID RESIDENT_CODE  UNDER_18_DISPOSITION_CODE  CLEARANCE_IND  \
# 0                NaN           NaN                        NaN            NaN
# 1                2.0           NaN                        NaN            NaN
# 2                NaN           NaN                        NaN            NaN
# 3                NaN           NaN                        NaN            NaN
# 4                NaN           NaN                        NaN            NaN
# ...              ...           ...                        ...            ...
# 134060           2.0           NaN                        NaN            NaN
# 134061           NaN           NaN                        NaN            NaN
# 134062           NaN           NaN                        NaN            NaN
# 134063           NaN           NaN                        NaN            NaN
# 134064           2.0           NaN                          H            NaN
#
#         AGE_RANGE_LOW_NUM AGE_RANGE_HIGH_NUM  ARREST_TYPE_CODE  \
# 0                     NaN                NaN               NaN
# 1                    37.0                0.0                 O
# 2                     NaN                NaN               NaN
# 3                     NaN                NaN               NaN
# 4                     NaN                NaN               NaN
# ...                   ...                ...               ...
# 134060               24.0                0.0                 S
# 134061                NaN                NaN               NaN
# 134062                NaN                NaN               NaN
# 134063                NaN                NaN               NaN
# 134064               17.0                0.0                 O
#
#         ARREST_TYPE_NAME
# 0                    NaN
# 1                On View
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ...                  ...
# 134060  Summoned / Cited
# 134061               NaN
# 134062               NaN
# 134063               NaN
# 134064           On View
#
# [134065 rows x 27 columns]

# %%
MO2019Offenses = MO2019Offenses.merge(OffenseTypes, how='left', left_on='OFFENSE_TYPE_ID_x',right_on='OFFENSE_TYPE_ID')

# %%
MO2019Offenses
# Out:
#         DATA_YEAR_x  OFFENSE_ID  INCIDENT_ID  OFFENSE_TYPE_ID_x  \
# 0              2019   133892120    109265381                 45
# 1              2019   133892125    109259840                 16
# 2              2019   133887750    109266759                 41
# 3              2019   133887762    109265397                 35
# 4              2019   133882715    109259897                 21
# ...             ...         ...          ...                ...
# 134060         2019   148794439    122990247                  5
# 134061         2019   148794458    122990264                 45
# 134062         2019   148790736    122990275                 51
# 134063         2019   148794501    122985921                 23
# 134064         2019   148790779    122990323                 49
#
#        ATTEMPT_COMPLETE_FLAG  LOCATION_ID  NUM_PREMISES_ENTERED  \
# 0                          C            7                   NaN
# 1                          C           13                   NaN
# 2                          C           47                   NaN
# 3                          C           12                   NaN
# 4                          C           20                   NaN
# ...                      ...          ...                   ...
# 134060                     C           20                   NaN
# 134061                     C           23                   NaN
# 134062                     C           20                   NaN
# 134063                     C            8                   NaN
# 134064                     C           20                   NaN
#
#        METHOD_ENTRY_CODE  DATA_YEAR_y  ARRESTEE_ID  ...  ARREST_TYPE_NAME  \
# 0                    NaN          NaN          NaN  ...               NaN
# 1                    NaN       2019.0   32600470.0  ...           On View
# 2                    NaN          NaN          NaN  ...               NaN
# 3                    NaN          NaN          NaN  ...               NaN
# 4                    NaN          NaN          NaN  ...               NaN
# ...                  ...          ...          ...  ...               ...
# 134060               NaN       2019.0   37759864.0  ...  Summoned / Cited
# 134061               NaN          NaN          NaN  ...               NaN
# 134062               NaN          NaN          NaN  ...               NaN
# 134063               NaN          NaN          NaN  ...               NaN
# 134064                 N       2019.0   37764688.0  ...           On View
#
#        OFFENSE_TYPE_ID  OFFENSE_CODE  \
# 0                   45           23H
# 1                   16           35A
# 2                   41           26B
# 3                   35           35B
# 4                   21           240
# ...                ...           ...
# 134060               5           290
# 134061              45           23H
# 134062              51           13B
# 134063              23           23C
# 134064              49           220
#
#                                       OFFENSE_NAME  CRIME_AGAINST  CT_FLAG  \
# 0                                All Other Larceny       Property        Y
# 1                         Drug/Narcotic Violations        Society        N
# 2       Credit Card/Automated Teller Machine Fraud       Property        Y
# 3                        Drug Equipment Violations        Society        N
# 4                              Motor Vehicle Theft       Property        Y
# ...                                            ...            ...      ...
# 134060    Destruction/Damage/Vandalism of Property       Property        N
# 134061                           All Other Larceny       Property        Y
# 134062                              Simple Assault         Person        N
# 134063                                 Shoplifting       Property        N
# 134064                Burglary/Breaking & Entering       Property        Y
#
#         HC_FLAG HC_CODE                     OFFENSE_CATEGORY_NAME  \
# 0             N     NaN                    Larceny/Theft Offenses
# 1             Y     NaN                    Drug/Narcotic Offenses
# 2             Y     NaN                            Fraud Offenses
# 3             Y     NaN                    Drug/Narcotic Offenses
# 4             Y     7.0                       Motor Vehicle Theft
# ...         ...     ...                                       ...
# 134060        Y    11.0  Destruction/Damage/Vandalism of Property
# 134061        N     NaN                    Larceny/Theft Offenses
# 134062        Y     9.0                          Assault Offenses
# 134063        N     NaN                    Larceny/Theft Offenses
# 134064        Y     5.0              Burglary/Breaking & Entering
#
#         OFFENSE_GROUP
# 0                   A
# 1                   A
# 2                   A
# 3                   A
# 4                   A
# ...               ...
# 134060              A
# 134061              A
# 134062              A
# 134063              A
# 134064              A
#
# [134065 rows x 36 columns]

# %%
LocationRef = pd.read_csv('NIBRS_LOCATION_TYPE.csv')

# %%
LocationRef
# Out:
#     LOCATION_ID  LOCATION_CODE                                  LOCATION_NAME
# 0             1              1                         Air/Bus/Train Terminal
# 1             2              2                          Bank/Savings and Loan
# 2             3              3                                  Bar/Nightclub
# 3             4              4                 Church/Synagogue/Temple/Mosque
# 4             5              5                     Commercial/Office Building
# 5             6              6                              Construction Site
# 6             7              7                              Convenience Store
# 7             8              8                      Department/Discount Store
# 8            10             10                                    Field/Woods
# 9            11             11                     Government/Public Building
# 10           12             12                            Grocery/Supermarket
# 11           13             13             Highway/Road/Alley/Street/Sidewalk
# 12           14             14                               Hotel/Motel/Etc.
# 13           15             15  Jail/Prison/Penitentiary/Corrections Facility
# 14           16             16                            Lake/Waterway/Beach
# 15           17             17                                   Liquor Store
# 16           18             18                        Parking/Drop Lot/Garage
# 17           19             19                        Rental Storage Facility
# 18           20             20                                 Residence/Home
# 19           21             21                                     Restaurant
# 20           22             22                                 School/College
# 21           23             23                            Service/Gas Station
# 22           24             24                                Specialty Store
# 23           25             25                                  Other/Unknown
# 24           26             37                  Abandoned/Condemned Structure
# 25           27             38                                 Amusement Park
# 26           28             39             Arena/Stadium/Fairgrounds/Coliseum
# 27           29             40                         ATM Separate from Bank
# 28           30             41                       Auto Dealership New/Used
# 29           31             42                                Camp/Campground
# 30           32             44                               Daycare Facility
# 31           33             45              Dock/Wharf/Freight/Modal Terminal
# 32           34             46                                  Farm Facility
# 33           35             47            Gambling Facility/Casino/Race Track
# 34           36             48                                Industrial Site
# 35           37             49                          Military Installation
# 36           38             50                                Park/Playground
# 37           39             51                                      Rest Area
# 38           40             52                      School-College/University
# 39           41             53                    School-Elementary/Secondary
# 40           42             54                       Shelter-Mission/Homeless
# 41           43             55                                  Shopping Mall
# 42           44             56                                   Tribal Lands
# 43           45             57                               Community Center
# 44           46              9            Drug Store/Doctor's Office/Hospital
# 45           47             58                                     Cyberspace
# 46            0              0                                  Not Specified

# %%
MO2019Offenses = MO2019Offenses.merge(LocationRef, how='left', on='LOCATION_ID')

# %%
MO2019Offenses
# Out:
#         DATA_YEAR_x  OFFENSE_ID  INCIDENT_ID  OFFENSE_TYPE_ID_x  \
# 0              2019   133892120    109265381                 45
# 1              2019   133892125    109259840                 16
# 2              2019   133887750    109266759                 41
# 3              2019   133887762    109265397                 35
# 4              2019   133882715    109259897                 21
# ...             ...         ...          ...                ...
# 134060         2019   148794439    122990247                  5
# 134061         2019   148794458    122990264                 45
# 134062         2019   148790736    122990275                 51
# 134063         2019   148794501    122985921                 23
# 134064         2019   148790779    122990323                 49
#
#        ATTEMPT_COMPLETE_FLAG  LOCATION_ID  NUM_PREMISES_ENTERED  \
# 0                          C            7                   NaN
# 1                          C           13                   NaN
# 2                          C           47                   NaN
# 3                          C           12                   NaN
# 4                          C           20                   NaN
# ...                      ...          ...                   ...
# 134060                     C           20                   NaN
# 134061                     C           23                   NaN
# 134062                     C           20                   NaN
# 134063                     C            8                   NaN
# 134064                     C           20                   NaN
#
#        METHOD_ENTRY_CODE  DATA_YEAR_y  ARRESTEE_ID  ...  OFFENSE_CODE  \
# 0                    NaN          NaN          NaN  ...           23H
# 1                    NaN       2019.0   32600470.0  ...           35A
# 2                    NaN          NaN          NaN  ...           26B
# 3                    NaN          NaN          NaN  ...           35B
# 4                    NaN          NaN          NaN  ...           240
# ...                  ...          ...          ...  ...           ...
# 134060               NaN       2019.0   37759864.0  ...           290
# 134061               NaN          NaN          NaN  ...           23H
# 134062               NaN          NaN          NaN  ...           13B
# 134063               NaN          NaN          NaN  ...           23C
# 134064                 N       2019.0   37764688.0  ...           220
#
#                                       OFFENSE_NAME  CRIME_AGAINST CT_FLAG  \
# 0                                All Other Larceny       Property       Y
# 1                         Drug/Narcotic Violations        Society       N
# 2       Credit Card/Automated Teller Machine Fraud       Property       Y
# 3                        Drug Equipment Violations        Society       N
# 4                              Motor Vehicle Theft       Property       Y
# ...                                            ...            ...     ...
# 134060    Destruction/Damage/Vandalism of Property       Property       N
# 134061                           All Other Larceny       Property       Y
# 134062                              Simple Assault         Person       N
# 134063                                 Shoplifting       Property       N
# 134064                Burglary/Breaking & Entering       Property       Y
#
#         HC_FLAG  HC_CODE                     OFFENSE_CATEGORY_NAME  \
# 0             N      NaN                    Larceny/Theft Offenses
# 1             Y      NaN                    Drug/Narcotic Offenses
# 2             Y      NaN                            Fraud Offenses
# 3             Y      NaN                    Drug/Narcotic Offenses
# 4             Y      7.0                       Motor Vehicle Theft
# ...         ...      ...                                       ...
# 134060        Y     11.0  Destruction/Damage/Vandalism of Property
# 134061        N      NaN                    Larceny/Theft Offenses
# 134062        Y      9.0                          Assault Offenses
# 134063        N      NaN                    Larceny/Theft Offenses
# 134064        Y      5.0              Burglary/Breaking & Entering
#
#        OFFENSE_GROUP  LOCATION_CODE                       LOCATION_NAME
# 0                  A              7                   Convenience Store
# 1                  A             13  Highway/Road/Alley/Street/Sidewalk
# 2                  A             58                          Cyberspace
# 3                  A             12                 Grocery/Supermarket
# 4                  A             20                      Residence/Home
# ...              ...            ...                                 ...
# 134060             A             20                      Residence/Home
# 134061             A             23                 Service/Gas Station
# 134062             A             20                      Residence/Home
# 134063             A              8           Department/Discount Store
# 134064             A             20                      Residence/Home
#
# [134065 rows x 38 columns]

# %%
Incidents = pd.read_csv('NIBRS_incident.csv')

# %%
Incidents
# Out:
#         DATA_YEAR  AGENCY_ID  INCIDENT_ID  NIBRS_MONTH_ID CARGO_THEFT_FLAG  \
# 0            2019       9960    116135030         9191064              NaN
# 1            2019       9761    111056480         8985492                Y
# 2            2019       9761    111048015         8985492              NaN
# 3            2019       9761    111048017         8985492              NaN
# 4            2019       9761    111048022         8985492                N
# ...           ...        ...          ...             ...              ...
# 107762       2019      10043    122997194         8152674                N
# 107763       2019      10043    123067626         8221632              NaN
# 107764       2019      10043    122358732         8145012              NaN
# 107765       2019      10043    122358736         8145012              NaN
# 107766       2019      10043    122358747         8152674              NaN
#
#        SUBMISSION_DATE INCIDENT_DATE REPORT_DATE_FLAG  INCIDENT_HOUR  \
# 0            23-SEP-19     06-AUG-19              NaN           19.0
# 1            21-MAY-19     11-MAR-19              NaN            8.0
# 2            21-MAY-19     03-MAR-19              NaN            1.0
# 3            21-MAY-19     07-MAR-19              NaN           23.0
# 4            21-MAY-19     15-MAR-19              NaN           16.0
# ...                ...           ...              ...            ...
# 107762       31-MAR-20     22-FEB-19              NaN           16.0
# 107763       06-APR-20     01-NOV-19              NaN           15.0
# 107764       17-MAR-20     21-JAN-19              NaN            4.0
# 107765       17-MAR-20     21-JAN-19              NaN           23.0
# 107766       17-MAR-20     01-FEB-19              NaN            8.0
#
#         CLEARED_EXCEPT_ID CLEARED_EXCEPT_DATE  INCIDENT_STATUS DATA_HOME  \
# 0                       6                 NaN                0         C
# 1                       6                 NaN                0         C
# 2                       6                 NaN                0         C
# 3                       6                 NaN                0         C
# 4                       6                 NaN                0         C
# ...                   ...                 ...              ...       ...
# 107762                  6                 NaN                0         C
# 107763                  6                 NaN                0         C
# 107764                  6                 NaN                0         C
# 107765                  6                 NaN                0         C
# 107766                  6                 NaN                0         C
#
#        ORIG_FORMAT       DID
# 0                F  56536880
# 1                F  46357401
# 2                F  46355347
# 3                F  46362702
# 4                F  46355357
# ...            ...       ...
# 107762           F  70662679
# 107763           F  70927660
# 107764           F  69415433
# 107765           F  69409314
# 107766           F  69415464
#
# [107767 rows x 15 columns]

# %%
MO2019Offenses = MO2019Offenses.merge(Incidents, how='left', on='INCIDENT_ID')

# %%
Agencies = pd.read_csv('agencies.csv')

# %%
# Agencies.COUNTY_NAME.values
pd.set_option('display.max_columns', None)
# Agencies['PUB_AGENCY_NAME'].values
Agencies#.groupby(['AGENCY_TYPE_NAME'])
# Out:
#     YEARLY_AGENCY_ID  AGENCY_ID  DATA_YEAR        ORI LEGACY_ORI  \
# 0           94802019       9480       2019  MO0010600  MO0010600
# 1           95072019       9507       2019  MO0070200  MO0070200
# 2           95092019       9509       2019  MO0080000  MO0080000
# 3           95172019       9517       2019  MO0100200  MO0100200
# 4           95222019       9522       2019  MO0110000  MO0110000
# ..               ...        ...        ...        ...        ...
# 80         101442019      10144       2019  MO1110300  MO1110300
# 81         101612019      10161       2019  MOKPD0000  MOKPD0000
# 82         101622019      10162       2019  MOMHP0000  MOMHP0000
# 83         101632019      10163       2019  MOMHP0700  MOMHP0700
# 84         255872019      25587       2019  MO0922400  MO0922400
#
#     COVERED_BY_LEGACY_ORI DIRECT_CONTRIBUTOR_FLAG DORMANT_FLAG  DORMANT_YEAR  \
# 0                     NaN                       N            N           NaN
# 1                     NaN                       N            N           NaN
# 2                     NaN                       N            N           NaN
# 3                     NaN                       N            N           NaN
# 4                     NaN                       N            N           NaN
# ..                    ...                     ...          ...           ...
# 80                    NaN                       N            N           NaN
# 81                    NaN                       N            N           NaN
# 82                    NaN                       N            N           NaN
# 83                    NaN                       N            N           NaN
# 84                    NaN                       N            N           NaN
#
#    REPORTING_TYPE          UCR_AGENCY_NAME          NCIC_AGENCY_NAME  \
# 0               I  TRUMAN STATE UNIVERSITY   TRUMAN STATE UNIVERSITY
# 1               I                   BUTLER                    BUTLER
# 2               I                   BENTON                    BENTON
# 3               I                 COLUMBIA                  COLUMBIA
# 4               I                 BUCHANAN                  BUCHANAN
# ..            ...                      ...                       ...
# 80              I                   POTOSI                    POTOSI
# 81              I              KANSAS CITY               KANSAS CITY
# 82              I  MO STATE HIGHWAY PATROL   MO STATE HIGHWAY PATROL
# 83              I  GAMING COMMISSION ENF D  GAMING COMMISSION, ENF D
# 84              I    ST. CHARLES COUNTY PD                       NaN
#
#                          PUB_AGENCY_NAME       PUB_AGENCY_UNIT AGENCY_STATUS  \
# 0                Truman State University                   NaN             A
# 1                                 Butler                   NaN             A
# 2                                 Benton                   NaN             A
# 3                               Columbia                   NaN             A
# 4                               Buchanan                   NaN             A
# ..                                   ...                   ...           ...
# 80                                Potosi                   NaN             A
# 81                           Kansas City                   NaN             A
# 82         Missouri State Highway Patrol                   NaN             A
# 83                     Gaming Commission  Enforcement Division             A
# 84  St. Charles County Police Department                   NaN             A
#
#     STATE_ID STATE_NAME STATE_ABBR STATE_POSTAL_ABBR  DIVISION_CODE  \
# 0         28   Missouri         MO                MO              4
# 1         28   Missouri         MO                MO              4
# 2         28   Missouri         MO                MO              4
# 3         28   Missouri         MO                MO              4
# 4         28   Missouri         MO                MO              4
# ..       ...        ...        ...               ...            ...
# 80        28   Missouri         MO                MO              4
# 81        28   Missouri         MO                MO              4
# 82        28   Missouri         MO                MO              4
# 83        28   Missouri         MO                MO              4
# 84        28   Missouri         MO                MO              4
#
#          DIVISION_NAME  REGION_CODE REGION_NAME REGION_DESC  \
# 0   West North Central            2     Midwest   Region II
# 1   West North Central            2     Midwest   Region II
# 2   West North Central            2     Midwest   Region II
# 3   West North Central            2     Midwest   Region II
# 4   West North Central            2     Midwest   Region II
# ..                 ...          ...         ...         ...
# 80  West North Central            2     Midwest   Region II
# 81  West North Central            2     Midwest   Region II
# 82  West North Central            2     Midwest   Region II
# 83  West North Central            2     Midwest   Region II
# 84  West North Central            2     Midwest   Region II
#
#          AGENCY_TYPE_NAME  POPULATION  SUBMITTING_AGENCY_ID        SAI  \
# 0   University or College           0                 23376  MOUCR0001
# 1                    City        4017                 23376  MOUCR0001
# 2                  County       14763                 23376  MOUCR0001
# 3                    City      125017                 23376  MOUCR0001
# 4                  County       12499                 23376  MOUCR0001
# ..                    ...         ...                   ...        ...
# 80                   City        2609                 23376  MOUCR0001
# 81                   City      495964                 23376  MOUCR0001
# 82           State Police           0                 23376  MOUCR0001
# 83     Other State Agency           0                 23376  MOUCR0001
# 84                 County      119556                 23376  MOUCR0001
#
#                                SUBMITTING_AGENCY_NAME SUBURBAN_AREA_FLAG  \
# 0   Missouri State Highway Patrol UCR Program Offi...                  N
# 1   Missouri State Highway Patrol UCR Program Offi...                  Y
# 2   Missouri State Highway Patrol UCR Program Offi...                  N
# 3   Missouri State Highway Patrol UCR Program Offi...                  N
# 4   Missouri State Highway Patrol UCR Program Offi...                  Y
# ..                                                ...                ...
# 80  Missouri State Highway Patrol UCR Program Offi...                  N
# 81  Missouri State Highway Patrol UCR Program Offi...                  N
# 82  Missouri State Highway Patrol UCR Program Offi...                  N
# 83  Missouri State Highway Patrol UCR Program Offi...                  N
# 84  Missouri State Highway Patrol UCR Program Offi...                  Y
#
#     POPULATION_GROUP_ID POPULATION_GROUP_CODE  \
# 0                    11                     7
# 1                    10                     6
# 2                    15                    8C
# 3                     6                     2
# 4                    21                    9C
# ..                  ...                   ...
# 80                   10                     6
# 81                    5                    1C
# 82                   17                    8E
# 83                   11                     7
# 84                   19                    9A
#
#                        POPULATION_GROUP_DESC  PARENT_POP_GROUP_CODE  \
# 0                         Cities under 2,500                      7
# 1               Cities from 2,500 thru 9,999                      6
# 2   Non-MSA counties from 10,000 thru 24,999                      8
# 3           Cities from 100,000 thru 249,999                      2
# 4       MSA counties from 10,000 thru 24,999                      9
# ..                                       ...                    ...
# 80              Cities from 2,500 thru 9,999                      6
# 81          Cities from 250,000 thru 499,999                      1
# 82                      Non-MSA State Police                      8
# 83                        Cities under 2,500                      7
# 84              MSA counties 100,000 or over                      9
#
#                PARENT_POP_GROUP_DESC MIP_FLAG  POP_SORT_ORDER  \
# 0                 Cities under 2,500        N               2
# 1       Cities from 2,500 thru 9,999        N               2
# 2                   Non-MSA Counties        N               3
# 3   Cities from 100,000 thru 249,999        Y               1
# 4                       MSA Counties        N               3
# ..                               ...      ...             ...
# 80      Cities from 2,500 thru 9,999        N               2
# 81        All cities 250,000 or over        Y               1
# 82                  Non-MSA Counties        N               3
# 83                Cities under 2,500        N               2
# 84                      MSA Counties        Y               3
#
#    SUMMARY_RAPE_DEF PE_REPORTED_FLAG  MALE_OFFICER  MALE_CIVILIAN  \
# 0                 R                N           NaN            NaN
# 1                 R                Y           9.0            4.0
# 2                 R                Y          15.0            7.0
# 3                 R                Y         134.0           16.0
# 4                 R                Y          58.0           13.0
# ..              ...              ...           ...            ...
# 80                R                Y           9.0            0.0
# 81                R                Y        1105.0          173.0
# 82                R                Y        1168.0          524.0
# 83                R                Y         100.0            0.0
# 84                R                Y         133.0           10.0
#
#     PED.MALE_OFFICER+PED.MALE_CIVILIAN  FEMALE_OFFICER  FEMALE_CIVILIAN  \
# 0                                  NaN             NaN              NaN
# 1                                 13.0             0.0              2.0
# 2                                 22.0             2.0              3.0
# 3                                150.0            24.0             21.0
# 4                                 71.0            11.0             24.0
# ..                                 ...             ...              ...
# 80                                 9.0             1.0              1.0
# 81                              1278.0           194.0            347.0
# 82                              1692.0            61.0            581.0
# 83                               100.0            11.0              3.0
# 84                               143.0            10.0             27.0
#
#     PED.FEMALE_CIVILIAN+PED.FEMALE_OFFICER  0  0.1 NIBRS_CERT_DATE  \
# 0                                      NaN  0    0       01-OCT-05
# 1                                      2.0  0    0       01-OCT-05
# 2                                      5.0  0    0       01-OCT-05
# 3                                     45.0  0    0       01-OCT-05
# 4                                     35.0  0    0       01-OCT-05
# ..                                     ... ..  ...             ...
# 80                                     2.0  0    0       01-OCT-05
# 81                                   541.0  0    0       01-OCT-05
# 82                                   642.0  0    0       01-OCT-05
# 83                                    14.0  0    0       01-OCT-05
# 84                                    37.0  0    0       01-OCT-05
#
#    NIBRS_START_DATE NIBRS_LEOKA_START_DATE NIBRS_CT_START_DATE  \
# 0         01-SEP-19              01-SEP-19           01-SEP-19
# 1         01-DEC-19              01-DEC-19           01-APR-20
# 2         01-OCT-17              01-OCT-17           01-MAR-20
# 3         01-OCT-19              01-OCT-19           01-OCT-19
# 4         01-MAR-18              01-MAR-18           01-FEB-19
# ..              ...                    ...                 ...
# 80        01-AUG-19              01-AUG-19           01-AUG-19
# 81        01-JAN-10              01-JAN-10           01-JAN-19
# 82        01-JUL-18              01-JUL-18           01-JAN-19
# 83        01-JUL-18              01-JUL-18           01-FEB-19
# 84        01-JUN-19              01-JUN-19           01-JUN-19
#
#    NIBRS_MULTI_BIAS_START_DATE NIBRS_OFF_ETH_START_DATE COVERED_FLAG  \
# 0                    01-SEP-19                01-SEP-19            N
# 1                    01-APR-20                01-APR-20            N
# 2                    01-MAR-20                01-MAR-20            N
# 3                    01-OCT-19                01-OCT-19            N
# 4                    01-APR-18                01-APR-18            N
# ..                         ...                      ...          ...
# 80                   01-AUG-19                01-AUG-19            N
# 81                   01-JAN-13                01-JAN-13            N
# 82                   01-JUL-18                01-JUL-18            N
# 83                   01-JUL-18                01-JUL-18            N
# 84                   01-JUN-19                01-JUN-19            N
#
#                     COUNTY_NAME            MSA_NAME PUBLISHABLE_FLAG  \
# 0                         ADAIR             Non-MSA                Y
# 1                         BATES  Kansas City, MO-KS                Y
# 2                        BENTON             Non-MSA                Y
# 3                         BOONE        Columbia, MO                Y
# 4                      BUCHANAN   St. Joseph, MO-KS                Y
# ..                          ...                 ...              ...
# 80                   WASHINGTON             Non-MSA                Y
# 81  CASS; PLATTE; CLAY; JACKSON  Kansas City, MO-KS                Y
# 82                          NaN             Non-MSA                Y
# 83                          NaN             Non-MSA                Y
# 84                   ST CHARLES    St. Louis, MO-IL                Y
#
#    PARTICIPATED NIBRS_PARTICIPATED
# 0             Y                  Y
# 1             Y                  Y
# 2             Y                  Y
# 3             Y                  Y
# 4             Y                  Y
# ..          ...                ...
# 80            Y                  Y
# 81            Y                  Y
# 82            Y                  Y
# 83            Y                  Y
# 84            Y                  Y
#
# [85 rows x 59 columns]

# %%
MO2019Offenses = MO2019Offenses.merge(Agencies, how='left', on='AGENCY_ID')

# %%
#Want to get counts by unique agency
MO2019Offenses.groupby(['AGENCY_TYPE_NAME','OFFENSE_NAME'])['OFFENSE_NAME'].count()
# Out:
# AGENCY_TYPE_NAME       OFFENSE_NAME
# City                   Aggravated Assault                             4990
#                        All Other Larceny                              8714
#                        Animal Cruelty                                   47
#                        Arson                                           264
#                        Assisting or Promoting Prostitution              17
#                                                                       ...
# University or College  Theft From Building                              36
#                        Theft From Motor Vehicle                         44
#                        Theft of Motor Vehicle Parts or Accessories       4
#                        Weapon Law Violations                             2
#                        Wire Fraud                                        1
# Name: OFFENSE_NAME, Length: 164, dtype: int64

# %%
Weapons = pd.read_csv('NIBRS_WEAPON.csv')

# %%
Weapons
# Out:
#        DATA_YEAR  WEAPON_ID  OFFENSE_ID  NIBRS_WEAPON_ID
# 0           2019         12   132156214         24307162
# 1           2019         12   132161231         24302626
# 2           2019         12   132161249         24307171
# 3           2019         12   132156369         24297661
# 4           2019         20   132156376         24297662
# ...          ...        ...         ...              ...
# 26248       2019         11   136261759         25352642
# 26249       2019         12   136256105         25345069
# 26250       2019         12   136258865         25352682
# 26251       2019         12   136266141         25345090
# 26252       2019         12   136258879         25349156
#
# [26253 rows x 4 columns]

# %%
MO2019Offenses = MO2019Offenses.merge(Weapons, how='left', on='OFFENSE_ID')

# %%
MO2019Offenses
# Out:
#         DATA_YEAR_x  OFFENSE_ID  INCIDENT_ID  OFFENSE_TYPE_ID_x  \
# 0              2019   133892120    109265381                 45
# 1              2019   133892125    109259840                 16
# 2              2019   133887750    109266759                 41
# 3              2019   133887762    109265397                 35
# 4              2019   133882715    109259897                 21
# ...             ...         ...          ...                ...
# 134610         2019   148794439    122990247                  5
# 134611         2019   148794458    122990264                 45
# 134612         2019   148790736    122990275                 51
# 134613         2019   148794501    122985921                 23
# 134614         2019   148790779    122990323                 49
#
#        ATTEMPT_COMPLETE_FLAG  LOCATION_ID  NUM_PREMISES_ENTERED  \
# 0                          C            7                   NaN
# 1                          C           13                   NaN
# 2                          C           47                   NaN
# 3                          C           12                   NaN
# 4                          C           20                   NaN
# ...                      ...          ...                   ...
# 134610                     C           20                   NaN
# 134611                     C           23                   NaN
# 134612                     C           20                   NaN
# 134613                     C            8                   NaN
# 134614                     C           20                   NaN
#
#        METHOD_ENTRY_CODE  DATA_YEAR_y  ARRESTEE_ID  ARRESTEE_SEQ_NUM  \
# 0                    NaN          NaN          NaN               NaN
# 1                    NaN       2019.0   32600470.0               1.0
# 2                    NaN          NaN          NaN               NaN
# 3                    NaN          NaN          NaN               NaN
# 4                    NaN          NaN          NaN               NaN
# ...                  ...          ...          ...               ...
# 134610               NaN       2019.0   37759864.0               1.0
# 134611               NaN          NaN          NaN               NaN
# 134612               NaN          NaN          NaN               NaN
# 134613               NaN          NaN          NaN               NaN
# 134614                 N       2019.0   37764688.0               1.0
#
#        ARREST_DATE  ARREST_TYPE_ID MULTIPLE_INDICATOR  OFFENSE_TYPE_ID_y  \
# 0              NaN             NaN                NaN                NaN
# 1        24-FEB-19             1.0                  C               16.0
# 2              NaN             NaN                NaN                NaN
# 3              NaN             NaN                NaN                NaN
# 4              NaN             NaN                NaN                NaN
# ...            ...             ...                ...                ...
# 134610   17-DEC-19             2.0                  N                5.0
# 134611         NaN             NaN                NaN                NaN
# 134612         NaN             NaN                NaN                NaN
# 134613         NaN             NaN                NaN                NaN
# 134614   05-NOV-19             1.0                  N               49.0
#
#         AGE_ID  AGE_NUM SEX_CODE  RACE_ID  ETHNICITY_ID RESIDENT_CODE  \
# 0          NaN      NaN      NaN      NaN           NaN           NaN
# 1          5.0     37.0        F      1.0           2.0           NaN
# 2          NaN      NaN      NaN      NaN           NaN           NaN
# 3          NaN      NaN      NaN      NaN           NaN           NaN
# 4          NaN      NaN      NaN      NaN           NaN           NaN
# ...        ...      ...      ...      ...           ...           ...
# 134610     5.0     24.0        M      1.0           2.0           NaN
# 134611     NaN      NaN      NaN      NaN           NaN           NaN
# 134612     NaN      NaN      NaN      NaN           NaN           NaN
# 134613     NaN      NaN      NaN      NaN           NaN           NaN
# 134614     5.0     17.0        M      1.0           2.0           NaN
#
#        UNDER_18_DISPOSITION_CODE  CLEARANCE_IND  AGE_RANGE_LOW_NUM  \
# 0                            NaN            NaN                NaN
# 1                            NaN            NaN               37.0
# 2                            NaN            NaN                NaN
# 3                            NaN            NaN                NaN
# 4                            NaN            NaN                NaN
# ...                          ...            ...                ...
# 134610                       NaN            NaN               24.0
# 134611                       NaN            NaN                NaN
# 134612                       NaN            NaN                NaN
# 134613                       NaN            NaN                NaN
# 134614                         H            NaN               17.0
#
#         AGE_RANGE_HIGH_NUM ARREST_TYPE_CODE  ARREST_TYPE_NAME  \
# 0                      NaN              NaN               NaN
# 1                      0.0                O           On View
# 2                      NaN              NaN               NaN
# 3                      NaN              NaN               NaN
# 4                      NaN              NaN               NaN
# ...                    ...              ...               ...
# 134610                 0.0                S  Summoned / Cited
# 134611                 NaN              NaN               NaN
# 134612                 NaN              NaN               NaN
# 134613                 NaN              NaN               NaN
# 134614                 0.0                O           On View
#
#         OFFENSE_TYPE_ID OFFENSE_CODE  \
# 0                    45          23H
# 1                    16          35A
# 2                    41          26B
# 3                    35          35B
# 4                    21          240
# ...                 ...          ...
# 134610                5          290
# 134611               45          23H
# 134612               51          13B
# 134613               23          23C
# 134614               49          220
#
#                                       OFFENSE_NAME CRIME_AGAINST CT_FLAG  \
# 0                                All Other Larceny      Property       Y
# 1                         Drug/Narcotic Violations       Society       N
# 2       Credit Card/Automated Teller Machine Fraud      Property       Y
# 3                        Drug Equipment Violations       Society       N
# 4                              Motor Vehicle Theft      Property       Y
# ...                                            ...           ...     ...
# 134610    Destruction/Damage/Vandalism of Property      Property       N
# 134611                           All Other Larceny      Property       Y
# 134612                              Simple Assault        Person       N
# 134613                                 Shoplifting      Property       N
# 134614                Burglary/Breaking & Entering      Property       Y
#
#        HC_FLAG  HC_CODE                     OFFENSE_CATEGORY_NAME  \
# 0            N      NaN                    Larceny/Theft Offenses
# 1            Y      NaN                    Drug/Narcotic Offenses
# 2            Y      NaN                            Fraud Offenses
# 3            Y      NaN                    Drug/Narcotic Offenses
# 4            Y      7.0                       Motor Vehicle Theft
# ...        ...      ...                                       ...
# 134610       Y     11.0  Destruction/Damage/Vandalism of Property
# 134611       N      NaN                    Larceny/Theft Offenses
# 134612       Y      9.0                          Assault Offenses
# 134613       N      NaN                    Larceny/Theft Offenses
# 134614       Y      5.0              Burglary/Breaking & Entering
#
#        OFFENSE_GROUP  LOCATION_CODE                       LOCATION_NAME  \
# 0                  A              7                   Convenience Store
# 1                  A             13  Highway/Road/Alley/Street/Sidewalk
# 2                  A             58                          Cyberspace
# 3                  A             12                 Grocery/Supermarket
# 4                  A             20                      Residence/Home
# ...              ...            ...                                 ...
# 134610             A             20                      Residence/Home
# 134611             A             23                 Service/Gas Station
# 134612             A             20                      Residence/Home
# 134613             A              8           Department/Discount Store
# 134614             A             20                      Residence/Home
#
#         DATA_YEAR_x  AGENCY_ID  NIBRS_MONTH_ID CARGO_THEFT_FLAG  \
# 0              2019       9543         8913644                N
# 1              2019       9541         8768580              NaN
# 2              2019       9543         8913644                N
# 3              2019       9541         8911642              NaN
# 4              2019       9562         8152650                N
# ...             ...        ...             ...              ...
# 134610         2019       9517        11218604              NaN
# 134611         2019       9720        10527962                N
# 134612         2019       9720         9086163              NaN
# 134613         2019       9517        11218604              NaN
# 134614         2019       9721         8221616                N
#
#        SUBMISSION_DATE INCIDENT_DATE REPORT_DATE_FLAG  INCIDENT_HOUR  \
# 0            08-APR-19     14-MAR-19              NaN           13.0
# 1            08-APR-19     24-FEB-19              NaN            3.0
# 2            08-APR-19     07-MAR-19              NaN            9.0
# 3            08-APR-19     10-MAR-19              NaN            0.0
# 4            08-APR-19     26-FEB-19              NaN            4.0
# ...                ...           ...              ...            ...
# 134610       31-MAR-20     17-DEC-19              NaN            6.0
# 134611       31-MAR-20     27-OCT-19              NaN           15.0
# 134612       31-MAR-20     13-JUN-19              NaN            9.0
# 134613       31-MAR-20     17-DEC-19              NaN           15.0
# 134614       31-MAR-20     05-NOV-19              NaN            8.0
#
#         CLEARED_EXCEPT_ID CLEARED_EXCEPT_DATE  INCIDENT_STATUS DATA_HOME  \
# 0                       6                 NaN                0         C
# 1                       6                 NaN                0         C
# 2                       6                 NaN                0         C
# 3                       6                 NaN                0         C
# 4                       6                 NaN                0         C
# ...                   ...                 ...              ...       ...
# 134610                  6                 NaN                0         C
# 134611                  6                 NaN                0         C
# 134612                  6                 NaN                0         C
# 134613                  6                 NaN                0         C
# 134614                  6                 NaN                0         C
#
#        ORIG_FORMAT       DID  YEARLY_AGENCY_ID  DATA_YEAR_y        ORI  \
# 0                F  43024701          95432019         2019  MO0150200
# 1                F  43027810          95412019         2019  MO0150000
# 2                F  43031655          95432019         2019  MO0150200
# 3                F  43024720          95412019         2019  MO0150000
# 4                F  43031768          95622019         2019  MO0190400
# ...            ...       ...               ...          ...        ...
# 134610           F  70648394          95172019         2019  MO0100200
# 134611           F  70653396          97202019         2019  MO0480600
# 134612           F  70653429          97202019         2019  MO0480600
# 134613           F  70653474          95172019         2019  MO0100200
# 134614           F  70648504          97212019         2019  MO0480700
#
#        LEGACY_ORI  COVERED_BY_LEGACY_ORI DIRECT_CONTRIBUTOR_FLAG DORMANT_FLAG  \
# 0       MO0150200                    NaN                       N            N
# 1       MO0150000                    NaN                       N            N
# 2       MO0150200                    NaN                       N            N
# 3       MO0150000                    NaN                       N            N
# 4       MO0190400                    NaN                       N            N
# ...           ...                    ...                     ...          ...
# 134610  MO0100200                    NaN                       N            N
# 134611  MO0480600                    NaN                       N            N
# 134612  MO0480600                    NaN                       N            N
# 134613  MO0100200                    NaN                       N            N
# 134614  MO0480700                    NaN                       N            N
#
#         DORMANT_YEAR REPORTING_TYPE UCR_AGENCY_NAME NCIC_AGENCY_NAME  \
# 0                NaN              I     OSAGE BEACH      OSAGE BEACH
# 1                NaN              I          CAMDEN           CAMDEN
# 2                NaN              I     OSAGE BEACH      OSAGE BEACH
# 3                NaN              I          CAMDEN           CAMDEN
# 4                NaN              I   HARRISONVILLE    HARRISONVILLE
# ...              ...            ...             ...              ...
# 134610           NaN              I        COLUMBIA         COLUMBIA
# 134611           NaN              I    INDEPENDENCE     INDEPENDENCE
# 134612           NaN              I    INDEPENDENCE     INDEPENDENCE
# 134613           NaN              I        COLUMBIA         COLUMBIA
# 134614           NaN              I   LAKE LOTAWANA    LAKE LOTAWANA
#
#        PUB_AGENCY_NAME PUB_AGENCY_UNIT AGENCY_STATUS  STATE_ID STATE_NAME  \
# 0          Osage Beach             NaN             A        28   Missouri
# 1               Camden             NaN             A        28   Missouri
# 2          Osage Beach             NaN             A        28   Missouri
# 3               Camden             NaN             A        28   Missouri
# 4        Harrisonville             NaN             A        28   Missouri
# ...                ...             ...           ...       ...        ...
# 134610        Columbia             NaN             A        28   Missouri
# 134611    Independence             NaN             A        28   Missouri
# 134612    Independence             NaN             A        28   Missouri
# 134613        Columbia             NaN             A        28   Missouri
# 134614   Lake Lotawana             NaN             A        28   Missouri
#
#        STATE_ABBR STATE_POSTAL_ABBR  DIVISION_CODE       DIVISION_NAME  \
# 0              MO                MO              4  West North Central
# 1              MO                MO              4  West North Central
# 2              MO                MO              4  West North Central
# 3              MO                MO              4  West North Central
# 4              MO                MO              4  West North Central
# ...           ...               ...            ...                 ...
# 134610         MO                MO              4  West North Central
# 134611         MO                MO              4  West North Central
# 134612         MO                MO              4  West North Central
# 134613         MO                MO              4  West North Central
# 134614         MO                MO              4  West North Central
#
#         REGION_CODE REGION_NAME REGION_DESC AGENCY_TYPE_NAME  POPULATION  \
# 0                 2     Midwest   Region II             City        4598
# 1                 2     Midwest   Region II           County       36589
# 2                 2     Midwest   Region II             City        4598
# 3                 2     Midwest   Region II           County       36589
# 4                 2     Midwest   Region II             City       10095
# ...             ...         ...         ...              ...         ...
# 134610            2     Midwest   Region II             City      125017
# 134611            2     Midwest   Region II             City      116931
# 134612            2     Midwest   Region II             City      116931
# 134613            2     Midwest   Region II             City      125017
# 134614            2     Midwest   Region II             City        2126
#
#         SUBMITTING_AGENCY_ID        SAI  \
# 0                      23376  MOUCR0001
# 1                      23376  MOUCR0001
# 2                      23376  MOUCR0001
# 3                      23376  MOUCR0001
# 4                      23376  MOUCR0001
# ...                      ...        ...
# 134610                 23376  MOUCR0001
# 134611                 23376  MOUCR0001
# 134612                 23376  MOUCR0001
# 134613                 23376  MOUCR0001
# 134614                 23376  MOUCR0001
#
#                                    SUBMITTING_AGENCY_NAME SUBURBAN_AREA_FLAG  \
# 0       Missouri State Highway Patrol UCR Program Offi...                  N
# 1       Missouri State Highway Patrol UCR Program Offi...                  N
# 2       Missouri State Highway Patrol UCR Program Offi...                  N
# 3       Missouri State Highway Patrol UCR Program Offi...                  N
# 4       Missouri State Highway Patrol UCR Program Offi...                  Y
# ...                                                   ...                ...
# 134610  Missouri State Highway Patrol UCR Program Offi...                  N
# 134611  Missouri State Highway Patrol UCR Program Offi...                  N
# 134612  Missouri State Highway Patrol UCR Program Offi...                  N
# 134613  Missouri State Highway Patrol UCR Program Offi...                  N
# 134614  Missouri State Highway Patrol UCR Program Offi...                  Y
#
#         POPULATION_GROUP_ID POPULATION_GROUP_CODE  \
# 0                        10                     6
# 1                        14                    8B
# 2                        10                     6
# 3                        14                    8B
# 4                         9                     5
# ...                     ...                   ...
# 134610                    6                     2
# 134611                    6                     2
# 134612                    6                     2
# 134613                    6                     2
# 134614                   11                     7
#
#                            POPULATION_GROUP_DESC  PARENT_POP_GROUP_CODE  \
# 0                   Cities from 2,500 thru 9,999                      6
# 1       Non-MSA counties from 25,000 thru 99,999                      8
# 2                   Cities from 2,500 thru 9,999                      6
# 3       Non-MSA counties from 25,000 thru 99,999                      8
# 4                 Cities from 10,000 thru 24,999                      5
# ...                                          ...                    ...
# 134610          Cities from 100,000 thru 249,999                      2
# 134611          Cities from 100,000 thru 249,999                      2
# 134612          Cities from 100,000 thru 249,999                      2
# 134613          Cities from 100,000 thru 249,999                      2
# 134614                        Cities under 2,500                      7
#
#                    PARENT_POP_GROUP_DESC MIP_FLAG  POP_SORT_ORDER  \
# 0           Cities from 2,500 thru 9,999        N               2
# 1                       Non-MSA Counties        N               3
# 2           Cities from 2,500 thru 9,999        N               2
# 3                       Non-MSA Counties        N               3
# 4         Cities from 10,000 thru 24,999        N               2
# ...                                  ...      ...             ...
# 134610  Cities from 100,000 thru 249,999        Y               1
# 134611  Cities from 100,000 thru 249,999        Y               1
# 134612  Cities from 100,000 thru 249,999        Y               1
# 134613  Cities from 100,000 thru 249,999        Y               1
# 134614                Cities under 2,500        N               2
#
#        SUMMARY_RAPE_DEF PE_REPORTED_FLAG  MALE_OFFICER  MALE_CIVILIAN  \
# 0                     R                Y          17.0            0.0
# 1                     R                Y          47.0           16.0
# 2                     R                Y          17.0            0.0
# 3                     R                Y          47.0           16.0
# 4                     R                Y          21.0            0.0
# ...                 ...              ...           ...            ...
# 134610                R                Y         134.0           16.0
# 134611                R                Y         180.0           19.0
# 134612                R                Y         180.0           19.0
# 134613                R                Y         134.0           16.0
# 134614                R                Y           4.0            0.0
#
#         PED.MALE_OFFICER+PED.MALE_CIVILIAN  FEMALE_OFFICER  FEMALE_CIVILIAN  \
# 0                                     17.0             3.0              4.0
# 1                                     63.0             7.0             23.0
# 2                                     17.0             3.0              4.0
# 3                                     63.0             7.0             23.0
# 4                                     21.0             2.0              8.0
# ...                                    ...             ...              ...
# 134610                               150.0            24.0             21.0
# 134611                               199.0            19.0             54.0
# 134612                               199.0            19.0             54.0
# 134613                               150.0            24.0             21.0
# 134614                                 4.0             0.0              0.0
#
#         PED.FEMALE_CIVILIAN+PED.FEMALE_OFFICER  0  0.1 NIBRS_CERT_DATE  \
# 0                                          7.0  0    0       01-OCT-05
# 1                                         30.0  0    0       01-OCT-05
# 2                                          7.0  0    0       01-OCT-05
# 3                                         30.0  0    0       01-OCT-05
# 4                                         10.0  0    0       01-OCT-05
# ...                                        ... ..  ...             ...
# 134610                                    45.0  0    0       01-OCT-05
# 134611                                    73.0  0    0       01-OCT-05
# 134612                                    73.0  0    0       01-OCT-05
# 134613                                    45.0  0    0       01-OCT-05
# 134614                                     0.0  0    0       01-OCT-05
#
#        NIBRS_START_DATE NIBRS_LEOKA_START_DATE NIBRS_CT_START_DATE  \
# 0             01-MAR-19              01-MAR-19           01-MAR-19
# 1             01-FEB-19              01-FEB-19           01-FEB-19
# 2             01-MAR-19              01-MAR-19           01-MAR-19
# 3             01-FEB-19              01-FEB-19           01-FEB-19
# 4             01-FEB-18              01-FEB-18           01-MAR-19
# ...                 ...                    ...                 ...
# 134610        01-OCT-19              01-OCT-19           01-OCT-19
# 134611        01-FEB-19              01-FEB-19           01-FEB-19
# 134612        01-FEB-19              01-FEB-19           01-FEB-19
# 134613        01-OCT-19              01-OCT-19           01-OCT-19
# 134614        01-APR-10              01-APR-10           01-FEB-19
#
#        NIBRS_MULTI_BIAS_START_DATE NIBRS_OFF_ETH_START_DATE COVERED_FLAG  \
# 0                        01-MAR-19                01-MAR-19            N
# 1                        01-FEB-19                01-FEB-19            N
# 2                        01-MAR-19                01-MAR-19            N
# 3                        01-FEB-19                01-FEB-19            N
# 4                        01-FEB-18                01-FEB-18            N
# ...                            ...                      ...          ...
# 134610                   01-OCT-19                01-OCT-19            N
# 134611                   01-FEB-19                01-FEB-19            N
# 134612                   01-FEB-19                01-FEB-19            N
# 134613                   01-OCT-19                01-OCT-19            N
# 134614                   01-APR-13                01-APR-13            N
#
#            COUNTY_NAME            MSA_NAME PUBLISHABLE_FLAG PARTICIPATED  \
# 0       MILLER; CAMDEN             Non-MSA                Y            Y
# 1               CAMDEN             Non-MSA                Y            Y
# 2       MILLER; CAMDEN             Non-MSA                Y            Y
# 3               CAMDEN             Non-MSA                Y            Y
# 4                 CASS  Kansas City, MO-KS                Y            Y
# ...                ...                 ...              ...          ...
# 134610           BOONE        Columbia, MO                Y            Y
# 134611         JACKSON  Kansas City, MO-KS                Y            Y
# 134612         JACKSON  Kansas City, MO-KS                Y            Y
# 134613           BOONE        Columbia, MO                Y            Y
# 134614         JACKSON  Kansas City, MO-KS                Y            Y
#
#        NIBRS_PARTICIPATED  DATA_YEAR  WEAPON_ID  NIBRS_WEAPON_ID
# 0                       Y        NaN        NaN              NaN
# 1                       Y        NaN        NaN              NaN
# 2                       Y        NaN        NaN              NaN
# 3                       Y        NaN        NaN              NaN
# 4                       Y        NaN        NaN              NaN
# ...                   ...        ...        ...              ...
# 134610                  Y        NaN        NaN              NaN
# 134611                  Y        NaN        NaN              NaN
# 134612                  Y     2019.0       12.0       29652294.0
# 134613                  Y        NaN        NaN              NaN
# 134614                  Y        NaN        NaN              NaN
#
# [134615 rows x 113 columns]

# %%
WeaponType = pd.read_csv('NIBRS_WEAPON_TYPE.csv')

# %%
WeaponType
# Out:
#     WEAPON_ID WEAPON_CODE                      WEAPON_NAME SHR_FLAG
# 0          21         11A              Firearm (Automatic)        N
# 1          22         12A              Handgun (Automatic)        N
# 2          23         13A                Rifle (Automatic)        N
# 3          24         14A              Shotgun (Automatic)        N
# 4          25         15A        Other Firearm (Automatic)        N
# 5          26          55      Pushed or Thrown Out Window        Y
# 6          27          75                         Drowning        Y
# 7          28          80  Strangulation - Include Hanging        Y
# 8           1          01                          Unarmed        N
# 9           2          11                          Firearm        Y
# 10          3          12                          Handgun        Y
# 11          4          13                            Rifle        Y
# 12          5          14                          Shotgun        Y
# 13          6          15                    Other Firearm        Y
# 14          7          16        Lethal Cutting Instrument        N
# 15          8          17    Club/Blackjack/Brass Knuckles        N
# 16          9          20         Knife/Cutting Instrument        Y
# 17         10          30                     Blunt Object        Y
# 18         11          35             Motor Vehicle/Vessel        N
# 19         12          40                 Personal Weapons        Y
# 20         13          50                           Poison        Y
# 21         14          60                       Explosives        Y
# 22         15          65           Fire/Incendiary Device        Y
# 23         16          70   Drugs/Narcotics/Sleeping Pills        Y
# 24         17          85                     Asphyxiation        Y
# 25         18          90                            Other        Y
# 26         19          95                          Unknown        N
# 27         20          99                             None        N

# %%
MO2019Offenses = MO2019Offenses.merge(WeaponType, how='left', on='WEAPON_ID')

# %%
ArrestType = pd.read_csv('NIBRS_ARREST_TYPE.csv')

# %%
Offender = pd.read_csv('NIBRS_OFFENDER.csv')

# %%
Offender
# Out:
#         DATA_YEAR  OFFENDER_ID  INCIDENT_ID  OFFENDER_SEQ_NUM  AGE_ID  \
# 0            2019    130978437    115243752                 1     5.0
# 1            2019    130982474    115243753                 0     NaN
# 2            2019    130973899    115243754                 1     5.0
# 3            2019    130978446    115234941                 1     5.0
# 4            2019    130973900    115243757                 1     5.0
# ...           ...          ...          ...               ...     ...
# 124032       2019    138489525    121843151                 1     5.0
# 124033       2019    138494203    121840885                 1     5.0
# 124034       2019    138489740    121843343                 1     5.0
# 124035       2019    138489781    121843380                 1     5.0
# 124036       2019    138494414    121841071                 1     4.0
#
#         AGE_NUM SEX_CODE  RACE_ID  ETHNICITY_ID  AGE_RANGE_LOW_NUM  \
# 0          54.0        M      2.0           2.0               54.0
# 1           NaN      NaN      NaN           NaN                NaN
# 2          24.0        F      1.0           2.0               24.0
# 3          35.0        M      1.0           2.0               35.0
# 4          28.0        M      2.0           2.0               28.0
# ...         ...      ...      ...           ...                ...
# 124032     21.0        M      2.0           2.0               21.0
# 124033     42.0        F      1.0           3.0               42.0
# 124034     27.0        M      1.0           2.0               27.0
# 124035     47.0        M      1.0           2.0               47.0
# 124036      NaN        U      0.0           3.0                NaN
#
#         AGE_RANGE_HIGH_NUM
# 0                      0.0
# 1                      NaN
# 2                      0.0
# 3                      0.0
# 4                      0.0
# ...                    ...
# 124032                 0.0
# 124033                 0.0
# 124034                 0.0
# 124035                 0.0
# 124036                 NaN
#
# [124037 rows x 11 columns]

# %%
MO2019Offenses = MO2019Offenses.merge(Offender, how='left', on='INCIDENT_ID')

# %%
MO2019Offenses
# Out:
#         DATA_YEAR_x  OFFENSE_ID  INCIDENT_ID  OFFENSE_TYPE_ID_x  \
# 0              2019   133892120    109265381                 45
# 1              2019   133892125    109259840                 16
# 2              2019   133887750    109266759                 41
# 3              2019   133887762    109265397                 35
# 4              2019   133882715    109259897                 21
# ...             ...         ...          ...                ...
# 170607         2019   148794439    122990247                  5
# 170608         2019   148794458    122990264                 45
# 170609         2019   148790736    122990275                 51
# 170610         2019   148794501    122985921                 23
# 170611         2019   148790779    122990323                 49
#
#        ATTEMPT_COMPLETE_FLAG  LOCATION_ID  NUM_PREMISES_ENTERED  \
# 0                          C            7                   NaN
# 1                          C           13                   NaN
# 2                          C           47                   NaN
# 3                          C           12                   NaN
# 4                          C           20                   NaN
# ...                      ...          ...                   ...
# 170607                     C           20                   NaN
# 170608                     C           23                   NaN
# 170609                     C           20                   NaN
# 170610                     C            8                   NaN
# 170611                     C           20                   NaN
#
#        METHOD_ENTRY_CODE  DATA_YEAR_y  ARRESTEE_ID  ARRESTEE_SEQ_NUM  \
# 0                    NaN          NaN          NaN               NaN
# 1                    NaN       2019.0   32600470.0               1.0
# 2                    NaN          NaN          NaN               NaN
# 3                    NaN          NaN          NaN               NaN
# 4                    NaN          NaN          NaN               NaN
# ...                  ...          ...          ...               ...
# 170607               NaN       2019.0   37759864.0               1.0
# 170608               NaN          NaN          NaN               NaN
# 170609               NaN          NaN          NaN               NaN
# 170610               NaN          NaN          NaN               NaN
# 170611                 N       2019.0   37764688.0               1.0
#
#        ARREST_DATE  ARREST_TYPE_ID MULTIPLE_INDICATOR  OFFENSE_TYPE_ID_y  \
# 0              NaN             NaN                NaN                NaN
# 1        24-FEB-19             1.0                  C               16.0
# 2              NaN             NaN                NaN                NaN
# 3              NaN             NaN                NaN                NaN
# 4              NaN             NaN                NaN                NaN
# ...            ...             ...                ...                ...
# 170607   17-DEC-19             2.0                  N                5.0
# 170608         NaN             NaN                NaN                NaN
# 170609         NaN             NaN                NaN                NaN
# 170610         NaN             NaN                NaN                NaN
# 170611   05-NOV-19             1.0                  N               49.0
#
#         AGE_ID_x  AGE_NUM_x SEX_CODE_x  RACE_ID_x  ETHNICITY_ID_x  \
# 0            NaN        NaN        NaN        NaN             NaN
# 1            5.0       37.0          F        1.0             2.0
# 2            NaN        NaN        NaN        NaN             NaN
# 3            NaN        NaN        NaN        NaN             NaN
# 4            NaN        NaN        NaN        NaN             NaN
# ...          ...        ...        ...        ...             ...
# 170607       5.0       24.0          M        1.0             2.0
# 170608       NaN        NaN        NaN        NaN             NaN
# 170609       NaN        NaN        NaN        NaN             NaN
# 170610       NaN        NaN        NaN        NaN             NaN
# 170611       5.0       17.0          M        1.0             2.0
#
#        RESIDENT_CODE UNDER_18_DISPOSITION_CODE  CLEARANCE_IND  \
# 0                NaN                       NaN            NaN
# 1                NaN                       NaN            NaN
# 2                NaN                       NaN            NaN
# 3                NaN                       NaN            NaN
# 4                NaN                       NaN            NaN
# ...              ...                       ...            ...
# 170607           NaN                       NaN            NaN
# 170608           NaN                       NaN            NaN
# 170609           NaN                       NaN            NaN
# 170610           NaN                       NaN            NaN
# 170611           NaN                         H            NaN
#
#         AGE_RANGE_LOW_NUM_x  AGE_RANGE_HIGH_NUM_x ARREST_TYPE_CODE  \
# 0                       NaN                   NaN              NaN
# 1                      37.0                   0.0                O
# 2                       NaN                   NaN              NaN
# 3                       NaN                   NaN              NaN
# 4                       NaN                   NaN              NaN
# ...                     ...                   ...              ...
# 170607                 24.0                   0.0                S
# 170608                  NaN                   NaN              NaN
# 170609                  NaN                   NaN              NaN
# 170610                  NaN                   NaN              NaN
# 170611                 17.0                   0.0                O
#
#         ARREST_TYPE_NAME  OFFENSE_TYPE_ID OFFENSE_CODE  \
# 0                    NaN               45          23H
# 1                On View               16          35A
# 2                    NaN               41          26B
# 3                    NaN               35          35B
# 4                    NaN               21          240
# ...                  ...              ...          ...
# 170607  Summoned / Cited                5          290
# 170608               NaN               45          23H
# 170609               NaN               51          13B
# 170610               NaN               23          23C
# 170611           On View               49          220
#
#                                       OFFENSE_NAME CRIME_AGAINST CT_FLAG  \
# 0                                All Other Larceny      Property       Y
# 1                         Drug/Narcotic Violations       Society       N
# 2       Credit Card/Automated Teller Machine Fraud      Property       Y
# 3                        Drug Equipment Violations       Society       N
# 4                              Motor Vehicle Theft      Property       Y
# ...                                            ...           ...     ...
# 170607    Destruction/Damage/Vandalism of Property      Property       N
# 170608                           All Other Larceny      Property       Y
# 170609                              Simple Assault        Person       N
# 170610                                 Shoplifting      Property       N
# 170611                Burglary/Breaking & Entering      Property       Y
#
#        HC_FLAG  HC_CODE                     OFFENSE_CATEGORY_NAME  \
# 0            N      NaN                    Larceny/Theft Offenses
# 1            Y      NaN                    Drug/Narcotic Offenses
# 2            Y      NaN                            Fraud Offenses
# 3            Y      NaN                    Drug/Narcotic Offenses
# 4            Y      7.0                       Motor Vehicle Theft
# ...        ...      ...                                       ...
# 170607       Y     11.0  Destruction/Damage/Vandalism of Property
# 170608       N      NaN                    Larceny/Theft Offenses
# 170609       Y      9.0                          Assault Offenses
# 170610       N      NaN                    Larceny/Theft Offenses
# 170611       Y      5.0              Burglary/Breaking & Entering
#
#        OFFENSE_GROUP  LOCATION_CODE                       LOCATION_NAME  \
# 0                  A              7                   Convenience Store
# 1                  A             13  Highway/Road/Alley/Street/Sidewalk
# 2                  A             58                          Cyberspace
# 3                  A             12                 Grocery/Supermarket
# 4                  A             20                      Residence/Home
# ...              ...            ...                                 ...
# 170607             A             20                      Residence/Home
# 170608             A             23                 Service/Gas Station
# 170609             A             20                      Residence/Home
# 170610             A              8           Department/Discount Store
# 170611             A             20                      Residence/Home
#
#         DATA_YEAR_x  AGENCY_ID  NIBRS_MONTH_ID CARGO_THEFT_FLAG  \
# 0              2019       9543         8913644                N
# 1              2019       9541         8768580              NaN
# 2              2019       9543         8913644                N
# 3              2019       9541         8911642              NaN
# 4              2019       9562         8152650                N
# ...             ...        ...             ...              ...
# 170607         2019       9517        11218604              NaN
# 170608         2019       9720        10527962                N
# 170609         2019       9720         9086163              NaN
# 170610         2019       9517        11218604              NaN
# 170611         2019       9721         8221616                N
#
#        SUBMISSION_DATE INCIDENT_DATE REPORT_DATE_FLAG  INCIDENT_HOUR  \
# 0            08-APR-19     14-MAR-19              NaN           13.0
# 1            08-APR-19     24-FEB-19              NaN            3.0
# 2            08-APR-19     07-MAR-19              NaN            9.0
# 3            08-APR-19     10-MAR-19              NaN            0.0
# 4            08-APR-19     26-FEB-19              NaN            4.0
# ...                ...           ...              ...            ...
# 170607       31-MAR-20     17-DEC-19              NaN            6.0
# 170608       31-MAR-20     27-OCT-19              NaN           15.0
# 170609       31-MAR-20     13-JUN-19              NaN            9.0
# 170610       31-MAR-20     17-DEC-19              NaN           15.0
# 170611       31-MAR-20     05-NOV-19              NaN            8.0
#
#         CLEARED_EXCEPT_ID CLEARED_EXCEPT_DATE  INCIDENT_STATUS DATA_HOME  \
# 0                       6                 NaN                0         C
# 1                       6                 NaN                0         C
# 2                       6                 NaN                0         C
# 3                       6                 NaN                0         C
# 4                       6                 NaN                0         C
# ...                   ...                 ...              ...       ...
# 170607                  6                 NaN                0         C
# 170608                  6                 NaN                0         C
# 170609                  6                 NaN                0         C
# 170610                  6                 NaN                0         C
# 170611                  6                 NaN                0         C
#
#        ORIG_FORMAT       DID  YEARLY_AGENCY_ID  DATA_YEAR_y        ORI  \
# 0                F  43024701          95432019         2019  MO0150200
# 1                F  43027810          95412019         2019  MO0150000
# 2                F  43031655          95432019         2019  MO0150200
# 3                F  43024720          95412019         2019  MO0150000
# 4                F  43031768          95622019         2019  MO0190400
# ...            ...       ...               ...          ...        ...
# 170607           F  70648394          95172019         2019  MO0100200
# 170608           F  70653396          97202019         2019  MO0480600
# 170609           F  70653429          97202019         2019  MO0480600
# 170610           F  70653474          95172019         2019  MO0100200
# 170611           F  70648504          97212019         2019  MO0480700
#
#        LEGACY_ORI  COVERED_BY_LEGACY_ORI DIRECT_CONTRIBUTOR_FLAG DORMANT_FLAG  \
# 0       MO0150200                    NaN                       N            N
# 1       MO0150000                    NaN                       N            N
# 2       MO0150200                    NaN                       N            N
# 3       MO0150000                    NaN                       N            N
# 4       MO0190400                    NaN                       N            N
# ...           ...                    ...                     ...          ...
# 170607  MO0100200                    NaN                       N            N
# 170608  MO0480600                    NaN                       N            N
# 170609  MO0480600                    NaN                       N            N
# 170610  MO0100200                    NaN                       N            N
# 170611  MO0480700                    NaN                       N            N
#
#         DORMANT_YEAR REPORTING_TYPE UCR_AGENCY_NAME NCIC_AGENCY_NAME  \
# 0                NaN              I     OSAGE BEACH      OSAGE BEACH
# 1                NaN              I          CAMDEN           CAMDEN
# 2                NaN              I     OSAGE BEACH      OSAGE BEACH
# 3                NaN              I          CAMDEN           CAMDEN
# 4                NaN              I   HARRISONVILLE    HARRISONVILLE
# ...              ...            ...             ...              ...
# 170607           NaN              I        COLUMBIA         COLUMBIA
# 170608           NaN              I    INDEPENDENCE     INDEPENDENCE
# 170609           NaN              I    INDEPENDENCE     INDEPENDENCE
# 170610           NaN              I        COLUMBIA         COLUMBIA
# 170611           NaN              I   LAKE LOTAWANA    LAKE LOTAWANA
#
#        PUB_AGENCY_NAME PUB_AGENCY_UNIT AGENCY_STATUS  STATE_ID STATE_NAME  \
# 0          Osage Beach             NaN             A        28   Missouri
# 1               Camden             NaN             A        28   Missouri
# 2          Osage Beach             NaN             A        28   Missouri
# 3               Camden             NaN             A        28   Missouri
# 4        Harrisonville             NaN             A        28   Missouri
# ...                ...             ...           ...       ...        ...
# 170607        Columbia             NaN             A        28   Missouri
# 170608    Independence             NaN             A        28   Missouri
# 170609    Independence             NaN             A        28   Missouri
# 170610        Columbia             NaN             A        28   Missouri
# 170611   Lake Lotawana             NaN             A        28   Missouri
#
#        STATE_ABBR STATE_POSTAL_ABBR  DIVISION_CODE       DIVISION_NAME  \
# 0              MO                MO              4  West North Central
# 1              MO                MO              4  West North Central
# 2              MO                MO              4  West North Central
# 3              MO                MO              4  West North Central
# 4              MO                MO              4  West North Central
# ...           ...               ...            ...                 ...
# 170607         MO                MO              4  West North Central
# 170608         MO                MO              4  West North Central
# 170609         MO                MO              4  West North Central
# 170610         MO                MO              4  West North Central
# 170611         MO                MO              4  West North Central
#
#         REGION_CODE REGION_NAME REGION_DESC AGENCY_TYPE_NAME  POPULATION  \
# 0                 2     Midwest   Region II             City        4598
# 1                 2     Midwest   Region II           County       36589
# 2                 2     Midwest   Region II             City        4598
# 3                 2     Midwest   Region II           County       36589
# 4                 2     Midwest   Region II             City       10095
# ...             ...         ...         ...              ...         ...
# 170607            2     Midwest   Region II             City      125017
# 170608            2     Midwest   Region II             City      116931
# 170609            2     Midwest   Region II             City      116931
# 170610            2     Midwest   Region II             City      125017
# 170611            2     Midwest   Region II             City        2126
#
#         SUBMITTING_AGENCY_ID        SAI  \
# 0                      23376  MOUCR0001
# 1                      23376  MOUCR0001
# 2                      23376  MOUCR0001
# 3                      23376  MOUCR0001
# 4                      23376  MOUCR0001
# ...                      ...        ...
# 170607                 23376  MOUCR0001
# 170608                 23376  MOUCR0001
# 170609                 23376  MOUCR0001
# 170610                 23376  MOUCR0001
# 170611                 23376  MOUCR0001
#
#                                    SUBMITTING_AGENCY_NAME SUBURBAN_AREA_FLAG  \
# 0       Missouri State Highway Patrol UCR Program Offi...                  N
# 1       Missouri State Highway Patrol UCR Program Offi...                  N
# 2       Missouri State Highway Patrol UCR Program Offi...                  N
# 3       Missouri State Highway Patrol UCR Program Offi...                  N
# 4       Missouri State Highway Patrol UCR Program Offi...                  Y
# ...                                                   ...                ...
# 170607  Missouri State Highway Patrol UCR Program Offi...                  N
# 170608  Missouri State Highway Patrol UCR Program Offi...                  N
# 170609  Missouri State Highway Patrol UCR Program Offi...                  N
# 170610  Missouri State Highway Patrol UCR Program Offi...                  N
# 170611  Missouri State Highway Patrol UCR Program Offi...                  Y
#
#         POPULATION_GROUP_ID POPULATION_GROUP_CODE  \
# 0                        10                     6
# 1                        14                    8B
# 2                        10                     6
# 3                        14                    8B
# 4                         9                     5
# ...                     ...                   ...
# 170607                    6                     2
# 170608                    6                     2
# 170609                    6                     2
# 170610                    6                     2
# 170611                   11                     7
#
#                            POPULATION_GROUP_DESC  PARENT_POP_GROUP_CODE  \
# 0                   Cities from 2,500 thru 9,999                      6
# 1       Non-MSA counties from 25,000 thru 99,999                      8
# 2                   Cities from 2,500 thru 9,999                      6
# 3       Non-MSA counties from 25,000 thru 99,999                      8
# 4                 Cities from 10,000 thru 24,999                      5
# ...                                          ...                    ...
# 170607          Cities from 100,000 thru 249,999                      2
# 170608          Cities from 100,000 thru 249,999                      2
# 170609          Cities from 100,000 thru 249,999                      2
# 170610          Cities from 100,000 thru 249,999                      2
# 170611                        Cities under 2,500                      7
#
#                    PARENT_POP_GROUP_DESC MIP_FLAG  POP_SORT_ORDER  \
# 0           Cities from 2,500 thru 9,999        N               2
# 1                       Non-MSA Counties        N               3
# 2           Cities from 2,500 thru 9,999        N               2
# 3                       Non-MSA Counties        N               3
# 4         Cities from 10,000 thru 24,999        N               2
# ...                                  ...      ...             ...
# 170607  Cities from 100,000 thru 249,999        Y               1
# 170608  Cities from 100,000 thru 249,999        Y               1
# 170609  Cities from 100,000 thru 249,999        Y               1
# 170610  Cities from 100,000 thru 249,999        Y               1
# 170611                Cities under 2,500        N               2
#
#        SUMMARY_RAPE_DEF PE_REPORTED_FLAG  MALE_OFFICER  MALE_CIVILIAN  \
# 0                     R                Y          17.0            0.0
# 1                     R                Y          47.0           16.0
# 2                     R                Y          17.0            0.0
# 3                     R                Y          47.0           16.0
# 4                     R                Y          21.0            0.0
# ...                 ...              ...           ...            ...
# 170607                R                Y         134.0           16.0
# 170608                R                Y         180.0           19.0
# 170609                R                Y         180.0           19.0
# 170610                R                Y         134.0           16.0
# 170611                R                Y           4.0            0.0
#
#         PED.MALE_OFFICER+PED.MALE_CIVILIAN  FEMALE_OFFICER  FEMALE_CIVILIAN  \
# 0                                     17.0             3.0              4.0
# 1                                     63.0             7.0             23.0
# 2                                     17.0             3.0              4.0
# 3                                     63.0             7.0             23.0
# 4                                     21.0             2.0              8.0
# ...                                    ...             ...              ...
# 170607                               150.0            24.0             21.0
# 170608                               199.0            19.0             54.0
# 170609                               199.0            19.0             54.0
# 170610                               150.0            24.0             21.0
# 170611                                 4.0             0.0              0.0
#
#         PED.FEMALE_CIVILIAN+PED.FEMALE_OFFICER  0  0.1 NIBRS_CERT_DATE  \
# 0                                          7.0  0    0       01-OCT-05
# 1                                         30.0  0    0       01-OCT-05
# 2                                          7.0  0    0       01-OCT-05
# 3                                         30.0  0    0       01-OCT-05
# 4                                         10.0  0    0       01-OCT-05
# ...                                        ... ..  ...             ...
# 170607                                    45.0  0    0       01-OCT-05
# 170608                                    73.0  0    0       01-OCT-05
# 170609                                    73.0  0    0       01-OCT-05
# 170610                                    45.0  0    0       01-OCT-05
# 170611                                     0.0  0    0       01-OCT-05
#
#        NIBRS_START_DATE NIBRS_LEOKA_START_DATE NIBRS_CT_START_DATE  \
# 0             01-MAR-19              01-MAR-19           01-MAR-19
# 1             01-FEB-19              01-FEB-19           01-FEB-19
# 2             01-MAR-19              01-MAR-19           01-MAR-19
# 3             01-FEB-19              01-FEB-19           01-FEB-19
# 4             01-FEB-18              01-FEB-18           01-MAR-19
# ...                 ...                    ...                 ...
# 170607        01-OCT-19              01-OCT-19           01-OCT-19
# 170608        01-FEB-19              01-FEB-19           01-FEB-19
# 170609        01-FEB-19              01-FEB-19           01-FEB-19
# 170610        01-OCT-19              01-OCT-19           01-OCT-19
# 170611        01-APR-10              01-APR-10           01-FEB-19
#
#        NIBRS_MULTI_BIAS_START_DATE NIBRS_OFF_ETH_START_DATE COVERED_FLAG  \
# 0                        01-MAR-19                01-MAR-19            N
# 1                        01-FEB-19                01-FEB-19            N
# 2                        01-MAR-19                01-MAR-19            N
# 3                        01-FEB-19                01-FEB-19            N
# 4                        01-FEB-18                01-FEB-18            N
# ...                            ...                      ...          ...
# 170607                   01-OCT-19                01-OCT-19            N
# 170608                   01-FEB-19                01-FEB-19            N
# 170609                   01-FEB-19                01-FEB-19            N
# 170610                   01-OCT-19                01-OCT-19            N
# 170611                   01-APR-13                01-APR-13            N
#
#            COUNTY_NAME            MSA_NAME PUBLISHABLE_FLAG PARTICIPATED  \
# 0       MILLER; CAMDEN             Non-MSA                Y            Y
# 1               CAMDEN             Non-MSA                Y            Y
# 2       MILLER; CAMDEN             Non-MSA                Y            Y
# 3               CAMDEN             Non-MSA                Y            Y
# 4                 CASS  Kansas City, MO-KS                Y            Y
# ...                ...                 ...              ...          ...
# 170607           BOONE        Columbia, MO                Y            Y
# 170608         JACKSON  Kansas City, MO-KS                Y            Y
# 170609         JACKSON  Kansas City, MO-KS                Y            Y
# 170610           BOONE        Columbia, MO                Y            Y
# 170611         JACKSON  Kansas City, MO-KS                Y            Y
#
#        NIBRS_PARTICIPATED  DATA_YEAR_x  WEAPON_ID  NIBRS_WEAPON_ID  \
# 0                       Y          NaN        NaN              NaN
# 1                       Y          NaN        NaN              NaN
# 2                       Y          NaN        NaN              NaN
# 3                       Y          NaN        NaN              NaN
# 4                       Y          NaN        NaN              NaN
# ...                   ...          ...        ...              ...
# 170607                  Y          NaN        NaN              NaN
# 170608                  Y          NaN        NaN              NaN
# 170609                  Y       2019.0       12.0       29652294.0
# 170610                  Y          NaN        NaN              NaN
# 170611                  Y          NaN        NaN              NaN
#
#        WEAPON_CODE       WEAPON_NAME SHR_FLAG  DATA_YEAR_y  OFFENDER_ID  \
# 0              NaN               NaN      NaN         2019    123710966
# 1              NaN               NaN      NaN         2019    123706789
# 2              NaN               NaN      NaN         2019    123706794
# 3              NaN               NaN      NaN         2019    123716052
# 4              NaN               NaN      NaN         2019    123706877
# ...            ...               ...      ...          ...          ...
# 170607         NaN               NaN      NaN         2019    139868734
# 170608         NaN               NaN      NaN         2019    139868753
# 170609          40  Personal Weapons        Y         2019    139868765
# 170610         NaN               NaN      NaN         2019    139872070
# 170611         NaN               NaN      NaN         2019    139872099
#
#         OFFENDER_SEQ_NUM  AGE_ID_y  AGE_NUM_y SEX_CODE_y  RACE_ID_y  \
# 0                      1       5.0       52.0          F        1.0
# 1                      1       5.0       37.0          F        1.0
# 2                      1       4.0        NaN          U        0.0
# 3                      1       5.0       47.0          F        1.0
# 4                      2       5.0       40.0          F        1.0
# ...                  ...       ...        ...        ...        ...
# 170607                 1       5.0       24.0          M        1.0
# 170608                 1       5.0       35.0          M        2.0
# 170609                 1       5.0       48.0          M        2.0
# 170610                 0       NaN        NaN        NaN        NaN
# 170611                 1       5.0       17.0          M        1.0
#
#         ETHNICITY_ID_y  AGE_RANGE_LOW_NUM_y  AGE_RANGE_HIGH_NUM_y
# 0                  2.0                 52.0                   0.0
# 1                  2.0                 37.0                   0.0
# 2                  3.0                  NaN                   NaN
# 3                  3.0                 47.0                   0.0
# 4                  2.0                 40.0                   0.0
# ...                ...                  ...                   ...
# 170607             3.0                 24.0                   0.0
# 170608             2.0                 35.0                   0.0
# 170609             2.0                 48.0                   0.0
# 170610             NaN                  NaN                   NaN
# 170611             2.0                 17.0                   0.0
#
# [170612 rows x 126 columns]

# %%
Race = pd.read_csv('REF_RACE.csv')

# %%
Race
# Out:
#     RACE_ID RACE_CODE                                          RACE_DESC  \
# 0         0         U                                            Unknown
# 1         1         W                                              White
# 2         2         B                          Black or African American
# 3         3         I                   American Indian or Alaska Native
# 4         4         A                                              Asian
# 5         5        AP  Asian, Native Hawaiian, or Other Pacific Islander
# 6         6         C                                            Chinese
# 7         7         J                                           Japanese
# 8         8         P          Native Hawaiian or Other Pacific Islander
# 9         9         O                                              Other
# 10       98         M                                           Multiple
# 11       99        NS                                      Not Specified
#
#     SORT_ORDER  START_YEAR  END_YEAR  \
# 0           98         NaN       NaN
# 1           10         NaN       NaN
# 2           20         NaN       NaN
# 3           30         NaN       NaN
# 4           40      2013.0       NaN
# 5           41      1980.0    2012.0
# 6           42      1960.0    1979.0
# 7           43      1960.0    1979.0
# 8           50      2013.0       NaN
# 9           60      1960.0    1979.0
# 10          70         NaN       NaN
# 11          99         NaN       NaN
#
#                                                 NOTES
# 0                          Race is explicitly unknown
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                               Includes Asian Indian
# 5                               Includes Asian Indian
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9   Includes Native Hawaiian or Other Pacific Isla...
# 10                Used for groups with multiple races
# 11                              Race is not specified

# %%
MO2019Offenses = MO2019Offenses.merge(Race, how='left', left_on='RACE_ID_x',right_on='RACE_ID')

# %%
MO2019Offenses['OFFENSE_ID'] = MO2019Offenses['OFFENSE_ID'].astype(float)

# %%
set(MO2019Offenses.COUNTY_NAME.values)
# Out:
# {'ADAIR',
#  'BATES',
#  'BENTON',
#  'BOONE',
#  'BUCHANAN',
#  'BUTLER',
#  'CALDWELL',
#  'CALLAWAY; COLE',
#  'CAMDEN',
#  'CASS',
#  'CASS; PLATTE; CLAY; JACKSON',
#  'CHARITON; LINN',
#  'CHRISTIAN',
#  'CLAY',
#  'CLAY; RAY',
#  'COOPER',
#  'DEKALB; CLINTON',
#  'DUNKLIN',
#  'FRANKLIN',
#  'GASCONADE',
#  'HENRY',
#  'HOWARD',
#  'IRON',
#  'JACKSON',
#  'JASPER',
#  'JOHNSON',
#  'LACLEDE',
#  'LAFAYETTE',
#  'LAFAYETTE; JACKSON',
#  'LINCOLN',
#  'LIVINGSTON',
#  'MCDONALD',
#  'MILLER',
#  'MILLER; CAMDEN',
#  'MORGAN',
#  'NEW MADRID',
#  'NEWTON',
#  'NEWTON; JASPER',
#  'PERRY',
#  'POLK',
#  'SALINE',
#  'SCOTT',
#  'SHELBY',
#  'ST CHARLES',
#  'ST FRANCOIS',
#  'ST LOUIS',
#  'STE GENEVIEVE',
#  'STODDARD',
#  'TEXAS',
#  'WASHINGTON',
#  nan}

# %% [markdown]
# # Scott County Drilldown

# %%
ScottCO = MO2019Offenses[MO2019Offenses['COUNTY_NAME']=='SCOTT']

# %%
STAR_relevant_offenses = ['Trespass of Real Property','Curfew/Loitering/Vagrancy Violations',
                          'Drug/Narcotic Violations','Drunkenness','Disorderly Conduct',
                         'Family Offenses, Nonviolent','Simple Assault',
                          'Drug Equipment Violations','Destruction/Damage/Vandalism of Property']

# %%
ScottCO = ScottCO[ScottCO['OFFENSE_NAME'].isin(STAR_relevant_offenses)]

# %%
ScottCO = ScottCO[ScottCO['WEAPON_ID'].isnull()]

# %%
set(ScottCO.ARREST_TYPE_NAME.values)
ScottCO
# Out:
#         DATA_YEAR_x   OFFENSE_ID  INCIDENT_ID  OFFENSE_TYPE_ID_x  \
# 1358           2019  148954217.0    123115231                  5
# 1359           2019  148954219.0    123115231                 16
# 5216           2019  148314019.0    122587835                  5
# 21147          2019  143149361.0    118014786                 35
# 21148          2019  143149360.0    118014786                 16
# ...             ...          ...          ...                ...
# 169104         2019  148318383.0    122587895                 16
# 169105         2019  148314090.0    122582010                 16
# 169110         2019  148314136.0    122587946                 35
# 169111         2019  148314135.0    122587946                 16
# 170282         2019  148314005.0    122587814                 16
#
#        ATTEMPT_COMPLETE_FLAG  LOCATION_ID  NUM_PREMISES_ENTERED  \
# 1358                       C           20                   NaN
# 1359                       C           13                   NaN
# 5216                       C           20                   NaN
# 21147                      C           11                   NaN
# 21148                      C           11                   NaN
# ...                      ...          ...                   ...
# 169104                     C           13                   NaN
# 169105                     C           13                   NaN
# 169110                     C           13                   NaN
# 169111                     C           13                   NaN
# 170282                     C           20                   NaN
#
#        METHOD_ENTRY_CODE  DATA_YEAR_y  ARRESTEE_ID  ARRESTEE_SEQ_NUM  \
# 1358                 NaN       2019.0   38065366.0               1.0
# 1359                 NaN       2019.0   38065366.0               1.0
# 5216                 NaN       2019.0   37631978.0               1.0
# 21147                NaN       2019.0   35968856.0               1.0
# 21148                NaN       2019.0   35968856.0               1.0
# ...                  ...          ...          ...               ...
# 169104               NaN          NaN          NaN               NaN
# 169105               NaN          NaN          NaN               NaN
# 169110               NaN       2019.0   37635634.0               1.0
# 169111               NaN       2019.0   37635634.0               1.0
# 170282               NaN          NaN          NaN               NaN
#
#        ARREST_DATE  ARREST_TYPE_ID MULTIPLE_INDICATOR  OFFENSE_TYPE_ID_y  \
# 1358     29-SEP-19             1.0                  C                5.0
# 1359     29-SEP-19             1.0                  C                5.0
# 5216     10-AUG-19             3.0                  C                5.0
# 21147    19-OCT-19             3.0                  C               51.0
# 21148    19-OCT-19             3.0                  C               51.0
# ...            ...             ...                ...                ...
# 169104         NaN             NaN                NaN                NaN
# 169105         NaN             NaN                NaN                NaN
# 169110   26-JUL-19             3.0                  N               16.0
# 169111   26-JUL-19             3.0                  N               16.0
# 170282         NaN             NaN                NaN                NaN
#
#         AGE_ID_x  AGE_NUM_x SEX_CODE_x  RACE_ID_x  ETHNICITY_ID_x  \
# 1358         5.0       17.0          M        1.0             2.0
# 1359         5.0       17.0          M        1.0             2.0
# 5216         5.0       37.0          F        1.0             2.0
# 21147        5.0       39.0          M        1.0             2.0
# 21148        5.0       39.0          M        1.0             2.0
# ...          ...        ...        ...        ...             ...
# 169104       NaN        NaN        NaN        NaN             NaN
# 169105       NaN        NaN        NaN        NaN             NaN
# 169110       5.0       48.0          F        1.0             2.0
# 169111       5.0       48.0          F        1.0             2.0
# 170282       NaN        NaN        NaN        NaN             NaN
#
#        RESIDENT_CODE UNDER_18_DISPOSITION_CODE  CLEARANCE_IND  \
# 1358             NaN                         H            NaN
# 1359             NaN                         H            NaN
# 5216             NaN                       NaN            NaN
# 21147            NaN                       NaN            NaN
# 21148            NaN                       NaN            NaN
# ...              ...                       ...            ...
# 169104           NaN                       NaN            NaN
# 169105           NaN                       NaN            NaN
# 169110           NaN                       NaN            NaN
# 169111           NaN                       NaN            NaN
# 170282           NaN                       NaN            NaN
#
#         AGE_RANGE_LOW_NUM_x  AGE_RANGE_HIGH_NUM_x ARREST_TYPE_CODE  \
# 1358                   17.0                   0.0                O
# 1359                   17.0                   0.0                O
# 5216                   37.0                   0.0                T
# 21147                  39.0                   0.0                T
# 21148                  39.0                   0.0                T
# ...                     ...                   ...              ...
# 169104                  NaN                   NaN              NaN
# 169105                  NaN                   NaN              NaN
# 169110                 48.0                   0.0                T
# 169111                 48.0                   0.0                T
# 170282                  NaN                   NaN              NaN
#
#           ARREST_TYPE_NAME  OFFENSE_TYPE_ID OFFENSE_CODE  \
# 1358               On View                5          290
# 1359               On View               16          35A
# 5216    Taken INTO Custody                5          290
# 21147   Taken INTO Custody               35          35B
# 21148   Taken INTO Custody               16          35A
# ...                    ...              ...          ...
# 169104                 NaN               16          35A
# 169105                 NaN               16          35A
# 169110  Taken INTO Custody               35          35B
# 169111  Taken INTO Custody               16          35A
# 170282                 NaN               16          35A
#
#                                     OFFENSE_NAME CRIME_AGAINST CT_FLAG  \
# 1358    Destruction/Damage/Vandalism of Property      Property       N
# 1359                    Drug/Narcotic Violations       Society       N
# 5216    Destruction/Damage/Vandalism of Property      Property       N
# 21147                  Drug Equipment Violations       Society       N
# 21148                   Drug/Narcotic Violations       Society       N
# ...                                          ...           ...     ...
# 169104                  Drug/Narcotic Violations       Society       N
# 169105                  Drug/Narcotic Violations       Society       N
# 169110                 Drug Equipment Violations       Society       N
# 169111                  Drug/Narcotic Violations       Society       N
# 170282                  Drug/Narcotic Violations       Society       N
#
#        HC_FLAG  HC_CODE                     OFFENSE_CATEGORY_NAME  \
# 1358         Y     11.0  Destruction/Damage/Vandalism of Property
# 1359         Y      NaN                    Drug/Narcotic Offenses
# 5216         Y     11.0  Destruction/Damage/Vandalism of Property
# 21147        Y      NaN                    Drug/Narcotic Offenses
# 21148        Y      NaN                    Drug/Narcotic Offenses
# ...        ...      ...                                       ...
# 169104       Y      NaN                    Drug/Narcotic Offenses
# 169105       Y      NaN                    Drug/Narcotic Offenses
# 169110       Y      NaN                    Drug/Narcotic Offenses
# 169111       Y      NaN                    Drug/Narcotic Offenses
# 170282       Y      NaN                    Drug/Narcotic Offenses
#
#        OFFENSE_GROUP  LOCATION_CODE                       LOCATION_NAME  \
# 1358               A             20                      Residence/Home
# 1359               A             13  Highway/Road/Alley/Street/Sidewalk
# 5216               A             20                      Residence/Home
# 21147              A             11          Government/Public Building
# 21148              A             11          Government/Public Building
# ...              ...            ...                                 ...
# 169104             A             13  Highway/Road/Alley/Street/Sidewalk
# 169105             A             13  Highway/Road/Alley/Street/Sidewalk
# 169110             A             13  Highway/Road/Alley/Street/Sidewalk
# 169111             A             13  Highway/Road/Alley/Street/Sidewalk
# 170282             A             20                      Residence/Home
#
#         DATA_YEAR_x  AGENCY_ID  NIBRS_MONTH_ID CARGO_THEFT_FLAG  \
# 1358           2019      10092        10527991              NaN
# 1359           2019      10092        10527991              NaN
# 5216           2019      10092         9961238              NaN
# 21147          2019      10092        10749471              NaN
# 21148          2019      10092        10749471              NaN
# ...             ...        ...             ...              ...
# 169104         2019      10092         9961238              NaN
# 169105         2019      10092         9134065              NaN
# 169110         2019      10092         9191063              NaN
# 169111         2019      10092         9191063              NaN
# 170282         2019      10092        10527991              NaN
#
#        SUBMISSION_DATE INCIDENT_DATE REPORT_DATE_FLAG  INCIDENT_HOUR  \
# 1358         13-APR-20     28-SEP-19              NaN           12.0
# 1359         13-APR-20     28-SEP-19              NaN           12.0
# 5216         26-MAR-20     10-AUG-19              NaN           21.0
# 21147        25-NOV-19     19-OCT-19              NaN           18.0
# 21148        25-NOV-19     19-OCT-19              NaN           18.0
# ...                ...           ...              ...            ...
# 169104       26-MAR-20     26-AUG-19              NaN            1.0
# 169105       26-MAR-20     28-JUN-19              NaN           10.0
# 169110       26-MAR-20     26-JUL-19              NaN           13.0
# 169111       26-MAR-20     26-JUL-19              NaN           13.0
# 170282       26-MAR-20     07-SEP-19              NaN           13.0
#
#         CLEARED_EXCEPT_ID CLEARED_EXCEPT_DATE  INCIDENT_STATUS DATA_HOME  \
# 1358                    6                 NaN                0         C
# 1359                    6                 NaN                0         C
# 5216                    6                 NaN                0         C
# 21147                   6                 NaN                0         C
# 21148                   6                 NaN                0         C
# ...                   ...                 ...              ...       ...
# 169104                  6                 NaN                0         C
# 169105                  6                 NaN                0         C
# 169110                  6                 NaN                0         C
# 169111                  6                 NaN                0         C
# 170282                  6                 NaN                0         C
#
#        ORIG_FORMAT       DID  YEARLY_AGENCY_ID  DATA_YEAR_y        ORI  \
# 1358             F  71082367         100922019         2019  MO1010500
# 1359             F  71082367         100922019         2019  MO1010500
# 5216             F  69873522         100922019         2019  MO1010500
# 21147            F  60723128         100922019         2019  MO1010500
# 21148            F  60723128         100922019         2019  MO1010500
# ...            ...       ...               ...          ...        ...
# 169104           F  69873652         100922019         2019  MO1010500
# 169105           F  69873676         100922019         2019  MO1010500
# 169110           F  69877427         100922019         2019  MO1010500
# 169111           F  69877427         100922019         2019  MO1010500
# 170282           F  69877185         100922019         2019  MO1010500
#
#        LEGACY_ORI  COVERED_BY_LEGACY_ORI DIRECT_CONTRIBUTOR_FLAG DORMANT_FLAG  \
# 1358    MO1010500                    NaN                       N            N
# 1359    MO1010500                    NaN                       N            N
# 5216    MO1010500                    NaN                       N            N
# 21147   MO1010500                    NaN                       N            N
# 21148   MO1010500                    NaN                       N            N
# ...           ...                    ...                     ...          ...
# 169104  MO1010500                    NaN                       N            N
# 169105  MO1010500                    NaN                       N            N
# 169110  MO1010500                    NaN                       N            N
# 169111  MO1010500                    NaN                       N            N
# 170282  MO1010500                    NaN                       N            N
#
#         DORMANT_YEAR REPORTING_TYPE UCR_AGENCY_NAME NCIC_AGENCY_NAME  \
# 1358             NaN              I      SCOTT CITY       SCOTT CITY
# 1359             NaN              I      SCOTT CITY       SCOTT CITY
# 5216             NaN              I      SCOTT CITY       SCOTT CITY
# 21147            NaN              I      SCOTT CITY       SCOTT CITY
# 21148            NaN              I      SCOTT CITY       SCOTT CITY
# ...              ...            ...             ...              ...
# 169104           NaN              I      SCOTT CITY       SCOTT CITY
# 169105           NaN              I      SCOTT CITY       SCOTT CITY
# 169110           NaN              I      SCOTT CITY       SCOTT CITY
# 169111           NaN              I      SCOTT CITY       SCOTT CITY
# 170282           NaN              I      SCOTT CITY       SCOTT CITY
#
#        PUB_AGENCY_NAME PUB_AGENCY_UNIT AGENCY_STATUS  STATE_ID STATE_NAME  \
# 1358        Scott City             NaN             A        28   Missouri
# 1359        Scott City             NaN             A        28   Missouri
# 5216        Scott City             NaN             A        28   Missouri
# 21147       Scott City             NaN             A        28   Missouri
# 21148       Scott City             NaN             A        28   Missouri
# ...                ...             ...           ...       ...        ...
# 169104      Scott City             NaN             A        28   Missouri
# 169105      Scott City             NaN             A        28   Missouri
# 169110      Scott City             NaN             A        28   Missouri
# 169111      Scott City             NaN             A        28   Missouri
# 170282      Scott City             NaN             A        28   Missouri
#
#        STATE_ABBR STATE_POSTAL_ABBR  DIVISION_CODE       DIVISION_NAME  \
# 1358           MO                MO              4  West North Central
# 1359           MO                MO              4  West North Central
# 5216           MO                MO              4  West North Central
# 21147          MO                MO              4  West North Central
# 21148          MO                MO              4  West North Central
# ...           ...               ...            ...                 ...
# 169104         MO                MO              4  West North Central
# 169105         MO                MO              4  West North Central
# 169110         MO                MO              4  West North Central
# 169111         MO                MO              4  West North Central
# 170282         MO                MO              4  West North Central
#
#         REGION_CODE REGION_NAME REGION_DESC AGENCY_TYPE_NAME  POPULATION  \
# 1358              2     Midwest   Region II             City        4493
# 1359              2     Midwest   Region II             City        4493
# 5216              2     Midwest   Region II             City        4493
# 21147             2     Midwest   Region II             City        4493
# 21148             2     Midwest   Region II             City        4493
# ...             ...         ...         ...              ...         ...
# 169104            2     Midwest   Region II             City        4493
# 169105            2     Midwest   Region II             City        4493
# 169110            2     Midwest   Region II             City        4493
# 169111            2     Midwest   Region II             City        4493
# 170282            2     Midwest   Region II             City        4493
#
#         SUBMITTING_AGENCY_ID        SAI  \
# 1358                   23376  MOUCR0001
# 1359                   23376  MOUCR0001
# 5216                   23376  MOUCR0001
# 21147                  23376  MOUCR0001
# 21148                  23376  MOUCR0001
# ...                      ...        ...
# 169104                 23376  MOUCR0001
# 169105                 23376  MOUCR0001
# 169110                 23376  MOUCR0001
# 169111                 23376  MOUCR0001
# 170282                 23376  MOUCR0001
#
#                                    SUBMITTING_AGENCY_NAME SUBURBAN_AREA_FLAG  \
# 1358    Missouri State Highway Patrol UCR Program Offi...                  N
# 1359    Missouri State Highway Patrol UCR Program Offi...                  N
# 5216    Missouri State Highway Patrol UCR Program Offi...                  N
# 21147   Missouri State Highway Patrol UCR Program Offi...                  N
# 21148   Missouri State Highway Patrol UCR Program Offi...                  N
# ...                                                   ...                ...
# 169104  Missouri State Highway Patrol UCR Program Offi...                  N
# 169105  Missouri State Highway Patrol UCR Program Offi...                  N
# 169110  Missouri State Highway Patrol UCR Program Offi...                  N
# 169111  Missouri State Highway Patrol UCR Program Offi...                  N
# 170282  Missouri State Highway Patrol UCR Program Offi...                  N
#
#         POPULATION_GROUP_ID POPULATION_GROUP_CODE  \
# 1358                     10                     6
# 1359                     10                     6
# 5216                     10                     6
# 21147                    10                     6
# 21148                    10                     6
# ...                     ...                   ...
# 169104                   10                     6
# 169105                   10                     6
# 169110                   10                     6
# 169111                   10                     6
# 170282                   10                     6
#
#                POPULATION_GROUP_DESC  PARENT_POP_GROUP_CODE  \
# 1358    Cities from 2,500 thru 9,999                      6
# 1359    Cities from 2,500 thru 9,999                      6
# 5216    Cities from 2,500 thru 9,999                      6
# 21147   Cities from 2,500 thru 9,999                      6
# 21148   Cities from 2,500 thru 9,999                      6
# ...                              ...                    ...
# 169104  Cities from 2,500 thru 9,999                      6
# 169105  Cities from 2,500 thru 9,999                      6
# 169110  Cities from 2,500 thru 9,999                      6
# 169111  Cities from 2,500 thru 9,999                      6
# 170282  Cities from 2,500 thru 9,999                      6
#
#                PARENT_POP_GROUP_DESC MIP_FLAG  POP_SORT_ORDER  \
# 1358    Cities from 2,500 thru 9,999        N               2
# 1359    Cities from 2,500 thru 9,999        N               2
# 5216    Cities from 2,500 thru 9,999        N               2
# 21147   Cities from 2,500 thru 9,999        N               2
# 21148   Cities from 2,500 thru 9,999        N               2
# ...                              ...      ...             ...
# 169104  Cities from 2,500 thru 9,999        N               2
# 169105  Cities from 2,500 thru 9,999        N               2
# 169110  Cities from 2,500 thru 9,999        N               2
# 169111  Cities from 2,500 thru 9,999        N               2
# 170282  Cities from 2,500 thru 9,999        N               2
#
#        SUMMARY_RAPE_DEF PE_REPORTED_FLAG  MALE_OFFICER  MALE_CIVILIAN  \
# 1358                  R                Y          13.0            1.0
# 1359                  R                Y          13.0            1.0
# 5216                  R                Y          13.0            1.0
# 21147                 R                Y          13.0            1.0
# 21148                 R                Y          13.0            1.0
# ...                 ...              ...           ...            ...
# 169104                R                Y          13.0            1.0
# 169105                R                Y          13.0            1.0
# 169110                R                Y          13.0            1.0
# 169111                R                Y          13.0            1.0
# 170282                R                Y          13.0            1.0
#
#         PED.MALE_OFFICER+PED.MALE_CIVILIAN  FEMALE_OFFICER  FEMALE_CIVILIAN  \
# 1358                                  14.0             0.0              4.0
# 1359                                  14.0             0.0              4.0
# 5216                                  14.0             0.0              4.0
# 21147                                 14.0             0.0              4.0
# 21148                                 14.0             0.0              4.0
# ...                                    ...             ...              ...
# 169104                                14.0             0.0              4.0
# 169105                                14.0             0.0              4.0
# 169110                                14.0             0.0              4.0
# 169111                                14.0             0.0              4.0
# 170282                                14.0             0.0              4.0
#
#         PED.FEMALE_CIVILIAN+PED.FEMALE_OFFICER  0  0.1 NIBRS_CERT_DATE  \
# 1358                                       4.0  0    0       01-OCT-05
# 1359                                       4.0  0    0       01-OCT-05
# 5216                                       4.0  0    0       01-OCT-05
# 21147                                      4.0  0    0       01-OCT-05
# 21148                                      4.0  0    0       01-OCT-05
# ...                                        ... ..  ...             ...
# 169104                                     4.0  0    0       01-OCT-05
# 169105                                     4.0  0    0       01-OCT-05
# 169110                                     4.0  0    0       01-OCT-05
# 169111                                     4.0  0    0       01-OCT-05
# 170282                                     4.0  0    0       01-OCT-05
#
#        NIBRS_START_DATE NIBRS_LEOKA_START_DATE NIBRS_CT_START_DATE  \
# 1358          01-JUN-19              01-JUN-19           01-JUN-19
# 1359          01-JUN-19              01-JUN-19           01-JUN-19
# 5216          01-JUN-19              01-JUN-19           01-JUN-19
# 21147         01-JUN-19              01-JUN-19           01-JUN-19
# 21148         01-JUN-19              01-JUN-19           01-JUN-19
# ...                 ...                    ...                 ...
# 169104        01-JUN-19              01-JUN-19           01-JUN-19
# 169105        01-JUN-19              01-JUN-19           01-JUN-19
# 169110        01-JUN-19              01-JUN-19           01-JUN-19
# 169111        01-JUN-19              01-JUN-19           01-JUN-19
# 170282        01-JUN-19              01-JUN-19           01-JUN-19
#
#        NIBRS_MULTI_BIAS_START_DATE NIBRS_OFF_ETH_START_DATE COVERED_FLAG  \
# 1358                     01-JUN-19                01-JUN-19            N
# 1359                     01-JUN-19                01-JUN-19            N
# 5216                     01-JUN-19                01-JUN-19            N
# 21147                    01-JUN-19                01-JUN-19            N
# 21148                    01-JUN-19                01-JUN-19            N
# ...                            ...                      ...          ...
# 169104                   01-JUN-19                01-JUN-19            N
# 169105                   01-JUN-19                01-JUN-19            N
# 169110                   01-JUN-19                01-JUN-19            N
# 169111                   01-JUN-19                01-JUN-19            N
# 170282                   01-JUN-19                01-JUN-19            N
#
#        COUNTY_NAME MSA_NAME PUBLISHABLE_FLAG PARTICIPATED NIBRS_PARTICIPATED  \
# 1358         SCOTT  Non-MSA                Y            Y                  Y
# 1359         SCOTT  Non-MSA                Y            Y                  Y
# 5216         SCOTT  Non-MSA                Y            Y                  Y
# 21147        SCOTT  Non-MSA                Y            Y                  Y
# 21148        SCOTT  Non-MSA                Y            Y                  Y
# ...            ...      ...              ...          ...                ...
# 169104       SCOTT  Non-MSA                Y            Y                  Y
# 169105       SCOTT  Non-MSA                Y            Y                  Y
# 169110       SCOTT  Non-MSA                Y            Y                  Y
# 169111       SCOTT  Non-MSA                Y            Y                  Y
# 170282       SCOTT  Non-MSA                Y            Y                  Y
#
#         DATA_YEAR_x  WEAPON_ID  NIBRS_WEAPON_ID WEAPON_CODE WEAPON_NAME  \
# 1358            NaN        NaN              NaN         NaN         NaN
# 1359            NaN        NaN              NaN         NaN         NaN
# 5216            NaN        NaN              NaN         NaN         NaN
# 21147           NaN        NaN              NaN         NaN         NaN
# 21148           NaN        NaN              NaN         NaN         NaN
# ...             ...        ...              ...         ...         ...
# 169104          NaN        NaN              NaN         NaN         NaN
# 169105          NaN        NaN              NaN         NaN         NaN
# 169110          NaN        NaN              NaN         NaN         NaN
# 169111          NaN        NaN              NaN         NaN         NaN
# 170282          NaN        NaN              NaN         NaN         NaN
#
#        SHR_FLAG  DATA_YEAR_y  OFFENDER_ID  OFFENDER_SEQ_NUM  AGE_ID_y  \
# 1358        NaN         2019    140053399                 1       5.0
# 1359        NaN         2019    140053399                 1       5.0
# 5216        NaN         2019    139349603                 1       5.0
# 21147       NaN         2019    134076231                 1       5.0
# 21148       NaN         2019    134076231                 1       5.0
# ...         ...          ...          ...               ...       ...
# 169104      NaN         2019    139357344                 1       5.0
# 169105      NaN         2019    139349675                 1       5.0
# 169110      NaN         2019    139367084                 1       5.0
# 169111      NaN         2019    139367084                 1       5.0
# 170282      NaN         2019    139349593                 1       5.0
#
#         AGE_NUM_y SEX_CODE_y  RACE_ID_y  ETHNICITY_ID_y  AGE_RANGE_LOW_NUM_y  \
# 1358         17.0          M        1.0             2.0                 17.0
# 1359         17.0          M        1.0             2.0                 17.0
# 5216         37.0          F        1.0             2.0                 37.0
# 21147        39.0          M        1.0             2.0                 39.0
# 21148        39.0          M        1.0             2.0                 39.0
# ...           ...        ...        ...             ...                  ...
# 169104       25.0          M        1.0             2.0                 25.0
# 169105       24.0          M        1.0             2.0                 24.0
# 169110       48.0          F        1.0             2.0                 48.0
# 169111       48.0          F        1.0             2.0                 48.0
# 170282       55.0          M        1.0             2.0                 55.0
#
#         AGE_RANGE_HIGH_NUM_y  RACE_ID RACE_CODE RACE_DESC  SORT_ORDER  \
# 1358                     0.0      1.0         W     White        10.0
# 1359                     0.0      1.0         W     White        10.0
# 5216                     0.0      1.0         W     White        10.0
# 21147                    0.0      1.0         W     White        10.0
# 21148                    0.0      1.0         W     White        10.0
# ...                      ...      ...       ...       ...         ...
# 169104                   0.0      NaN       NaN       NaN         NaN
# 169105                   0.0      NaN       NaN       NaN         NaN
# 169110                   0.0      1.0         W     White        10.0
# 169111                   0.0      1.0         W     White        10.0
# 170282                   0.0      NaN       NaN       NaN         NaN
#
#         START_YEAR  END_YEAR NOTES
# 1358           NaN       NaN   NaN
# 1359           NaN       NaN   NaN
# 5216           NaN       NaN   NaN
# 21147          NaN       NaN   NaN
# 21148          NaN       NaN   NaN
# ...            ...       ...   ...
# 169104         NaN       NaN   NaN
# 169105         NaN       NaN   NaN
# 169110         NaN       NaN   NaN
# 169111         NaN       NaN   NaN
# 170282         NaN       NaN   NaN
#
# [236 rows x 133 columns]

# %%
ScottCOViz = ScottCO[['RACE_DESC','OFFENSE_NAME']]

# %%
alt.Chart(ScottCOViz).mark_bar().encode(
    x=alt.X('count(RACE_DESC)'),
    y=alt.Y('OFFENSE_NAME'),
    color=alt.Color('OFFENSE_NAME:N',scale=alt.Scale(scheme='category20c'))
)
# Out:
# alt.Chart(...)

# %%
ScottCO['OFFENSE_NAME'].count()
# Out:
# 236

# %%
ScottCOViz1 = ScottCO[['OFFENSE_ID','LOCATION_NAME','OFFENSE_NAME']]

# %%
alt.Chart(ScottCOViz1).mark_bar().encode(
    x=alt.X('count(OFFENSE_ID)', stack="normalize",axis=alt.Axis(format='%')),
    y='LOCATION_NAME:N',
    color=alt.Color('OFFENSE_NAME:N',scale=alt.Scale(scheme='category20c'))
)
# Out:
# alt.Chart(...)

# %%
ScottCOViz2 = ScottCO[['OFFENSE_ID','OFFENSE_NAME','WEAPON_ID']]

# %%
alt.Chart(ScottCOViz2).mark_bar().encode(
    x=alt.X('count(OFFENSE_ID)', stack="normalize",axis=alt.Axis(format='%')),
    y='OFFENSE_NAME:N',
    color=alt.Color('WEAPON_ID:N',scale=alt.Scale(scheme='category20c'))
)
# Out:
# alt.Chart(...)

# %%
ScottCODrugOffenses = ScottCO[ScottCO['OFFENSE_NAME'].isin(['Drug/Narcotic Violations','Drug Equipment Violations'])]

# %%
# pd.set_option('display.max_columns', None)

# %%
ScottCODrugOffenses.columns.values
# Out:
# array(['DATA_YEAR_x', 'OFFENSE_ID', 'INCIDENT_ID', 'OFFENSE_TYPE_ID_x',
#        'ATTEMPT_COMPLETE_FLAG', 'LOCATION_ID', 'NUM_PREMISES_ENTERED',
#        'METHOD_ENTRY_CODE', 'DATA_YEAR_y', 'ARRESTEE_ID',
#        'ARRESTEE_SEQ_NUM', 'ARREST_DATE', 'ARREST_TYPE_ID',
#        'MULTIPLE_INDICATOR', 'OFFENSE_TYPE_ID_y', 'AGE_ID_x', 'AGE_NUM_x',
#        'SEX_CODE_x', 'RACE_ID_x', 'ETHNICITY_ID_x', 'RESIDENT_CODE',
#        'UNDER_18_DISPOSITION_CODE', 'CLEARANCE_IND',
#        'AGE_RANGE_LOW_NUM_x', 'AGE_RANGE_HIGH_NUM_x', 'ARREST_TYPE_CODE',
#        'ARREST_TYPE_NAME', 'OFFENSE_TYPE_ID', 'OFFENSE_CODE',
#        'OFFENSE_NAME', 'CRIME_AGAINST', 'CT_FLAG', 'HC_FLAG', 'HC_CODE',
#        'OFFENSE_CATEGORY_NAME', 'OFFENSE_GROUP', 'LOCATION_CODE',
#        'LOCATION_NAME', 'DATA_YEAR_x', 'AGENCY_ID', 'NIBRS_MONTH_ID',
#        'CARGO_THEFT_FLAG', 'SUBMISSION_DATE', 'INCIDENT_DATE',
#        'REPORT_DATE_FLAG', 'INCIDENT_HOUR', 'CLEARED_EXCEPT_ID',
#        'CLEARED_EXCEPT_DATE', 'INCIDENT_STATUS', 'DATA_HOME',
#        'ORIG_FORMAT', 'DID', 'YEARLY_AGENCY_ID', 'DATA_YEAR_y', 'ORI',
#        'LEGACY_ORI', 'COVERED_BY_LEGACY_ORI', 'DIRECT_CONTRIBUTOR_FLAG',
#        'DORMANT_FLAG', 'DORMANT_YEAR', 'REPORTING_TYPE',
#        'UCR_AGENCY_NAME', 'NCIC_AGENCY_NAME', 'PUB_AGENCY_NAME',
#        'PUB_AGENCY_UNIT', 'AGENCY_STATUS', 'STATE_ID', 'STATE_NAME',
#        'STATE_ABBR', 'STATE_POSTAL_ABBR', 'DIVISION_CODE',
#        'DIVISION_NAME', 'REGION_CODE', 'REGION_NAME', 'REGION_DESC',
#        'AGENCY_TYPE_NAME', 'POPULATION', 'SUBMITTING_AGENCY_ID', 'SAI',
#        'SUBMITTING_AGENCY_NAME', 'SUBURBAN_AREA_FLAG',
#        'POPULATION_GROUP_ID', 'POPULATION_GROUP_CODE',
#        'POPULATION_GROUP_DESC', 'PARENT_POP_GROUP_CODE',
#        'PARENT_POP_GROUP_DESC', 'MIP_FLAG', 'POP_SORT_ORDER',
#        'SUMMARY_RAPE_DEF', 'PE_REPORTED_FLAG', 'MALE_OFFICER',
#        'MALE_CIVILIAN', 'PED.MALE_OFFICER+PED.MALE_CIVILIAN',
#        'FEMALE_OFFICER', 'FEMALE_CIVILIAN',
#        'PED.FEMALE_CIVILIAN+PED.FEMALE_OFFICER', '0', '0.1',
#        'NIBRS_CERT_DATE', 'NIBRS_START_DATE', 'NIBRS_LEOKA_START_DATE',
#        'NIBRS_CT_START_DATE', 'NIBRS_MULTI_BIAS_START_DATE',
#        'NIBRS_OFF_ETH_START_DATE', 'COVERED_FLAG', 'COUNTY_NAME',
#        'MSA_NAME', 'PUBLISHABLE_FLAG', 'PARTICIPATED',
#        'NIBRS_PARTICIPATED', 'DATA_YEAR_x', 'WEAPON_ID',
#        'NIBRS_WEAPON_ID', 'WEAPON_CODE', 'WEAPON_NAME', 'SHR_FLAG',
#        'DATA_YEAR_y', 'OFFENDER_ID', 'OFFENDER_SEQ_NUM', 'AGE_ID_y',
#        'AGE_NUM_y', 'SEX_CODE_y', 'RACE_ID_y', 'ETHNICITY_ID_y',
#        'AGE_RANGE_LOW_NUM_y', 'AGE_RANGE_HIGH_NUM_y', 'RACE_ID',
#        'RACE_CODE', 'RACE_DESC', 'SORT_ORDER', 'START_YEAR', 'END_YEAR',
#        'NOTES'], dtype=object)

# %%
ScottCODrugOffenses.WEAPON_ID.notnull().any()
# Out:
# False

# %%
ScottCODrugOffensesViz1 = ScottCODrugOffenses[['OFFENSE_ID','LOCATION_NAME','NIBRS_WEAPON_ID']]

# %%
alt.Chart(ScottCODrugOffensesViz1).mark_bar().encode(
    x=alt.X('count(OFFENSE_ID)'),
    y='LOCATION_NAME:N'
)
# Out:
# alt.Chart(...)

# %%
ScottCODrugOffensesViz1
# Out:
#          OFFENSE_ID                       LOCATION_NAME  NIBRS_WEAPON_ID
# 1359    148954219.0  Highway/Road/Alley/Street/Sidewalk              NaN
# 21147   143149361.0          Government/Public Building              NaN
# 21148   143149360.0          Government/Public Building              NaN
# 21152   143158269.0             Parking/Drop Lot/Garage              NaN
# 21153   143158269.0             Parking/Drop Lot/Garage              NaN
# ...             ...                                 ...              ...
# 169104  148318383.0  Highway/Road/Alley/Street/Sidewalk              NaN
# 169105  148314090.0  Highway/Road/Alley/Street/Sidewalk              NaN
# 169110  148314136.0  Highway/Road/Alley/Street/Sidewalk              NaN
# 169111  148314135.0  Highway/Road/Alley/Street/Sidewalk              NaN
# 170282  148314005.0                      Residence/Home              NaN
#
# [219 rows x 3 columns]

# %% [markdown]
# # Kansas City Drilldown

# %%
##Contact Jason Kander Campaign##

# %%
KC = MO2019Offenses[MO2019Offenses['PUB_AGENCY_NAME']=='Kansas City']

# %%
KC = KC[KC['OFFENSE_NAME'].isin(STAR_relevant_offenses)]

# %%
KC = KC[KC['WEAPON_ID'].isnull()]

# %%
KC['OFFENSE_NAME'].count()
# Out:
# 7396

# %%
KC.groupby(['OFFENSE_NAME','RACE_DESC'])['OFFENSE_NAME'].count()
#incredibly disproportionate effect on blacks
# Out:
# OFFENSE_NAME                              RACE_DESC
# Destruction/Damage/Vandalism of Property  American Indian or Alaska Native               1
#                                           Asian                                          2
#                                           Black or African American                    415
#                                           Unknown                                        2
#                                           White                                        255
# Drug Equipment Violations                 Black or African American                    243
#                                           Unknown                                        2
#                                           White                                        410
# Drug/Narcotic Violations                  American Indian or Alaska Native               2
#                                           Asian                                          3
#                                           Black or African American                    564
#                                           Native Hawaiian or Other Pacific Islander      1
#                                           Unknown                                        9
#                                           White                                        609
# Name: OFFENSE_NAME, dtype: int64

# %%
KC['ARREST_TYPE_ID'] = KC['ARREST_TYPE_ID'].fillna(0)
KC['ARREST_TYPE_ID']
# Out:
# 272       0.0
# 274       2.0
# 278       0.0
# 283       0.0
# 284       0.0
#          ...
# 168448    1.0
# 168450    0.0
# 168621    1.0
# 170291    0.0
# 170296    2.0
# Name: ARREST_TYPE_ID, Length: 7396, dtype: float64

# %%
KC.groupby(['OFFENSE_NAME','RACE_DESC','ARREST_TYPE_ID'])['OFFENSE_NAME'].count()
# Out:
# OFFENSE_NAME                              RACE_DESC                                  ARREST_TYPE_ID
# Destruction/Damage/Vandalism of Property  American Indian or Alaska Native           2.0                 1
#                                           Asian                                      3.0                 2
#                                           Black or African American                  1.0               115
#                                                                                      2.0               192
#                                                                                      3.0               108
#                                           Unknown                                    2.0                 2
#                                           White                                      1.0                81
#                                                                                      2.0               105
#                                                                                      3.0                69
# Drug Equipment Violations                 Black or African American                  1.0                98
#                                                                                      2.0                40
#                                                                                      3.0               105
#                                           Unknown                                    3.0                 2
#                                           White                                      1.0               230
#                                                                                      2.0                55
#                                                                                      3.0               125
# Drug/Narcotic Violations                  American Indian or Alaska Native           3.0                 2
#                                           Asian                                      1.0                 2
#                                                                                      3.0                 1
#                                           Black or African American                  1.0               219
#                                                                                      2.0               153
#                                                                                      3.0               192
#                                           Native Hawaiian or Other Pacific Islander  2.0                 1
#                                           Unknown                                    2.0                 9
#                                           White                                      1.0               302
#                                                                                      2.0               125
#                                                                                      3.0               182
# Name: OFFENSE_NAME, dtype: int64

# %% [markdown]
# # 8th Congressional District Drilldown

# %%
EighthCongressionalCounties = ['Bollinger','Butler','Cape Girardeau','Carter','Crawford','Dent','Douglas','Dunklin',
'Howell','Iron','Jefferson','Madison','Mississippi','New Madrid','Oregon','Ozark','Pemiscot','Perry','Phelps',
'Reynolds','Ripley','Scott','Shannon','St. Francois','Ste. Genevieve','Stoddard','Texas','Washington','Wayne','Wright']

# %%
EighthCongressionalCounties = [county.upper() for county in EighthCongressionalCounties]

# %%
EighthCongressionalCounties = [county.replace('.','') for county in EighthCongressionalCounties]

# %%
EighthCongressionalCounties
# Out:
# ['BOLLINGER',
#  'BUTLER',
#  'CAPE GIRARDEAU',
#  'CARTER',
#  'CRAWFORD',
#  'DENT',
#  'DOUGLAS',
#  'DUNKLIN',
#  'HOWELL',
#  'IRON',
#  'JEFFERSON',
#  'MADISON',
#  'MISSISSIPPI',
#  'NEW MADRID',
#  'OREGON',
#  'OZARK',
#  'PEMISCOT',
#  'PERRY',
#  'PHELPS',
#  'REYNOLDS',
#  'RIPLEY',
#  'SCOTT',
#  'SHANNON',
#  'ST FRANCOIS',
#  'STE GENEVIEVE',
#  'STODDARD',
#  'TEXAS',
#  'WASHINGTON',
#  'WAYNE',
#  'WRIGHT']

# %%
EightCongressionalOffenses = MO2019Offenses[MO2019Offenses['COUNTY_NAME'].isin(EighthCongressionalCounties)]

# %%
EightCongressionalOffenses.columns.values
# Out:
# array(['DATA_YEAR_x', 'OFFENSE_ID', 'INCIDENT_ID', 'OFFENSE_TYPE_ID_x',
#        'ATTEMPT_COMPLETE_FLAG', 'LOCATION_ID', 'NUM_PREMISES_ENTERED',
#        'METHOD_ENTRY_CODE', 'DATA_YEAR_y', 'ARRESTEE_ID',
#        'ARRESTEE_SEQ_NUM', 'ARREST_DATE', 'ARREST_TYPE_ID',
#        'MULTIPLE_INDICATOR', 'OFFENSE_TYPE_ID_y', 'AGE_ID_x', 'AGE_NUM_x',
#        'SEX_CODE_x', 'RACE_ID_x', 'ETHNICITY_ID_x', 'RESIDENT_CODE',
#        'UNDER_18_DISPOSITION_CODE', 'CLEARANCE_IND',
#        'AGE_RANGE_LOW_NUM_x', 'AGE_RANGE_HIGH_NUM_x', 'ARREST_TYPE_CODE',
#        'ARREST_TYPE_NAME', 'OFFENSE_TYPE_ID', 'OFFENSE_CODE',
#        'OFFENSE_NAME', 'CRIME_AGAINST', 'CT_FLAG', 'HC_FLAG', 'HC_CODE',
#        'OFFENSE_CATEGORY_NAME', 'OFFENSE_GROUP', 'LOCATION_CODE',
#        'LOCATION_NAME', 'DATA_YEAR_x', 'AGENCY_ID', 'NIBRS_MONTH_ID',
#        'CARGO_THEFT_FLAG', 'SUBMISSION_DATE', 'INCIDENT_DATE',
#        'REPORT_DATE_FLAG', 'INCIDENT_HOUR', 'CLEARED_EXCEPT_ID',
#        'CLEARED_EXCEPT_DATE', 'INCIDENT_STATUS', 'DATA_HOME',
#        'ORIG_FORMAT', 'DID', 'YEARLY_AGENCY_ID', 'DATA_YEAR_y', 'ORI',
#        'LEGACY_ORI', 'COVERED_BY_LEGACY_ORI', 'DIRECT_CONTRIBUTOR_FLAG',
#        'DORMANT_FLAG', 'DORMANT_YEAR', 'REPORTING_TYPE',
#        'UCR_AGENCY_NAME', 'NCIC_AGENCY_NAME', 'PUB_AGENCY_NAME',
#        'PUB_AGENCY_UNIT', 'AGENCY_STATUS', 'STATE_ID', 'STATE_NAME',
#        'STATE_ABBR', 'STATE_POSTAL_ABBR', 'DIVISION_CODE',
#        'DIVISION_NAME', 'REGION_CODE', 'REGION_NAME', 'REGION_DESC',
#        'AGENCY_TYPE_NAME', 'POPULATION', 'SUBMITTING_AGENCY_ID', 'SAI',
#        'SUBMITTING_AGENCY_NAME', 'SUBURBAN_AREA_FLAG',
#        'POPULATION_GROUP_ID', 'POPULATION_GROUP_CODE',
#        'POPULATION_GROUP_DESC', 'PARENT_POP_GROUP_CODE',
#        'PARENT_POP_GROUP_DESC', 'MIP_FLAG', 'POP_SORT_ORDER',
#        'SUMMARY_RAPE_DEF', 'PE_REPORTED_FLAG', 'MALE_OFFICER',
#        'MALE_CIVILIAN', 'PED.MALE_OFFICER+PED.MALE_CIVILIAN',
#        'FEMALE_OFFICER', 'FEMALE_CIVILIAN',
#        'PED.FEMALE_CIVILIAN+PED.FEMALE_OFFICER', '0', '0.1',
#        'NIBRS_CERT_DATE', 'NIBRS_START_DATE', 'NIBRS_LEOKA_START_DATE',
#        'NIBRS_CT_START_DATE', 'NIBRS_MULTI_BIAS_START_DATE',
#        'NIBRS_OFF_ETH_START_DATE', 'COVERED_FLAG', 'COUNTY_NAME',
#        'MSA_NAME', 'PUBLISHABLE_FLAG', 'PARTICIPATED',
#        'NIBRS_PARTICIPATED', 'DATA_YEAR_x', 'WEAPON_ID',
#        'NIBRS_WEAPON_ID', 'WEAPON_CODE', 'WEAPON_NAME', 'SHR_FLAG',
#        'DATA_YEAR_y', 'OFFENDER_ID', 'OFFENDER_SEQ_NUM', 'AGE_ID_y',
#        'AGE_NUM_y', 'SEX_CODE_y', 'RACE_ID_y', 'ETHNICITY_ID_y',
#        'AGE_RANGE_LOW_NUM_y', 'AGE_RANGE_HIGH_NUM_y', 'RACE_ID',
#        'RACE_CODE', 'RACE_DESC', 'SORT_ORDER', 'START_YEAR', 'END_YEAR',
#        'NOTES'], dtype=object)

# %%
EightCongressionalOffensesViz1 = EightCongressionalOffenses[['OFFENSE_ID','LOCATION_NAME','OFFENSE_NAME']]

# %%
alt.Chart(EightCongressionalOffensesViz1).mark_bar().encode(
    x=alt.X('count(OFFENSE_ID)', stack="normalize",axis=alt.Axis(format='%')),
    y='LOCATION_NAME:N',
    color=alt.Color('OFFENSE_NAME:N',scale=alt.Scale(scheme='category20c'))
)
# Out:
# ---------------------------------------------------------------------------
# MaxRowsError                              Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\altair\vegalite\v4\api.py in to_dict(self, *args, **kwargs)
#     361         copy = self.copy(deep=False)
#     362         original_data = getattr(copy, "data", Undefined)
# --> 363         copy.data = _prepare_data(original_data, context)
#     364
#     365         if original_data is not Undefined:
#
# C:\ProgramData\Anaconda3\lib\site-packages\altair\vegalite\v4\api.py in _prepare_data(data, context)
#      82     # convert dataframes  or objects with __geo_interface__ to dict
#      83     if isinstance(data, pd.DataFrame) or hasattr(data, "__geo_interface__"):
# ---> 84         data = _pipe(data, data_transformers.get())
#      85
#      86     # convert string input to a URLData
#
# C:\ProgramData\Anaconda3\lib\site-packages\toolz\functoolz.py in pipe(data, *funcs)
#     632     """
#     633     for func in funcs:
# --> 634         data = func(data)
#     635     return data
#     636
#
# C:\ProgramData\Anaconda3\lib\site-packages\toolz\functoolz.py in __call__(self, *args, **kwargs)
#     301     def __call__(self, *args, **kwargs):
#     302         try:
# --> 303             return self._partial(*args, **kwargs)
#     304         except TypeError as exc:
#     305             if self._should_curry(args, kwargs, exc):
#
# C:\ProgramData\Anaconda3\lib\site-packages\altair\vegalite\data.py in default_data_transformer(data, max_rows)
#      17 @curried.curry
#      18 def default_data_transformer(data, max_rows=5000):
# ---> 19     return curried.pipe(data, limit_rows(max_rows=max_rows), to_values)
#      20
#      21
#
# C:\ProgramData\Anaconda3\lib\site-packages\toolz\functoolz.py in pipe(data, *funcs)
#     632     """
#     633     for func in funcs:
# --> 634         data = func(data)
#     635     return data
#     636
#
# C:\ProgramData\Anaconda3\lib\site-packages\toolz\functoolz.py in __call__(self, *args, **kwargs)
#     301     def __call__(self, *args, **kwargs):
#     302         try:
# --> 303             return self._partial(*args, **kwargs)
#     304         except TypeError as exc:
#     305             if self._should_curry(args, kwargs, exc):
#
# C:\ProgramData\Anaconda3\lib\site-packages\altair\utils\data.py in limit_rows(data, max_rows)
#      82             "than the maximum allowed ({}). "
#      83             "For information on how to plot larger datasets "
# ---> 84             "in Altair, see the documentation".format(max_rows)
#      85         )
#      86     return data
#
# MaxRowsError: The number of rows in your dataset is greater than the maximum allowed (5000). For information on how to plot larger datasets in Altair, see the documentation
# alt.Chart(...)

# %%
EightCongressionalOffensesViz2 = EightCongressionalOffenses[['OFFENSE_ID','OFFENSE_NAME','WEAPON_NAME','COUNTY_NAME']]

# %%
alt.Chart(EightCongressionalOffensesViz2).mark_bar().encode(
    x=alt.X('count(OFFENSE_ID)', stack="normalize",axis=alt.Axis(format='%')),
    y='OFFENSE_NAME:N',
    color=alt.Color('WEAPON_NAME:N',scale=alt.Scale(scheme='category20c'))
)
# Out:
# ---------------------------------------------------------------------------
# MaxRowsError                              Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\altair\vegalite\v4\api.py in to_dict(self, *args, **kwargs)
#     361         copy = self.copy(deep=False)
#     362         original_data = getattr(copy, "data", Undefined)
# --> 363         copy.data = _prepare_data(original_data, context)
#     364
#     365         if original_data is not Undefined:
#
# C:\ProgramData\Anaconda3\lib\site-packages\altair\vegalite\v4\api.py in _prepare_data(data, context)
#      82     # convert dataframes  or objects with __geo_interface__ to dict
#      83     if isinstance(data, pd.DataFrame) or hasattr(data, "__geo_interface__"):
# ---> 84         data = _pipe(data, data_transformers.get())
#      85
#      86     # convert string input to a URLData
#
# C:\ProgramData\Anaconda3\lib\site-packages\toolz\functoolz.py in pipe(data, *funcs)
#     632     """
#     633     for func in funcs:
# --> 634         data = func(data)
#     635     return data
#     636
#
# C:\ProgramData\Anaconda3\lib\site-packages\toolz\functoolz.py in __call__(self, *args, **kwargs)
#     301     def __call__(self, *args, **kwargs):
#     302         try:
# --> 303             return self._partial(*args, **kwargs)
#     304         except TypeError as exc:
#     305             if self._should_curry(args, kwargs, exc):
#
# C:\ProgramData\Anaconda3\lib\site-packages\altair\vegalite\data.py in default_data_transformer(data, max_rows)
#      17 @curried.curry
#      18 def default_data_transformer(data, max_rows=5000):
# ---> 19     return curried.pipe(data, limit_rows(max_rows=max_rows), to_values)
#      20
#      21
#
# C:\ProgramData\Anaconda3\lib\site-packages\toolz\functoolz.py in pipe(data, *funcs)
#     632     """
#     633     for func in funcs:
# --> 634         data = func(data)
#     635     return data
#     636
#
# C:\ProgramData\Anaconda3\lib\site-packages\toolz\functoolz.py in __call__(self, *args, **kwargs)
#     301     def __call__(self, *args, **kwargs):
#     302         try:
# --> 303             return self._partial(*args, **kwargs)
#     304         except TypeError as exc:
#     305             if self._should_curry(args, kwargs, exc):
#
# C:\ProgramData\Anaconda3\lib\site-packages\altair\utils\data.py in limit_rows(data, max_rows)
#      82             "than the maximum allowed ({}). "
#      83             "For information on how to plot larger datasets "
# ---> 84             "in Altair, see the documentation".format(max_rows)
#      85         )
#      86     return data
#
# MaxRowsError: The number of rows in your dataset is greater than the maximum allowed (5000). For information on how to plot larger datasets in Altair, see the documentation
# alt.Chart(...)

# %%
EightCongressionalDrugOffenses = EightCongressionalOffenses[EightCongressionalOffenses['OFFENSE_NAME'].isin(['Drug/Narcotic Violations','Drug Equipment Violations'])]

# %%
EightCongressionalOffensesViz3 = EightCongressionalDrugOffenses[['OFFENSE_ID','LOCATION_NAME','COUNTY_NAME']]

# %%
alt.Chart(EightCongressionalOffensesViz3).mark_bar().encode(
    x=alt.X('count(OFFENSE_ID)'),
    y='COUNTY_NAME:N',
    color=alt.Color('LOCATION_NAME:N',scale=alt.Scale(scheme='category20c'))
)
# Out:
# alt.Chart(...)

# %%
EightCongressionalOffensesViz4 = EightCongressionalDrugOffenses[['ARRESTEE_ID','ARREST_TYPE_NAME','COUNTY_NAME','WEAPON_NAME']]

# %%
alt.Chart(EightCongressionalOffensesViz4).mark_bar().encode(
    x=alt.X('count(ARRESTEE_ID)'),
    y='ARREST_TYPE_NAME:N',
    color=alt.Color('WEAPON_NAME:N',scale=alt.Scale(scheme='category20c'))
)
# Out:
# alt.Chart(...)

# %%
EightCongressionalOffensesViz5 = EightCongressionalDrugOffenses[['ARRESTEE_ID','RACE_DESC','COUNTY_NAME']]

# %%
alt.Chart(EightCongressionalOffensesViz5).mark_bar().encode(
    x=alt.X('count(ARRESTEE_ID)'),
    y='RACE_DESC:N',
)
# Out:
# alt.Chart(...)

# %%
DrugPossession = pd.read_csv('arrests-for-drug-possession-offenses-2019.csv')

# %%
Participation = pd.read_csv('mo-participation-data.csv')

# %%
CrimesAgainstSociety = pd.read_csv('arrests-for-crimes-against-society-offenses-2019.csv')

# %%
AllArrests = pd.read_csv('all-arrest-by-offense-2019.csv')

# %%
Prostitution = pd.read_csv('arrests-for-prostitution-violations-2019.csv')

# %%
Gambling = pd.read_csv('arrests-for-gambling-offenses-2019.csv')

# %%
DrugMeasureType = pd.read_csv('NIBRS_DRUG_MEASURE_TYPE.csv')

# %%
# import geopandas as gpd

# %%
# def get_gpd_df(use_shape_file=True):
#     if use_shape_file:
#         gdf = gpd.read_file(shape_file_loc)
#     else:
#         toronto_json = open_geojson()
#         gdf = gpd.GeoDataFrame.from_features((toronto_json))
#     return gdf

# %%
MOCountiesShape = pd.read_csv('Missouri_Counties.csv')

# %%
MOCountiesShape
# Out:
#      OBJECTID COUNTYNAME  COUNTYFIPS  COUNTYGNIS NAME_UCASE  POP_1990  \
# 0           1      Clark          45      758477      CLARK      7547
# 1           2   Atchison           5      758457   ATCHISON      7457
# 2           3   Scotland         199      758552   SCOTLAND      4822
# 3           4   Schuyler         197      758551   SCHUYLER      4236
# 4           5    Nodaway         147      758528    NODAWAY     21709
# ..        ...        ...         ...         ...        ...       ...
# 110       111   McDonald         119      758518   MCDONALD     16938
# 111       112    Dunklin          69      758489    DUNKLIN     33112
# 112       113   Pemiscot         155      758532   PEMISCOT     21921
# 113       114     Marion         127      758517     MARION     27682
# 114       115     Monroe         137      758523     MONROE      9104
#
#      POP_2000          ACRES    SQ_MILES       CNTY_SEAT  CO_CLASS  \
# 0        7416  327632.419997  511.925656          Kahoka         3
# 1        6430  351990.513001  549.985177       Rock Port         3
# 2        4983  280948.966704  438.982760         Memphis         3
# 3        4170  197084.747448  307.944918       Lancaster         3
# 4       21912  561734.052590  877.709457       Maryville         3
# ..        ...            ...         ...             ...       ...
# 110     21681  345102.871821  539.223237       Pineville         3
# 111     33155  350410.474198  547.516366         Kennett         3
# 112     20047  326247.923468  509.762380  Caruthersville         3
# 113     28289  284331.719607  444.268312         Palmyra         3
# 114      9311  428556.385958  669.619353           Paris         3
#
#       ShapeSTArea  ShapeSTLength
# 0    1.325887e+09  164046.437172
# 1    1.424485e+09  183529.686005
# 2    1.136968e+09  135147.562405
# 3    7.975771e+08  156174.553037
# 4    2.273255e+09  212568.360652
# ..            ...            ...
# 110  1.396929e+09  155042.255480
# 111  1.418415e+09  274321.961664
# 112  1.320522e+09  189371.277913
# 113  1.150632e+09  152114.138426
# 114  1.734337e+09  172133.702469
#
# [115 rows x 13 columns]

# %%
d = {'911 Operator Flag': [.418], 'Independent Request': [.348], 'STAR self-initiation': [.234]}
STARAssignments = pd.DataFrame(data=d).T

# %%
STARAssignments.columns = ['Percentage']

# %%
STARAssignments = STARAssignments.reset_index()

# %%
STARAssignments.columns = ['Type','Percentage']

# %%
alt.Chart(STARAssignments).mark_bar().encode(
    x=alt.X('Percentage',axis=alt.Axis(format='%'),title='Percentage of Calls'),
    y=alt.Y('Type',title=None),
    color = alt.Color('Percentage',legend=None)
).configure(font='Merriweather'
).configure_axis(labelFontSize=15,titleFontSize=24
).properties(
    width=500,
    height=200
)
# Out:
# alt.Chart(...)

# %%
#median star 24.65 on scene personnel time
#median traditional 34.08
d = {'STAR': [24.65], 'Traditional': [34.08]}
ResponseCallTime = pd.DataFrame(data=d).T.reset_index()
ResponseCallTime
# Out:
#          index      0
# 0         STAR  24.65
# 1  Traditional  34.08

# %%
ResponseCallTime.columns = ['Type','MedianResponseTime']

# %%
alt.Chart(ResponseCallTime).mark_bar().encode(
    x=alt.X('MedianResponseTime',title='Median Response Time (in minutes)',axis=alt.Axis(values=[0, 5, 10, 15, 20, 25, 30, 35])),
    y=alt.Y('Type',title=None),
    color = alt.Color('MedianResponseTime',legend=None)
).configure(font='Merriweather'
).configure_axis(labelFontSize=15,titleFontSize=24,grid=False
).properties(
    width=500,
    height=200
)
# Out:
# alt.Chart(...)

# %%
d = {'Homeless Services': [30], 'Walk-in Crisis Center': [24], 'Hospital': [18]}
Transportation = pd.DataFrame(data=d).T.reset_index()
Transportation.columns = ['Location','Times']
Transportation
# Out:
#                 Location  Times
# 0      Homeless Services     30
# 1  Walk-in Crisis Center     24
# 2               Hospital     18

# %%
alt.Chart(Transportation).mark_bar().encode(
    x=alt.X('Times',title='Frequency of Transportation'),#,axis=alt.Axis(values=[0, 5, 10, 15, 20, 25, 30, 35])),
    y=alt.Y('Location',title=None),
    color = alt.Color('Location',legend=None)
).configure(font='Merriweather'
).configure_axis(labelFontSize=15,titleFontSize=24,grid=False
).properties(
    width=500,
    height=200
)
# Out:
# alt.Chart(...)

# %%
denverCrime = pd.read_csv('DENVERcrime.csv')

# %%
denverCrime
# Out:
#         INCIDENT_ID         OFFENSE_ID  OFFENSE_CODE  OFFENSE_CODE_EXTENSION  \
# 0        2021224206   2021224206220200          2202                       0
# 1        2021225308   2021225308240400          2404                       0
# 2       20216009452  20216009452239900          2399                       0
# 3       20216009439  20216009439230500          2305                       0
# 4       20218017976  20218017976240400          2404                       0
# ...             ...                ...           ...                     ...
# 480103   2021145230   2021145230240400          2404                       0
# 480104   2021146155   2021146155220300          2203                       0
# 480105   2021145594   2021145594131501          1315                       1
# 480106   2021146785   2021146785131502          1315                       2
# 480107   2021146095   2021146095240400          2404                       0
#
#                     OFFENSE_TYPE_ID       OFFENSE_CATEGORY_ID  \
# 0       burglary-residence-by-force                  burglary
# 1            theft-of-motor-vehicle                auto-theft
# 2                       theft-other                   larceny
# 3          theft-items-from-vehicle  theft-from-motor-vehicle
# 4            theft-of-motor-vehicle                auto-theft
# ...                             ...                       ...
# 480103       theft-of-motor-vehicle                auto-theft
# 480104   burglary-business-by-force                  burglary
# 480105        aggravated-assault-dv        aggravated-assault
# 480106       menacing-felony-w-weap        aggravated-assault
# 480107       theft-of-motor-vehicle                auto-theft
#
#         FIRST_OCCURRENCE_DATE   LAST_OCCURRENCE_DATE          REPORTED_DATE  \
# 0       4/18/2021 10:30:00 PM   4/19/2021 5:00:00 AM   4/21/2021 3:25:00 PM
# 1       4/21/2021 11:25:00 PM                    NaN  4/22/2021 12:01:00 AM
# 2       3/22/2021 12:51:00 PM  3/22/2021 12:51:00 PM  4/21/2021 10:13:00 PM
# 3       4/21/2021 12:00:00 PM  4/21/2021 12:05:00 PM   4/21/2021 1:17:00 PM
# 4        3/9/2021 12:01:00 PM  4/21/2021 12:20:00 PM  4/21/2021 12:20:00 PM
# ...                       ...                    ...                    ...
# 480103   3/12/2021 3:00:00 AM   3/12/2021 6:00:00 AM   3/12/2021 6:06:00 AM
# 480104   3/10/2021 9:00:00 PM   3/11/2021 8:00:00 AM   3/12/2021 4:04:00 PM
# 480105  3/12/2021 10:15:00 AM                    NaN  3/12/2021 11:13:00 AM
# 480106   3/12/2021 8:20:00 PM                    NaN   3/12/2021 8:20:00 PM
# 480107   3/11/2021 5:00:00 PM  3/12/2021 10:00:00 AM   3/12/2021 2:43:00 PM
#
#                 INCIDENT_ADDRESS      GEO_X      GEO_Y     GEO_LON    GEO_LAT  \
# 0                 300 W 11TH AVE  3142828.0  1692472.0 -104.992161  39.733543
# 1       5700 BLK W DARTMOUTH AVE  3124936.0  1664570.0 -105.056261  39.657203
# 2             3412 N HUMBOLDT ST  3149191.0  1703917.0 -104.969299  39.764862
# 3         1900 BLK S CLARKSON ST  3146781.0  1673727.0 -104.978488  39.682023
# 4               24050 E 78TH AVE  3223419.0  1730557.0 -104.704438  39.836504
# ...                          ...        ...        ...         ...        ...
# 480103    1100 BLK N GALAPAGO ST  3141647.0  1693035.0 -104.996349  39.735107
# 480104          17900 E 56TH AVE  3202807.0  1716160.0 -104.778238  39.797456
# 480105        2140 S DELAWARE ST  3142957.0  1672196.0 -104.992105  39.677879
# 480106          1088 S BRYANT ST  3135704.0  1679185.0 -105.017741  39.697174
# 480107          3257 S PARKER RD  3183194.0  1665052.0 -104.849338  39.657563
#
#         DISTRICT_ID  PRECINCT_ID             NEIGHBORHOOD_ID  IS_CRIME  \
# 0               6.0        611.0                civic-center         1
# 1               4.0        423.0                 bear-valley         1
# 2               2.0        211.0                        cole         1
# 3               3.0        313.0                  platt-park         1
# 4               7.0        759.0                         dia         1
# ...             ...          ...                         ...       ...
# 480103          1.0        123.0                lincoln-park         1
# 480104          5.0        522.0  gateway-green-valley-ranch         1
# 480105          3.0        313.0                    overland         1
# 480106          4.0        412.0                 athmar-park         1
# 480107          3.0        323.0                     kennedy         1
#
#         IS_TRAFFIC
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...            ...
# 480103           0
# 480104           0
# 480105           0
# 480106           0
# 480107           0
#
# [480108 rows x 19 columns]

# %%
denverCrime[['OFFENSE_CODE','OFFENSE_TYPE_ID']].drop_duplicates().sort_values('OFFENSE_TYPE_ID')
# Out:
#         OFFENSE_CODE                OFFENSE_TYPE_ID
# 5077            7399  accessory-conspiracy-to-crime
# 235             1311         agg-aslt-police-weapon
# 126             1315             aggravated-assault
# 11              1315          aggravated-assault-dv
# 277352          2503            altering-vin-number
# ...              ...                            ...
# 896             5212  weapon-poss-illegal-dangerous
# 223             5213   weapon-unlawful-discharge-of
# 254055          5214           weapon-unlawful-sale
# 7221            3611                 window-peeping
# 105689          5799                    wiretapping
#
# [200 rows x 2 columns]

# %%
coloradoOffenses = pd.read_csv('CO_2019_NIBRS_OFFENSE.csv')

# %%
coloradoOffenses = coloradoOffenses.merge(OffenseTypes,how='left',on='OFFENSE_TYPE_ID')

# %%
coloradoOffenses
# Out:
#         DATA_YEAR  OFFENSE_ID  INCIDENT_ID  OFFENSE_TYPE_ID  \
# 0            2019   139343580    114122664                7
# 1            2019   139339591    114122668               45
# 2            2019   139339603    114114683               21
# 3            2019   139339607    114122695               45
# 4            2019   139339608    114122697               23
# ...           ...         ...          ...              ...
# 305311       2019   141844716    116813642                5
# 305312       2019   141852632    116813645               35
# 305313       2019   141848922    116813645               16
# 305314       2019   141844745    116813666               16
# 305315       2019   141848949    116813669               49
#
#        ATTEMPT_COMPLETE_FLAG  LOCATION_ID  NUM_PREMISES_ENTERED  \
# 0                          C           20                   NaN
# 1                          C           20                   NaN
# 2                          C           13                   NaN
# 3                          C           23                   NaN
# 4                          C           12                   NaN
# ...                      ...          ...                   ...
# 305311                     C           18                   NaN
# 305312                     C            8                   NaN
# 305313                     C            8                   NaN
# 305314                     C           38                   NaN
# 305315                     C           20                   NaN
#
#        METHOD_ENTRY_CODE OFFENSE_CODE  \
# 0                    NaN          23G
# 1                    NaN          23H
# 2                    NaN          240
# 3                    NaN          23H
# 4                    NaN          23C
# ...                  ...          ...
# 305311               NaN          290
# 305312               NaN          35B
# 305313               NaN          35A
# 305314               NaN          35A
# 305315                 N          220
#
#                                        OFFENSE_NAME CRIME_AGAINST CT_FLAG  \
# 0       Theft of Motor Vehicle Parts or Accessories      Property       N
# 1                                 All Other Larceny      Property       Y
# 2                               Motor Vehicle Theft      Property       Y
# 3                                 All Other Larceny      Property       Y
# 4                                       Shoplifting      Property       N
# ...                                             ...           ...     ...
# 305311     Destruction/Damage/Vandalism of Property      Property       N
# 305312                    Drug Equipment Violations       Society       N
# 305313                     Drug/Narcotic Violations       Society       N
# 305314                     Drug/Narcotic Violations       Society       N
# 305315                 Burglary/Breaking & Entering      Property       Y
#
#        HC_FLAG  HC_CODE                     OFFENSE_CATEGORY_NAME  \
# 0            N      NaN                    Larceny/Theft Offenses
# 1            N      NaN                    Larceny/Theft Offenses
# 2            Y      7.0                       Motor Vehicle Theft
# 3            N      NaN                    Larceny/Theft Offenses
# 4            N      NaN                    Larceny/Theft Offenses
# ...        ...      ...                                       ...
# 305311       Y     11.0  Destruction/Damage/Vandalism of Property
# 305312       Y      NaN                    Drug/Narcotic Offenses
# 305313       Y      NaN                    Drug/Narcotic Offenses
# 305314       Y      NaN                    Drug/Narcotic Offenses
# 305315       Y      5.0              Burglary/Breaking & Entering
#
#        OFFENSE_GROUP
# 0                  A
# 1                  A
# 2                  A
# 3                  A
# 4                  A
# ...              ...
# 305311             A
# 305312             A
# 305313             A
# 305314             A
# 305315             A
#
# [305316 rows x 16 columns]

# %%
coloradoIncidents = pd.read_csv('CO_2019_NIBRS_incident.csv')

# %%
coloradoOffenses = coloradoOffenses.merge(coloradoIncidents, how='left', on='INCIDENT_ID')

# %%
coloradoAgencies = pd.read_csv('CO_2019_agencies.csv')
coloradoAgencies
# Out:
#      YEARLY_AGENCY_ID  AGENCY_ID  DATA_YEAR        ORI LEGACY_ORI  \
# 0            18262019       1826       2019  CO0010000  CO0010000
# 1            18272019       1827       2019  CO0010100  CO0010100
# 2            18282019       1828       2019  CO0010200  CO0010200
# 3            18292019       1829       2019  CO0010300  CO0010300
# 4            18302019       1830       2019  CO0010400  CO0010400
# ..                ...        ...        ...        ...        ...
# 216         232122019      23212       2019  CO0622400  CO0622400
# 217         232402019      23240       2019  CO0570300  CO0570300
# 218         252672019      25267       2019  CO0418000  CO0418000
# 219         253142019      25314       2019  CO0191000  CO0191000
# 220         290742019      29074       2019  CO030015Y  CO030015Y
#
#      COVERED_BY_LEGACY_ORI DIRECT_CONTRIBUTOR_FLAG DORMANT_FLAG  DORMANT_YEAR  \
# 0                      NaN                       N            N           NaN
# 1                      NaN                       N            N           NaN
# 2                      NaN                       N            N           NaN
# 3                      NaN                       N            N           NaN
# 4                      NaN                       N            N           NaN
# ..                     ...                     ...          ...           ...
# 216                    NaN                       N            N           NaN
# 217                    NaN                       N            N           NaN
# 218                    NaN                       N            N           NaN
# 219                    NaN                       N            N           NaN
# 220                    NaN                       N            N           NaN
#
#     REPORTING_TYPE                     UCR_AGENCY_NAME  \
# 0                I                               ADAMS
# 1                I                              AURORA
# 2                I                            BRIGHTON
# 3                I                       COMMERCE CITY
# 4                I                            THORNTON
# ..             ...                                 ...
# 216              I                              HUDSON
# 217              I                    MOUNTAIN VILLAGE
# 218              I            ALL CRIMES ENFORCEMENT T
# 219              I                              GYPSUM
# 220              I  DIV GAMING CRIM ENF INVEST SECTION
#
#              NCIC_AGENCY_NAME  \
# 0                       ADAMS
# 1                      AURORA
# 2                    BRIGHTON
# 3               COMMERCE CITY
# 4                    THORNTON
# ..                        ...
# 216                    HUDSON
# 217          MOUNTAIN VILLAGE
# 218  ALL CRIMES ENFORCEMENT T
# 219                       NaN
# 220                       NaN
#
#                                        PUB_AGENCY_NAME PUB_AGENCY_UNIT  \
# 0                                                Adams             NaN
# 1                                               Aurora             NaN
# 2                                             Brighton             NaN
# 3                                        Commerce City             NaN
# 4                                             Thornton             NaN
# ..                                                 ...             ...
# 216                                             Hudson             NaN
# 217                                   Mountain Village             NaN
# 218                        All Crimes Enforcement Team             NaN
# 219                                             Gypsum             NaN
# 220  Division of Gaming Criminal Enforcement and In...          Golden
#
#     AGENCY_STATUS  STATE_ID STATE_NAME STATE_ABBR STATE_POSTAL_ABBR  \
# 0               A         7   Colorado         CO                CO
# 1               A         7   Colorado         CO                CO
# 2               A         7   Colorado         CO                CO
# 3               A         7   Colorado         CO                CO
# 4               A         7   Colorado         CO                CO
# ..            ...       ...        ...        ...               ...
# 216             A         7   Colorado         CO                CO
# 217             A         7   Colorado         CO                CO
# 218             A         7   Colorado         CO                CO
# 219             A         7   Colorado         CO                CO
# 220             A         7   Colorado         CO                CO
#
#      DIVISION_CODE DIVISION_NAME  REGION_CODE REGION_NAME REGION_DESC  \
# 0                8      Mountain            4        West   Region IV
# 1                8      Mountain            4        West   Region IV
# 2                8      Mountain            4        West   Region IV
# 3                8      Mountain            4        West   Region IV
# 4                8      Mountain            4        West   Region IV
# ..             ...           ...          ...         ...         ...
# 216              8      Mountain            4        West   Region IV
# 217              8      Mountain            4        West   Region IV
# 218              8      Mountain            4        West   Region IV
# 219              8      Mountain            4        West   Region IV
# 220              8      Mountain            4        West   Region IV
#
#        AGENCY_TYPE_NAME  POPULATION  SUBMITTING_AGENCY_ID        SAI  \
# 0                County      100624                 23358  COUCR0001
# 1                  City      380600                 23358  COUCR0001
# 2                  City       42267                 23358  COUCR0001
# 3                  City       60198                 23358  COUCR0001
# 4                  City      142168                 23358  COUCR0001
# ..                  ...         ...                   ...        ...
# 216                City        1806                 23358  COUCR0001
# 217                City        1450                 23358  COUCR0001
# 218               Other           0                 23358  COUCR0001
# 219                City        7467                 23358  COUCR0001
# 220  Other State Agency           0                 23358  COUCR0001
#
#                                 SUBMITTING_AGENCY_NAME SUBURBAN_AREA_FLAG  \
# 0    Colorado Bureau of Investigation Uniform Crime...                  Y
# 1    Colorado Bureau of Investigation Uniform Crime...                  N
# 2    Colorado Bureau of Investigation Uniform Crime...                  Y
# 3    Colorado Bureau of Investigation Uniform Crime...                  N
# 4    Colorado Bureau of Investigation Uniform Crime...                  N
# ..                                                 ...                ...
# 216  Colorado Bureau of Investigation Uniform Crime...                  Y
# 217  Colorado Bureau of Investigation Uniform Crime...                  N
# 218  Colorado Bureau of Investigation Uniform Crime...                  N
# 219  Colorado Bureau of Investigation Uniform Crime...                  N
# 220  Colorado Bureau of Investigation Uniform Crime...                  N
#
#      POPULATION_GROUP_ID POPULATION_GROUP_CODE  \
# 0                     19                    9A
# 1                      5                    1C
# 2                      8                     4
# 3                      7                     3
# 4                      6                     2
# ..                   ...                   ...
# 216                   11                     7
# 217                   11                     7
# 218                   11                     7
# 219                   10                     6
# 220                   11                     7
#
#                 POPULATION_GROUP_DESC  PARENT_POP_GROUP_CODE  \
# 0        MSA counties 100,000 or over                      9
# 1    Cities from 250,000 thru 499,999                      1
# 2      Cities from 25,000 thru 49,999                      4
# 3      Cities from 50,000 thru 99,999                      3
# 4    Cities from 100,000 thru 249,999                      2
# ..                                ...                    ...
# 216                Cities under 2,500                      7
# 217                Cities under 2,500                      7
# 218                Cities under 2,500                      7
# 219      Cities from 2,500 thru 9,999                      6
# 220                Cities under 2,500                      7
#
#                 PARENT_POP_GROUP_DESC MIP_FLAG  POP_SORT_ORDER  \
# 0                        MSA Counties        Y               3
# 1          All cities 250,000 or over        Y               1
# 2      Cities from 25,000 thru 49,999        N               2
# 3      Cities from 50,000 thru 99,999        N               2
# 4    Cities from 100,000 thru 249,999        Y               1
# ..                                ...      ...             ...
# 216                Cities under 2,500        N               2
# 217                Cities under 2,500        N               2
# 218                Cities under 2,500        N               2
# 219      Cities from 2,500 thru 9,999        N               2
# 220                Cities under 2,500        N               2
#
#     SUMMARY_RAPE_DEF PE_REPORTED_FLAG  MALE_OFFICER  MALE_CIVILIAN  \
# 0                  R                Y           344             43
# 1                  R                Y           610             47
# 2                  R                Y            59              5
# 3                  R                Y            93              6
# 4                  R                Y           206              6
# ..               ...              ...           ...            ...
# 216                R                Y             3              0
# 217                R                Y             6              2
# 218                R                Y             4              0
# 219                R                Y             4              0
# 220                R                Y            11             13
#
#      PED.MALE_OFFICER+PED.MALE_CIVILIAN  FEMALE_OFFICER  FEMALE_CIVILIAN  \
# 0                                   387              56              140
# 1                                   657              78              176
# 2                                    64              16               21
# 3                                    99              17               20
# 4                                   212              36               71
# ..                                  ...             ...              ...
# 216                                   3               1                1
# 217                                   8               1                1
# 218                                   4               0                0
# 219                                   4               0                0
# 220                                  24               3               19
#
#      PED.FEMALE_CIVILIAN+PED.FEMALE_OFFICER  0  0.1 NIBRS_CERT_DATE  \
# 0                                       196  0    0       01-JAN-92
# 1                                       254  0    0       01-JAN-92
# 2                                        37  0    0       01-JAN-92
# 3                                        37  0    0       01-JAN-92
# 4                                       107  0    0       01-JAN-92
# ..                                      ... ..  ...             ...
# 216                                       2  0    0       01-JAN-92
# 217                                       2  0    0       01-JAN-92
# 218                                       0  0    0       01-JAN-92
# 219                                       0  0    0       01-JAN-92
# 220                                      22  0    0       01-JAN-92
#
#     NIBRS_START_DATE NIBRS_LEOKA_START_DATE NIBRS_CT_START_DATE  \
# 0          01-JAN-97              01-MAR-03           01-FEB-14
# 1          01-JAN-85              01-MAR-03           01-FEB-14
# 2          01-SEP-04              01-JAN-06           01-FEB-14
# 3          01-JAN-97              01-MAR-03           01-FEB-14
# 4          01-JAN-12              01-SEP-12           01-JUL-14
# ..               ...                    ...                 ...
# 216        01-JAN-12              01-OCT-12           01-FEB-14
# 217        01-FEB-13              01-JAN-13           01-MAR-14
# 218        01-JAN-13              01-DEC-13           01-FEB-14
# 219        01-FEB-14              01-FEB-14           01-FEB-14
# 220        01-JAN-19              01-JAN-19                 NaN
#
#     NIBRS_MULTI_BIAS_START_DATE NIBRS_OFF_ETH_START_DATE COVERED_FLAG  \
# 0                     01-JAN-16                01-APR-13            N
# 1                     01-JAN-16                01-APR-13            N
# 2                     01-JAN-16                01-APR-13            N
# 3                     01-JAN-16                01-APR-13            N
# 4                     01-FEB-16                01-APR-13            N
# ..                          ...                      ...          ...
# 216                   01-JAN-16                01-APR-13            N
# 217                   01-FEB-16                01-APR-13            N
# 218                   01-JAN-16                01-FEB-14            N
# 219                   01-JAN-16                01-FEB-14            N
# 220                         NaN                      NaN            N
#
#                   COUNTY_NAME                                 MSA_NAME  \
# 0                       ADAMS               Denver-Aurora-Lakewood, CO
# 1    DOUGLAS; ADAMS; ARAPAHOE               Denver-Aurora-Lakewood, CO
# 2                 WELD; ADAMS  Denver-Aurora-Lakewood, CO; Greeley, CO
# 3                       ADAMS               Denver-Aurora-Lakewood, CO
# 4                       ADAMS               Denver-Aurora-Lakewood, CO
# ..                        ...                                      ...
# 216                      WELD                              Greeley, CO
# 217                SAN MIGUEL                                  Non-MSA
# 218                    MOFFAT                                  Non-MSA
# 219                     EAGLE                                  Non-MSA
# 220                 JEFFERSON               Denver-Aurora-Lakewood, CO
#
#     PUBLISHABLE_FLAG PARTICIPATED NIBRS_PARTICIPATED
# 0                  Y            Y                  Y
# 1                  Y            Y                  Y
# 2                  Y            Y                  Y
# 3                  Y            Y                  Y
# 4                  Y            Y                  Y
# ..               ...          ...                ...
# 216                Y            Y                  Y
# 217                Y            Y                  Y
# 218                Y            Y                  Y
# 219                Y            Y                  Y
# 220                Y            Y                  Y
#
# [221 rows x 59 columns]

# %%
coloradoOffenses = coloradoOffenses.merge(coloradoAgencies, how='left', on='AGENCY_ID')

# %%
denverOFFENSEcodes = pd.read_csv('DENVERoffense_codes.csv')

# %%
denverCrime = denverCrime.merge(denverOFFENSEcodes, on='OFFENSE_CODE',how='left')

# %%
denverCrime['REPORTED_DATE']=pd.to_datetime(denverCrime['REPORTED_DATE'])

# %%
import datetime 
start_date = "2019-1-1"
end_date = "2019-12-31"

after_start_date = denverCrime['REPORTED_DATE'] >= start_date
before_end_date = denverCrime['REPORTED_DATE'] <= end_date
between_two_dates = after_start_date & before_end_date
filtered_dates = denverCrime.loc[between_two_dates]

# %%
filtered_dates.sort_values('OFFENSE_ID')
# Out:
#            INCIDENT_ID           OFFENSE_ID  OFFENSE_CODE  \
# 925940           20196          20196521300          5213
# 925941           20196          20196521300          5213
# 833446          201911         201911521300          5213
# 833445          201911         201911521300          5213
# 385890          201960         201960520200          5202
# ...                ...                  ...           ...
# 699939   2019519190039  2019519190039531300          5313
# 1130683  2019659217111  2019659217111544400          5444
# 890238   2019659217111  2019659217111549900          5499
# 890239   2019659217111  2019659217111549900          5499
# 890240   2019659217111  2019659217111549900          5499
#
#          OFFENSE_CODE_EXTENSION_x             OFFENSE_TYPE_ID_x  \
# 925940                          0  weapon-unlawful-discharge-of
# 925941                          0  weapon-unlawful-discharge-of
# 833446                          0  weapon-unlawful-discharge-of
# 833445                          0  weapon-unlawful-discharge-of
# 385890                          0     weapon-carrying-concealed
# ...                           ...                           ...
# 699939                          0                        curfew
# 1130683                         0        traf-habitual-offender
# 890238                          0                    traf-other
# 890239                          0                    traf-other
# 890240                          0                    traf-other
#
#         OFFENSE_CATEGORY_ID_x   FIRST_OCCURRENCE_DATE LAST_OCCURRENCE_DATE  \
# 925940       all-other-crimes    1/1/2019 12:02:00 AM                  NaN
# 925941       all-other-crimes    1/1/2019 12:02:00 AM                  NaN
# 833446       all-other-crimes  12/31/2018 11:59:00 PM                  NaN
# 833445       all-other-crimes  12/31/2018 11:59:00 PM                  NaN
# 385890       all-other-crimes    1/1/2019 12:11:00 AM                  NaN
# ...                       ...                     ...                  ...
# 699939        public-disorder    5/19/2019 2:00:00 AM                  NaN
# 1130683      all-other-crimes  10/14/2019 11:27:00 PM                  NaN
# 890238       all-other-crimes  10/14/2019 11:27:00 PM                  NaN
# 890239       all-other-crimes  10/14/2019 11:27:00 PM                  NaN
# 890240       all-other-crimes  10/14/2019 11:27:00 PM                  NaN
#
#               REPORTED_DATE        INCIDENT_ADDRESS      GEO_X      GEO_Y  \
# 925940  2019-01-01 00:57:00    1100 BLK N WILLOW ST  3172162.0  1692732.0
# 925941  2019-01-01 00:57:00    1100 BLK N WILLOW ST  3172162.0  1692732.0
# 833446  2019-01-01 01:28:00  2800 BLK N HUMBOLDT ST  3149007.0  1701443.0
# 833445  2019-01-01 01:28:00  2800 BLK N HUMBOLDT ST  3149007.0  1701443.0
# 385890  2019-01-01 03:51:00     13691 E RANDOLPH PL  3188780.0  1716159.0
# ...                     ...                     ...        ...        ...
# 699939  2019-05-19 03:03:00                     NaN  3131848.0  1689129.0
# 1130683 2019-10-15 00:54:00  W 4TH AVE / N PERRY ST  3129472.0  1688543.0
# 890238  2019-10-15 00:54:00  W 4TH AVE / N PERRY ST  3129472.0  1688543.0
# 890239  2019-10-15 00:54:00  W 4TH AVE / N PERRY ST  3129472.0  1688543.0
# 890240  2019-10-15 00:54:00  W 4TH AVE / N PERRY ST  3129472.0  1688543.0
#
#             GEO_LON    GEO_LAT  DISTRICT_ID  PRECINCT_ID NEIGHBORHOOD_ID  \
# 925940  -104.887858  39.733761          2.0        223.0     east-colfax
# 925941  -104.887858  39.733761          2.0        223.0     east-colfax
# 833446  -104.970005  39.758073          2.0        211.0        whittier
# 833445  -104.970005  39.758073          2.0        211.0        whittier
# 385890  -104.828156  39.797748          5.0        521.0       montbello
# ...             ...        ...          ...          ...             ...
# 699939  -105.031262  39.724528          4.0        411.0          barnum
# 1130683 -105.039719  39.722953          4.0        411.0     barnum-west
# 890238  -105.039719  39.722953          4.0        411.0     barnum-west
# 890239  -105.039719  39.722953          4.0        411.0     barnum-west
# 890240  -105.039719  39.722953          4.0        411.0     barnum-west
#
#          IS_CRIME_x  IS_TRAFFIC_x  OFFENSE_CODE_EXTENSION_y  \
# 925940            1             0                         0
# 925941            1             0                         1
# 833446            1             0                         1
# 833445            1             0                         0
# 385890            1             0                         0
# ...             ...           ...                       ...
# 699939            1             0                         0
# 1130683           1             0                         0
# 890238            1             0                         0
# 890239            1             0                         1
# 890240            1             0                         2
#
#                     OFFENSE_TYPE_ID_y               OFFENSE_TYPE_NAME  \
# 925940   weapon-unlawful-discharge-of  Unlawful discharge of a weapon
# 925941             weapon-flourishing         Flourishing of a weapon
# 833446             weapon-flourishing         Flourishing of a weapon
# 833445   weapon-unlawful-discharge-of  Unlawful discharge of a weapon
# 385890      weapon-carrying-concealed     Carrying a concealed weapon
# ...                               ...                             ...
# 699939                         curfew                          Curfew
# 1130683        traf-habitual-offender       Habitual traffic offender
# 890238                     traf-other         Traffic offense - other
# 890239              vehicular-eluding               Vehicular eluding
# 890240     vehicular-eluding-no-chase    Vehicular eluding - no chase
#
#         OFFENSE_CATEGORY_ID_y OFFENSE_CATEGORY_NAME  IS_CRIME_y  IS_TRAFFIC_y
# 925940       all-other-crimes      All Other Crimes           1             0
# 925941       all-other-crimes      All Other Crimes           1             0
# 833446       all-other-crimes      All Other Crimes           1             0
# 833445       all-other-crimes      All Other Crimes           1             0
# 385890       all-other-crimes      All Other Crimes           1             0
# ...                       ...                   ...         ...           ...
# 699939        public-disorder       Public Disorder           1             0
# 1130683      all-other-crimes      All Other Crimes           1             0
# 890238       all-other-crimes      All Other Crimes           1             0
# 890239       all-other-crimes      All Other Crimes           1             0
# 890240       all-other-crimes      All Other Crimes           1             0
#
# [224965 rows x 26 columns]

# %%
denverOFFENSEcounts = pd.DataFrame(filtered_dates['OFFENSE_CATEGORY_NAME'].value_counts()).reset_index()

# %%
pd.options.display.max_rows = 200
denverOFFENSEcounts['OFFENSE_CATEGORY_NAME'].sum()
# Out:
# 224965

# %%
coloradoArrestees = pd.read_csv('CO_2019_NIBRS_ARRESTEE.csv')
coloradoArrestees
# Out:
#        DATA_YEAR  ARRESTEE_ID  INCIDENT_ID  ARRESTEE_SEQ_NUM ARREST_DATE  \
# 0           2019     37454104    122137607                 1   28-DEC-19
# 1           2019     37460105    122133856                 1   30-DEC-19
# 2           2019     37454111    122137644                 1   31-DEC-19
# 3           2019     37452104    122116889                 2   27-MAR-19
# 4           2019     37452106    122116896                 1   02-MAR-19
# ...          ...          ...          ...               ...         ...
# 90588       2019     35408700    116808837                 1   12-SEP-19
# 90589       2019     35412888    116814208                 1   18-AUG-19
# 90590       2019     35408862    116814220                 1   16-AUG-19
# 90591       2019     35408865    116814229                 1   23-SEP-19
# 90592       2019     35408867    116814237                 1   30-AUG-19
#
#        ARREST_TYPE_ID MULTIPLE_INDICATOR  OFFENSE_TYPE_ID  AGE_ID  AGE_NUM  \
# 0                   2                  C               45       5       54
# 1                   2                  C               35       5       28
# 2                   1                  C               16       5       24
# 3                   3                  M               44       5       59
# 4                   3                  C               27       5       23
# ...               ...                ...              ...     ...      ...
# 90588               2                  C               47       5       14
# 90589               3                  C               45       5       38
# 90590               3                  C               16       5       33
# 90591               2                  C               51       5       52
# 90592               3                  C               51       5       24
#
#       SEX_CODE  RACE_ID  ETHNICITY_ID RESIDENT_CODE UNDER_18_DISPOSITION_CODE  \
# 0            M        1             3             R                       NaN
# 1            M        1             2             R                       NaN
# 2            M        1             3             N                       NaN
# 3            M        1             3             R                       NaN
# 4            M        1             3             R                       NaN
# ...        ...      ...           ...           ...                       ...
# 90588        F        1             1             R                         R
# 90589        F        1             2             U                       NaN
# 90590        M        1             2             R                       NaN
# 90591        M        1             3             N                       NaN
# 90592        F        1             2             N                       NaN
#
#        CLEARANCE_IND  AGE_RANGE_LOW_NUM  AGE_RANGE_HIGH_NUM
# 0                NaN                 54                   0
# 1                NaN                 28                   0
# 2                NaN                 24                   0
# 3                NaN                 59                   0
# 4                NaN                 23                   0
# ...              ...                ...                 ...
# 90588            NaN                 14                   0
# 90589            NaN                 38                   0
# 90590            NaN                 33                   0
# 90591            NaN                 52                   0
# 90592            NaN                 24                   0
#
# [90593 rows x 18 columns]

# %%
coloradoOffenses = coloradoOffenses.merge(coloradoArrestees, how='left', on='INCIDENT_ID')

# %%
denverFBIoffenses = coloradoOffenses[coloradoOffenses['PUB_AGENCY_NAME']=='Denver']

# %%
FBIdenverOffensecounts = pd.DataFrame(denverFBIoffenses['OFFENSE_NAME'].value_counts()).reset_index()

# %%
FBIdenverOffensecounts['OFFENSE_NAME'].sum()
# Out:
# 55577
