# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import numpy as np
import requests
import statsmodels.formula.api as smf
import altair as alt
# from stargazer.stargazer import Stargazer
import json
apikey = 'AU24y7aNaHPclqjxNcZkTA4q9HcNsVla2ILFhE7h'

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # Data extract

# %%
wash19incidents = pd.read_csv('washington/NIBRS_incident.csv')
wash19incidents['INCIDENT_MONTH'] = pd.DatetimeIndex(wash19incidents['INCIDENT_DATE']).month
wash19offenses = pd.read_csv('washington/NIBRS_OFFENSE.csv')
wash19arrestees = pd.read_csv('washington/NIBRS_ARRESTEE.csv')
wash19offenseTypes = pd.read_csv('washington/NIBRS_OFFENSE_TYPE.csv')
relevant_offenses = ['Trespass of Real Property','Curfew/Loitering/Vagrancy Violations','Drug/Narcotic Violations', 'Drug Equipment Violations','Drunkenness','Disorderly Conduct','Family Offenses, Nonviolent']
wash19agencies = pd.read_csv('washington/agencies.csv')

# %%
wash19offenses = pd.read_csv('washington/NIBRS_OFFENSE.csv')
wash19offenses = wash19offenses.merge(wash19incidents, how='left', on='INCIDENT_ID')
wash19offenses = wash19offenses.merge(wash19agencies, how='left', on='AGENCY_ID')
wash19offenses = wash19offenses.merge(wash19offenseTypes, how='left', on='OFFENSE_TYPE_ID')

# %%
olympia19offenses = wash19offenses[wash19offenses['COUNTY_NAME']=='THURSTON']
olympia19offenseCounts = pd.DataFrame(olympia19offenses.groupby(['INCIDENT_MONTH','OFFENSE_NAME'])['OFFENSE_NAME'].count())
pd.set_option('display.max_rows', 500)
olympia19offenseCounts = olympia19offenseCounts.rename(columns={'OFFENSE_NAME':'OFFENSE_COUNT'})
olympia19offenseCounts = olympia19offenseCounts.reset_index()
olympia19offenseCounts['INCIDENT_MONTH'] = olympia19offenseCounts['INCIDENT_MONTH'].ffill()
olympia19offenseCounts['CRU'] = np.where(olympia19offenseCounts['INCIDENT_MONTH']<4, 0, 1)
olympia19offenseCounts = olympia19offenseCounts[olympia19offenseCounts['OFFENSE_NAME'].isin(relevant_offenses)]

# %%
alt.Chart(olympia19offenseCounts).mark_line().encode(
    x='INCIDENT_MONTH:O',
    y='OFFENSE_COUNT',
    color='OFFENSE_NAME',

)
# Out:
# alt.Chart(...)

# %% [markdown]
# # API

# %%
KC = 'MOKPD0000'


url_1 = "https://api.usa.gov/crime/fbi/sapi/api/agencies/list?api_key=" + apikey
url_2 = "https://api.usa.gov/crime/fbi/sapi/api/summarized/agencies/MOKPD0000/offenses/2014/2016?api_key=" + apikey
url_3 =  "https://api.usa.gov/crime/fbi/sapi/api/arrest/agencies/offense/MOKPD0000/all/2015/2019?api_key=" + apikey


headers = {'Accept': 'application/json'}



response = requests.get(url_3, headers=headers)

data = json.loads(response.content)
data
# Out:
# {'ui_type': 'basic_table',
#  'noun': 'Offense',
#  'category': 'Arrestee Offense',
#  'title': 'All Arrest by Offense',
#  'short_title': 'offense',
#  'ui_restriction': None,
#  'keys': ['Aggravated Assault',
#   'All Other Offenses (Except Traffic)',
#   'Arson',
#   'Burglary',
#   'Curfew and Loitering Law Violations',
#   'Disorderly Conduct',
#   'Driving Under the Influence',
#   'Drug Abuse Violations - Grand Total',
#   'Drunkenness',
#   'Embezzlement',
#   'Forgery and Counterfeiting',
#   'Fraud',
#   'Gambling - Total',
#   'Human Trafficking - Commercial Sex Acts',
#   'Human Trafficking - Involuntary Servitude',
#   'Larceny - Theft',
#   'Liquor Laws',
#   'Manslaughter by Negligence',
#   'Motor Vehicle Theft',
#   'Murder and Nonnegligent Manslaughter',
#   'Offenses Against the Family and Children',
#   'Prostitution and Commercialized Vice',
#   'Rape',
#   'Robbery',
#   'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)',
#   'Simple Assault',
#   'Stolen Property: Buying, Receiving, Possessing',
#   'Suspicion',
#   'Vagrancy',
#   'Vandalism',
#   'Weapons: Carrying, Possessing, Etc.'],
#  'data': [{'value': 437,
#    'data_year': 2015,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 516,
#    'data_year': 2016,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 490,
#    'data_year': 2017,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 401,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 796,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 2570,
#    'data_year': 2015,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 2617,
#    'data_year': 2016,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 2488,
#    'data_year': 2017,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 2666,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 2523,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 9, 'data_year': 2015, 'month_num': 0, 'key': 'Arson'},
#   {'value': 10, 'data_year': 2016, 'month_num': 0, 'key': 'Arson'},
#   {'value': 13, 'data_year': 2017, 'month_num': 0, 'key': 'Arson'},
#   {'value': 9, 'data_year': 2018, 'month_num': 0, 'key': 'Arson'},
#   {'value': 13, 'data_year': 2019, 'month_num': 0, 'key': 'Arson'},
#   {'value': 140, 'data_year': 2015, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 86, 'data_year': 2016, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 116, 'data_year': 2017, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 70, 'data_year': 2018, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 231, 'data_year': 2019, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 1,
#    'data_year': 2015,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 7,
#    'data_year': 2016,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 7,
#    'data_year': 2017,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 1,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 0,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 581,
#    'data_year': 2015,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 579,
#    'data_year': 2016,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 592,
#    'data_year': 2017,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 573,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 660,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 512,
#    'data_year': 2015,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 482,
#    'data_year': 2016,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 507,
#    'data_year': 2017,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 523,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 845,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 960,
#    'data_year': 2015,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 1017,
#    'data_year': 2016,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 1447,
#    'data_year': 2017,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 1368,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 797,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 16, 'data_year': 2015, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 9, 'data_year': 2016, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 2, 'data_year': 2017, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 3, 'data_year': 2018, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 4, 'data_year': 2019, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 17, 'data_year': 2015, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 10, 'data_year': 2016, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 17, 'data_year': 2017, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 14, 'data_year': 2018, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 61, 'data_year': 2019, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 30,
#    'data_year': 2015,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 21,
#    'data_year': 2016,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 21,
#    'data_year': 2017,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 26,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 25,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 46, 'data_year': 2015, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 41, 'data_year': 2016, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 32, 'data_year': 2017, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 25, 'data_year': 2018, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 64, 'data_year': 2019, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 0, 'data_year': 2015, 'month_num': 0, 'key': 'Gambling - Total'},
#   {'value': 0, 'data_year': 2016, 'month_num': 0, 'key': 'Gambling - Total'},
#   {'value': 0, 'data_year': 2017, 'month_num': 0, 'key': 'Gambling - Total'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Gambling - Total'},
#   {'value': 0, 'data_year': 2019, 'month_num': 0, 'key': 'Gambling - Total'},
#   {'value': 0,
#    'data_year': 2015,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 2016,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 2017,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 1,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 2015,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 0,
#    'data_year': 2016,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 0,
#    'data_year': 2017,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 0,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 1586, 'data_year': 2015, 'month_num': 0, 'key': 'Larceny - Theft'},
#   {'value': 1433, 'data_year': 2016, 'month_num': 0, 'key': 'Larceny - Theft'},
#   {'value': 1342, 'data_year': 2017, 'month_num': 0, 'key': 'Larceny - Theft'},
#   {'value': 1373, 'data_year': 2018, 'month_num': 0, 'key': 'Larceny - Theft'},
#   {'value': 1285, 'data_year': 2019, 'month_num': 0, 'key': 'Larceny - Theft'},
#   {'value': 201, 'data_year': 2015, 'month_num': 0, 'key': 'Liquor Laws'},
#   {'value': 104, 'data_year': 2016, 'month_num': 0, 'key': 'Liquor Laws'},
#   {'value': 77, 'data_year': 2017, 'month_num': 0, 'key': 'Liquor Laws'},
#   {'value': 72, 'data_year': 2018, 'month_num': 0, 'key': 'Liquor Laws'},
#   {'value': 47, 'data_year': 2019, 'month_num': 0, 'key': 'Liquor Laws'},
#   {'value': 4,
#    'data_year': 2015,
#    'month_num': 0,
#    'key': 'Manslaughter by Negligence'},
#   {'value': 6,
#    'data_year': 2016,
#    'month_num': 0,
#    'key': 'Manslaughter by Negligence'},
#   {'value': 7,
#    'data_year': 2017,
#    'month_num': 0,
#    'key': 'Manslaughter by Negligence'},
#   {'value': 3,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Manslaughter by Negligence'},
#   {'value': 4,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Manslaughter by Negligence'},
#   {'value': 89,
#    'data_year': 2015,
#    'month_num': 0,
#    'key': 'Motor Vehicle Theft'},
#   {'value': 78,
#    'data_year': 2016,
#    'month_num': 0,
#    'key': 'Motor Vehicle Theft'},
#   {'value': 74,
#    'data_year': 2017,
#    'month_num': 0,
#    'key': 'Motor Vehicle Theft'},
#   {'value': 122,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Motor Vehicle Theft'},
#   {'value': 264,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Motor Vehicle Theft'},
#   {'value': 31,
#    'data_year': 2015,
#    'month_num': 0,
#    'key': 'Murder and Nonnegligent Manslaughter'},
#   {'value': 39,
#    'data_year': 2016,
#    'month_num': 0,
#    'key': 'Murder and Nonnegligent Manslaughter'},
#   {'value': 42,
#    'data_year': 2017,
#    'month_num': 0,
#    'key': 'Murder and Nonnegligent Manslaughter'},
#   {'value': 65,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Murder and Nonnegligent Manslaughter'},
#   {'value': 67,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Murder and Nonnegligent Manslaughter'},
#   {'value': 59,
#    'data_year': 2015,
#    'month_num': 0,
#    'key': 'Offenses Against the Family and Children'},
#   {'value': 90,
#    'data_year': 2016,
#    'month_num': 0,
#    'key': 'Offenses Against the Family and Children'},
#   {'value': 68,
#    'data_year': 2017,
#    'month_num': 0,
#    'key': 'Offenses Against the Family and Children'},
#   {'value': 66,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Offenses Against the Family and Children'},
#   {'value': 80,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Offenses Against the Family and Children'},
#   {'value': 177,
#    'data_year': 2015,
#    'month_num': 0,
#    'key': 'Prostitution and Commercialized Vice'},
#   {'value': 214,
#    'data_year': 2016,
#    'month_num': 0,
#    'key': 'Prostitution and Commercialized Vice'},
#   {'value': 154,
#    'data_year': 2017,
#    'month_num': 0,
#    'key': 'Prostitution and Commercialized Vice'},
#   {'value': 148,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Prostitution and Commercialized Vice'},
#   {'value': 98,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Prostitution and Commercialized Vice'},
#   {'value': 30, 'data_year': 2015, 'month_num': 0, 'key': 'Rape'},
#   {'value': 36, 'data_year': 2016, 'month_num': 0, 'key': 'Rape'},
#   {'value': 67, 'data_year': 2017, 'month_num': 0, 'key': 'Rape'},
#   {'value': 56, 'data_year': 2018, 'month_num': 0, 'key': 'Rape'},
#   {'value': 48, 'data_year': 2019, 'month_num': 0, 'key': 'Rape'},
#   {'value': 232, 'data_year': 2015, 'month_num': 0, 'key': 'Robbery'},
#   {'value': 274, 'data_year': 2016, 'month_num': 0, 'key': 'Robbery'},
#   {'value': 216, 'data_year': 2017, 'month_num': 0, 'key': 'Robbery'},
#   {'value': 216, 'data_year': 2018, 'month_num': 0, 'key': 'Robbery'},
#   {'value': 231, 'data_year': 2019, 'month_num': 0, 'key': 'Robbery'},
#   {'value': 28,
#    'data_year': 2015,
#    'month_num': 0,
#    'key': 'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)'},
#   {'value': 29,
#    'data_year': 2016,
#    'month_num': 0,
#    'key': 'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)'},
#   {'value': 35,
#    'data_year': 2017,
#    'month_num': 0,
#    'key': 'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)'},
#   {'value': 23,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)'},
#   {'value': 24,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)'},
#   {'value': 2441, 'data_year': 2015, 'month_num': 0, 'key': 'Simple Assault'},
#   {'value': 2250, 'data_year': 2016, 'month_num': 0, 'key': 'Simple Assault'},
#   {'value': 2226, 'data_year': 2017, 'month_num': 0, 'key': 'Simple Assault'},
#   {'value': 2344, 'data_year': 2018, 'month_num': 0, 'key': 'Simple Assault'},
#   {'value': 2559, 'data_year': 2019, 'month_num': 0, 'key': 'Simple Assault'},
#   {'value': 37,
#    'data_year': 2015,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 46,
#    'data_year': 2016,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 66,
#    'data_year': 2017,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 64,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 247,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 0, 'data_year': 2015, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 0, 'data_year': 2016, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 0, 'data_year': 2017, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 0, 'data_year': 2019, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 44, 'data_year': 2015, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 62, 'data_year': 2016, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 46, 'data_year': 2017, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 11, 'data_year': 2018, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 6, 'data_year': 2019, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 408, 'data_year': 2015, 'month_num': 0, 'key': 'Vandalism'},
#   {'value': 349, 'data_year': 2016, 'month_num': 0, 'key': 'Vandalism'},
#   {'value': 401, 'data_year': 2017, 'month_num': 0, 'key': 'Vandalism'},
#   {'value': 373, 'data_year': 2018, 'month_num': 0, 'key': 'Vandalism'},
#   {'value': 494, 'data_year': 2019, 'month_num': 0, 'key': 'Vandalism'},
#   {'value': 200,
#    'data_year': 2015,
#    'month_num': 0,
#    'key': 'Weapons: Carrying, Possessing, Etc.'},
#   {'value': 224,
#    'data_year': 2016,
#    'month_num': 0,
#    'key': 'Weapons: Carrying, Possessing, Etc.'},
#   {'value': 157,
#    'data_year': 2017,
#    'month_num': 0,
#    'key': 'Weapons: Carrying, Possessing, Etc.'},
#   {'value': 183,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Weapons: Carrying, Possessing, Etc.'},
#   {'value': 256,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Weapons: Carrying, Possessing, Etc.'}],
#  'precise_data': []}

# %% [markdown]
# # Supervised models

# %% [markdown]
# ## KNN classification

# %% [markdown]
# ### Model development

# %% [markdown]
# ### Visualization

# %% [markdown]
# ### Analysis

# %% [markdown]
# ## Logistic regression

# %% [markdown]
# ### Model development

# %% [markdown]
# ### Visualization

# %% [markdown]
# ### Analysis

# %% [markdown]
# ## Linear regression

# %% [markdown]
# ### Model development

# %% [markdown]
# ### Visualization

# %% [markdown]
# ### Analysis

# %% [markdown]
# ## OLS regression

# %% [markdown]
# ### Model development

# %%
### Example code ####

#`smf.ols(formula="y ~ treatment + x1 + x2 ...")#
#"fixed effect for var_x", you can add a `+C(var_x)`
covariates = ['Intercept','treat1','treat2','treat3','water_2006','apr_may_07']
modelA = smf.ols(formula='summer_07 ~ treat1 + treat2 + treat3 + water_2006 + apr_may_07', data=a2).fit()
modelB = smf.ols(formula='summer_07 ~ treat1 + treat2 + treat3 + water_2006 + apr_may_07 +C(route)', data=a2).fit()
# Q3_table = Stargazer([modelA,modelB])
# Q3_table.covariate_order(covariates)
# Q3_table
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-d7553a1aac31> in <module>
#       4 #"fixed effect for var_x", you can add a `+C(var_x)`
#       5 covariates = ['Intercept','treat1','treat2','treat3','water_2006','apr_may_07']
# ----> 6 modelA = smf.ols(formula='summer_07 ~ treat1 + treat2 + treat3 + water_2006 + apr_may_07', data=a2).fit()
#       7 modelB = smf.ols(formula='summer_07 ~ treat1 + treat2 + treat3 + water_2006 + apr_may_07 +C(route)', data=a2).fit()
#       8 # Q3_table = Stargazer([modelA,modelB])
#
# NameError: name 'a2' is not defined

# %% [markdown]
# ### Visualization

# %% [markdown]
# ### Analysis

# %% [markdown]
# # Unsupervised models

# %% [markdown]
# ## PCA

# %% [markdown]
# ### Model development

# %% [markdown]
# ### Visualization

# %% [markdown]
# ### Analysis

# %% [markdown]
# ## DBSCAN

# %% [markdown]
# ### Model development

# %% [markdown]
# ### Visualization

# %% [markdown]
# ### Analysis
