# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import numpy as np
import requests
import statsmodels.formula.api as smf
# from stargazer.stargazer import Stargazer
import json
apikey = 'IbVrD08MpXh0yJhfYXGe9eFNlHwRWkXNyDb5RWws'
import tqdm

# %% [markdown]
# # Data extract

# %%
### API call library ###
########################

# https://crime-data-explorer.fr.cloud.gov/pages/docApi

########################
########################

# %%
url = "https://api.usa.gov/crime/fbi/sapi/api/agencies/list?api_key=" + apikey
headers = {'Accept': 'application/json'}

response = requests.get(url, headers=headers)

data = json.loads(response.content)
agencies = pd.DataFrame(data)
oris = list(agencies['ori'].unique())

# %%
#summarized-data-controller#
#second one - Agency level SRS crime data endpoint#
offenses = []
# for ori in tqdm(oris[:100]):
for ori in oris[:100]:
    try:
        url = f"https://api.usa.gov/crime/fbi/sapi/api/summarized/agencies/{ori}/offenses/2019/2021?api_key=" + apikey
        
        headers = {'Accept': 'application/json'}

        response = requests.get(url, headers=headers)

        data = json.loads(response.content)
        offenses.append(pd.DataFrame(data['results']))
    except:
        pass
    
offensesDf = pd.concat(offenses)
display(offensesDf)

# %%
url = f"https://api.usa.gov/crime/fbi/sapi/api/summarized/agencies/CODPD0000/offenses/2016/2018?api_key=" + apikey

headers = {'Accept': 'application/json'}

response = requests.get(url, headers=headers)

data = json.loads(response.content)
pd.DataFrame(data['results'])
# Out:
#           ori  data_year              offense state_abbr  cleared  actual  \
# 0   CODPD0000       2016        violent-crime         CO     2310    4602
# 1   CODPD0000       2016              robbery         CO      368    1159
# 2   CODPD0000       2016  motor-vehicle-theft         CO      588    4796
# 3   CODPD0000       2016                 rape         CO      279     586
# 4   CODPD0000       2016       property-crime         CO     4259   25164
# 5   CODPD0000       2016   aggravated-assault         CO     1621    2801
# 6   CODPD0000       2016     human-trafficing         CO        0       0
# 7   CODPD0000       2016                arson         CO       25      94
# 8   CODPD0000       2016             burglary         CO      802    4681
# 9   CODPD0000       2016          rape-legacy         CO        0       0
# 10  CODPD0000       2016             homicide         CO       42      56
# 11  CODPD0000       2016              larceny         CO     2869   15687
# 12  CODPD0000       2017  motor-vehicle-theft         CO      637    5570
# 13  CODPD0000       2017        violent-crime         CO     2815    5338
# 14  CODPD0000       2017              robbery         CO      463    1232
# 15  CODPD0000       2017          rape-legacy         CO      232     514
# 16  CODPD0000       2017                 rape         CO      374     746
# 17  CODPD0000       2017       property-crime         CO     3932   25995
# 18  CODPD0000       2017              larceny         CO     2638   16084
# 19  CODPD0000       2017     human-trafficing         CO        0       0
# 20  CODPD0000       2017             homicide         CO       39      57
# 21  CODPD0000       2017             burglary         CO      657    4341
# 22  CODPD0000       2017                arson         CO       37     132
# 23  CODPD0000       2017   aggravated-assault         CO     1707    2789
# 24  CODPD0000       2018                 rape         CO      390     740
# 25  CODPD0000       2018              robbery         CO      437    1213
# 26  CODPD0000       2018   aggravated-assault         CO     2031    3277
# 27  CODPD0000       2018                arson         CO       24     117
# 28  CODPD0000       2018             burglary         CO      633    4021
# 29  CODPD0000       2018             homicide         CO       49      65
# 30  CODPD0000       2018     human-trafficing         CO        0       0
# 31  CODPD0000       2018              larceny         CO     2453   17391
# 32  CODPD0000       2018  motor-vehicle-theft         CO      695    5340
# 33  CODPD0000       2018        violent-crime         CO     3161    5824
# 34  CODPD0000       2018       property-crime         CO     3781   26752
# 35  CODPD0000       2018          rape-legacy         CO      254     529
#
#    data_range
# 0        None
# 1        None
# 2        None
# 3        None
# 4        None
# 5        None
# 6        None
# 7        None
# 8        None
# 9        None
# 10       None
# 11       None
# 12       None
# 13       None
# 14       None
# 15       None
# 16       None
# 17       None
# 18       None
# 19       None
# 20       None
# 21       None
# 22       None
# 23       None
# 24       None
# 25       None
# 26       None
# 27       None
# 28       None
# 29       None
# 30       None
# 31       None
# 32       None
# 33       None
# 34       None
# 35       None

# %%
#arrest-tkm-controller
offensesDemo = []
KC = 'MOKPD0000'
for ori in oris[:200]:
    try:
        url = f"https://api.usa.gov/crime/fbi/sapi/api/arrest/agencies/offense/{ori}/all/2018/2020?api_key=" + apikey
#         url = f"https://api.usa.gov/crime/fbi/sapi/api/arrest/agencies/offense/{KC}/drug/2019/2021?api_key=" + apikey
        headers = {'Accept': 'application/json'}

        response = requests.get(url, headers=headers)

        data = json.loads(response.content)
        display(data)
#         offensesDemo.append(pd.DataFrame(data['results']))
    except:
        pass
    
# offensesDemoDf = pd.concat(offensesDemo)

# url = f"https://api.usa.gov/crime/fbi/sapi/api/arrest/agencies/offense/{KC}/drug/2019/2021?api_key=" + apikey
# headers = {'Accept': 'application/json'}

# response = requests.get(url, headers=headers)

# data = json.loads(response.content)
# display(data)

# url = f"https://api.usa.gov/crime/fbi/sapi/api/arrest/agencies/{KC}/drug-grand-total/race/2019/2021?api_key=" + apikey
# headers = {'Accept': 'application/json'}

# response = requests.get(url, headers=headers)

# data = json.loads(response.content)
# display(data)
# Out:
# {'ui_type': 'basic_table',
#  'noun': 'Offense',
#  'category': 'Arrestee Offense',
#  'title': 'All Arrest by Offense',
#  'short_title': 'offense',
#  'ui_restriction': None,
#  'keys': ['Aggravated Assault',
#   'All Other Offenses (Except Traffic)',
#   'Arson',
#   'Burglary',
#   'Curfew and Loitering Law Violations',
#   'Disorderly Conduct',
#   'Driving Under the Influence',
#   'Drug Abuse Violations - Grand Total',
#   'Drunkenness',
#   'Embezzlement',
#   'Forgery and Counterfeiting',
#   'Fraud',
#   'Gambling - Total',
#   'Human Trafficking - Commercial Sex Acts',
#   'Human Trafficking - Involuntary Servitude',
#   'Larceny - Theft',
#   'Liquor Laws',
#   'Manslaughter by Negligence',
#   'Motor Vehicle Theft',
#   'Murder and Nonnegligent Manslaughter',
#   'Offenses Against the Family and Children',
#   'Prostitution and Commercialized Vice',
#   'Rape',
#   'Robbery',
#   'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)',
#   'Simple Assault',
#   'Stolen Property: Buying, Receiving, Possessing',
#   'Suspicion',
#   'Vagrancy',
#   'Vandalism',
#   'Weapons: Carrying, Possessing, Etc.'],
#  'data': [{'value': 1124,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 1146,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 5435,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 5292,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 26, 'data_year': 2018, 'month_num': 0, 'key': 'Arson'},
#   {'value': 20, 'data_year': 2019, 'month_num': 0, 'key': 'Arson'},
#   {'value': 301, 'data_year': 2018, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 302, 'data_year': 2019, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 0,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 278,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 323,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 1102,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 1332,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 452,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 396,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 2, 'data_year': 2018, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 2, 'data_year': 2019, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 40, 'data_year': 2018, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 33, 'data_year': 2019, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 84,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 58,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 82, 'data_year': 2018, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 66, 'data_year': 2019, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Gambling - Total'},
#   {'value': 0, 'data_year': 2019, 'month_num': 0, 'key': 'Gambling - Total'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 0,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 1190, 'data_year': 2018, 'month_num': 0, 'key': 'Larceny - Theft'},
#   {'value': 992, 'data_year': 2019, 'month_num': 0, 'key': 'Larceny - Theft'},
#   {'value': 45, 'data_year': 2018, 'month_num': 0, 'key': 'Liquor Laws'},
#   {'value': 18, 'data_year': 2019, 'month_num': 0, 'key': 'Liquor Laws'},
#   {'value': 2,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Manslaughter by Negligence'},
#   {'value': 3,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Manslaughter by Negligence'},
#   {'value': 484,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Motor Vehicle Theft'},
#   {'value': 274,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Motor Vehicle Theft'},
#   {'value': 14,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Murder and Nonnegligent Manslaughter'},
#   {'value': 20,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Murder and Nonnegligent Manslaughter'},
#   {'value': 123,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Offenses Against the Family and Children'},
#   {'value': 136,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Offenses Against the Family and Children'},
#   {'value': 1,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Prostitution and Commercialized Vice'},
#   {'value': 5,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Prostitution and Commercialized Vice'},
#   {'value': 54, 'data_year': 2018, 'month_num': 0, 'key': 'Rape'},
#   {'value': 45, 'data_year': 2019, 'month_num': 0, 'key': 'Rape'},
#   {'value': 264, 'data_year': 2018, 'month_num': 0, 'key': 'Robbery'},
#   {'value': 203, 'data_year': 2019, 'month_num': 0, 'key': 'Robbery'},
#   {'value': 163,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)'},
#   {'value': 167,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)'},
#   {'value': 1796, 'data_year': 2018, 'month_num': 0, 'key': 'Simple Assault'},
#   {'value': 1906, 'data_year': 2019, 'month_num': 0, 'key': 'Simple Assault'},
#   {'value': 101,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 78,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 0, 'data_year': 2019, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 0, 'data_year': 2019, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 655, 'data_year': 2018, 'month_num': 0, 'key': 'Vandalism'},
#   {'value': 711, 'data_year': 2019, 'month_num': 0, 'key': 'Vandalism'},
#   {'value': 155,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Weapons: Carrying, Possessing, Etc.'},
#   {'value': 127,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Weapons: Carrying, Possessing, Etc.'}],
#  'precise_data': []}
# {'ui_type': 'basic_table',
#  'noun': 'Offense',
#  'category': 'Arrestee Offense',
#  'title': 'All Arrest by Offense',
#  'short_title': 'offense',
#  'ui_restriction': None,
#  'keys': ['Aggravated Assault',
#   'All Other Offenses (Except Traffic)',
#   'Arson',
#   'Burglary',
#   'Curfew and Loitering Law Violations',
#   'Disorderly Conduct',
#   'Driving Under the Influence',
#   'Drug Abuse Violations - Grand Total',
#   'Drunkenness',
#   'Embezzlement',
#   'Forgery and Counterfeiting',
#   'Fraud',
#   'Gambling - Total',
#   'Human Trafficking - Commercial Sex Acts',
#   'Human Trafficking - Involuntary Servitude',
#   'Larceny - Theft',
#   'Liquor Laws',
#   'Manslaughter by Negligence',
#   'Motor Vehicle Theft',
#   'Murder and Nonnegligent Manslaughter',
#   'Offenses Against the Family and Children',
#   'Prostitution and Commercialized Vice',
#   'Rape',
#   'Robbery',
#   'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)',
#   'Simple Assault',
#   'Stolen Property: Buying, Receiving, Possessing',
#   'Suspicion',
#   'Vagrancy',
#   'Vandalism',
#   'Weapons: Carrying, Possessing, Etc.'],
#  'data': [{'value': 63,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 57,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 324,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 374,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 2, 'data_year': 2018, 'month_num': 0, 'key': 'Arson'},
#   {'value': 1, 'data_year': 2019, 'month_num': 0, 'key': 'Arson'},
#   {'value': 10, 'data_year': 2018, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 20, 'data_year': 2019, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 0,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 59,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 77,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 194,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 155,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 37,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 31,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 0, 'data_year': 2019, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 9, 'data_year': 2018, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 6, 'data_year': 2019, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 38,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 16,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 20, 'data_year': 2018, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 21, 'data_year': 2019, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Gambling - Total'},
#   {'value': 0, 'data_year': 2019, 'month_num': 0, 'key': 'Gambling - Total'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 0,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 231, 'data_year': 2018, 'month_num': 0, 'key': 'Larceny - Theft'},
#   {'value': 220, 'data_year': 2019, 'month_num': 0, 'key': 'Larceny - Theft'},
#   {'value': 31, 'data_year': 2018, 'month_num': 0, 'key': 'Liquor Laws'},
#   {'value': 20, 'data_year': 2019, 'month_num': 0, 'key': 'Liquor Laws'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Manslaughter by Negligence'},
#   {'value': 0,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Manslaughter by Negligence'},
#   {'value': 37,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Motor Vehicle Theft'},
#   {'value': 43,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Motor Vehicle Theft'},
#   {'value': 8,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Murder and Nonnegligent Manslaughter'},
#   {'value': 2,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Murder and Nonnegligent Manslaughter'},
#   {'value': 5,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Offenses Against the Family and Children'},
#   {'value': 7,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Offenses Against the Family and Children'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Prostitution and Commercialized Vice'},
#   {'value': 0,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Prostitution and Commercialized Vice'},
#   {'value': 1, 'data_year': 2018, 'month_num': 0, 'key': 'Rape'},
#   {'value': 6, 'data_year': 2019, 'month_num': 0, 'key': 'Rape'},
#   {'value': 26, 'data_year': 2018, 'month_num': 0, 'key': 'Robbery'},
#   {'value': 20, 'data_year': 2019, 'month_num': 0, 'key': 'Robbery'},
#   {'value': 27,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)'},
#   {'value': 16,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)'},
#   {'value': 196, 'data_year': 2018, 'month_num': 0, 'key': 'Simple Assault'},
#   {'value': 209, 'data_year': 2019, 'month_num': 0, 'key': 'Simple Assault'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 0,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 0, 'data_year': 2019, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 0, 'data_year': 2019, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 35, 'data_year': 2018, 'month_num': 0, 'key': 'Vandalism'},
#   {'value': 47, 'data_year': 2019, 'month_num': 0, 'key': 'Vandalism'},
#   {'value': 28,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Weapons: Carrying, Possessing, Etc.'},
#   {'value': 37,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Weapons: Carrying, Possessing, Etc.'}],
#  'precise_data': []}
# {'ui_type': 'basic_table',
#  'noun': 'Offense',
#  'category': 'Arrestee Offense',
#  'title': 'All Arrest by Offense',
#  'short_title': 'offense',
#  'ui_restriction': None,
#  'keys': ['Aggravated Assault',
#   'All Other Offenses (Except Traffic)',
#   'Arson',
#   'Burglary',
#   'Curfew and Loitering Law Violations',
#   'Disorderly Conduct',
#   'Driving Under the Influence',
#   'Drug Abuse Violations - Grand Total',
#   'Drunkenness',
#   'Embezzlement',
#   'Forgery and Counterfeiting',
#   'Fraud',
#   'Gambling - Total',
#   'Human Trafficking - Commercial Sex Acts',
#   'Human Trafficking - Involuntary Servitude',
#   'Larceny - Theft',
#   'Liquor Laws',
#   'Manslaughter by Negligence',
#   'Motor Vehicle Theft',
#   'Murder and Nonnegligent Manslaughter',
#   'Offenses Against the Family and Children',
#   'Prostitution and Commercialized Vice',
#   'Rape',
#   'Robbery',
#   'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)',
#   'Simple Assault',
#   'Stolen Property: Buying, Receiving, Possessing',
#   'Suspicion',
#   'Vagrancy',
#   'Vandalism',
#   'Weapons: Carrying, Possessing, Etc.'],
#  'data': [{'value': 90,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 91,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 670,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 691,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 1, 'data_year': 2018, 'month_num': 0, 'key': 'Arson'},
#   {'value': 3, 'data_year': 2019, 'month_num': 0, 'key': 'Arson'},
#   {'value': 24, 'data_year': 2018, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 34, 'data_year': 2019, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 0,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 40,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 36,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 193,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 163,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 65,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 70,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 0, 'data_year': 2019, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 2, 'data_year': 2018, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 1, 'data_year': 2019, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 2,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 0,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 18, 'data_year': 2018, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 18, 'data_year': 2019, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Gambling - Total'},
#   {'value': 0, 'data_year': 2019, 'month_num': 0, 'key': 'Gambling - Total'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 0,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 152, 'data_year': 2018, 'month_num': 0, 'key': 'Larceny - Theft'},
#   {'value': 162, 'data_year': 2019, 'month_num': 0, 'key': 'Larceny - Theft'},
#   {'value': 277, 'data_year': 2018, 'month_num': 0, 'key': 'Liquor Laws'},
#   {'value': 132, 'data_year': 2019, 'month_num': 0, 'key': 'Liquor Laws'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Manslaughter by Negligence'},
#   {'value': 0,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Manslaughter by Negligence'},
#   {'value': 20,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Motor Vehicle Theft'},
#   {'value': 18,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Motor Vehicle Theft'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Murder and Nonnegligent Manslaughter'},
#   {'value': 2,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Murder and Nonnegligent Manslaughter'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Offenses Against the Family and Children'},
#   {'value': 0,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Offenses Against the Family and Children'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Prostitution and Commercialized Vice'},
#   {'value': 0,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Prostitution and Commercialized Vice'},
#   {'value': 5, 'data_year': 2018, 'month_num': 0, 'key': 'Rape'},
#   {'value': 1, 'data_year': 2019, 'month_num': 0, 'key': 'Rape'},
#   {'value': 18, 'data_year': 2018, 'month_num': 0, 'key': 'Robbery'},
#   {'value': 20, 'data_year': 2019, 'month_num': 0, 'key': 'Robbery'},
#   {'value': 10,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)'},
#   {'value': 20,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)'},
#   {'value': 291, 'data_year': 2018, 'month_num': 0, 'key': 'Simple Assault'},
#   {'value': 275, 'data_year': 2019, 'month_num': 0, 'key': 'Simple Assault'},
#   {'value': 4,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 0,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 0, 'data_year': 2019, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 0, 'data_year': 2019, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 64, 'data_year': 2018, 'month_num': 0, 'key': 'Vandalism'},
#   {'value': 61, 'data_year': 2019, 'month_num': 0, 'key': 'Vandalism'},
#   {'value': 22,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Weapons: Carrying, Possessing, Etc.'},
#   {'value': 16,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Weapons: Carrying, Possessing, Etc.'}],
#  'precise_data': []}
# {'ui_type': 'basic_table',
#  'noun': 'Offense',
#  'category': 'Arrestee Offense',
#  'title': 'All Arrest by Offense',
#  'short_title': 'offense',
#  'ui_restriction': None,
#  'keys': ['Aggravated Assault',
#   'All Other Offenses (Except Traffic)',
#   'Arson',
#   'Burglary',
#   'Curfew and Loitering Law Violations',
#   'Disorderly Conduct',
#   'Driving Under the Influence',
#   'Drug Abuse Violations - Grand Total',
#   'Drunkenness',
#   'Embezzlement',
#   'Forgery and Counterfeiting',
#   'Fraud',
#   'Gambling - Total',
#   'Human Trafficking - Commercial Sex Acts',
#   'Human Trafficking - Involuntary Servitude',
#   'Larceny - Theft',
#   'Liquor Laws',
#   'Manslaughter by Negligence',
#   'Motor Vehicle Theft',
#   'Murder and Nonnegligent Manslaughter',
#   'Offenses Against the Family and Children',
#   'Prostitution and Commercialized Vice',
#   'Rape',
#   'Robbery',
#   'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)',
#   'Simple Assault',
#   'Stolen Property: Buying, Receiving, Possessing',
#   'Suspicion',
#   'Vagrancy',
#   'Vandalism',
#   'Weapons: Carrying, Possessing, Etc.'],
#  'data': [{'value': 12,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 27,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 129,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 193,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Arson'},
#   {'value': 2, 'data_year': 2019, 'month_num': 0, 'key': 'Arson'},
#   {'value': 15, 'data_year': 2018, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 6, 'data_year': 2019, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 0,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 35,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 37,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 59,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 67,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 22,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 22,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 0, 'data_year': 2019, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 0, 'data_year': 2019, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 1,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 0,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 4, 'data_year': 2018, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 1, 'data_year': 2019, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Gambling - Total'},
#   {'value': 0, 'data_year': 2019, 'month_num': 0, 'key': 'Gambling - Total'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 0,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 106, 'data_year': 2018, 'month_num': 0, 'key': 'Larceny - Theft'},
#   {'value': 89, 'data_year': 2019, 'month_num': 0, 'key': 'Larceny - Theft'},
#   {'value': 1, 'data_year': 2018, 'month_num': 0, 'key': 'Liquor Laws'},
#   {'value': 4, 'data_year': 2019, 'month_num': 0, 'key': 'Liquor Laws'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Manslaughter by Negligence'},
#   {'value': 0,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Manslaughter by Negligence'},
#   {'value': 13,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Motor Vehicle Theft'},
#   {'value': 10,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Motor Vehicle Theft'},
#   {'value': 1,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Murder and Nonnegligent Manslaughter'},
#   {'value': 0,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Murder and Nonnegligent Manslaughter'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Offenses Against the Family and Children'},
#   {'value': 0,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Offenses Against the Family and Children'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Prostitution and Commercialized Vice'},
#   {'value': 0,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Prostitution and Commercialized Vice'},
#   {'value': 1, 'data_year': 2018, 'month_num': 0, 'key': 'Rape'},
#   {'value': 0, 'data_year': 2019, 'month_num': 0, 'key': 'Rape'},
#   {'value': 2, 'data_year': 2018, 'month_num': 0, 'key': 'Robbery'},
#   {'value': 0, 'data_year': 2019, 'month_num': 0, 'key': 'Robbery'},
#   {'value': 7,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)'},
#   {'value': 3,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)'},
#   {'value': 96, 'data_year': 2018, 'month_num': 0, 'key': 'Simple Assault'},
#   {'value': 123, 'data_year': 2019, 'month_num': 0, 'key': 'Simple Assault'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 0,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 0, 'data_year': 2019, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 0, 'data_year': 2019, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 22, 'data_year': 2018, 'month_num': 0, 'key': 'Vandalism'},
#   {'value': 32, 'data_year': 2019, 'month_num': 0, 'key': 'Vandalism'},
#   {'value': 1,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Weapons: Carrying, Possessing, Etc.'},
#   {'value': 2,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Weapons: Carrying, Possessing, Etc.'}],
#  'precise_data': []}
# {'ui_type': 'basic_table',
#  'noun': 'Offense',
#  'category': 'Arrestee Offense',
#  'title': 'All Arrest by Offense',
#  'short_title': 'offense',
#  'ui_restriction': None,
#  'keys': ['Aggravated Assault',
#   'All Other Offenses (Except Traffic)',
#   'Arson',
#   'Burglary',
#   'Curfew and Loitering Law Violations',
#   'Disorderly Conduct',
#   'Driving Under the Influence',
#   'Drug Abuse Violations - Grand Total',
#   'Drunkenness',
#   'Embezzlement',
#   'Forgery and Counterfeiting',
#   'Fraud',
#   'Gambling - Total',
#   'Human Trafficking - Commercial Sex Acts',
#   'Human Trafficking - Involuntary Servitude',
#   'Larceny - Theft',
#   'Liquor Laws',
#   'Manslaughter by Negligence',
#   'Motor Vehicle Theft',
#   'Murder and Nonnegligent Manslaughter',
#   'Offenses Against the Family and Children',
#   'Prostitution and Commercialized Vice',
#   'Rape',
#   'Robbery',
#   'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)',
#   'Simple Assault',
#   'Stolen Property: Buying, Receiving, Possessing',
#   'Suspicion',
#   'Vagrancy',
#   'Vandalism',
#   'Weapons: Carrying, Possessing, Etc.'],
#  'data': [{'value': 17,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 16,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 88,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 123,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Arson'},
#   {'value': 0, 'data_year': 2019, 'month_num': 0, 'key': 'Arson'},
#   {'value': 5, 'data_year': 2018, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 1, 'data_year': 2019, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 0,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 3, 'data_year': 2018, 'month_num': 0, 'key': 'Disorderly Conduct'},
#   {'value': 9, 'data_year': 2019, 'month_num': 0, 'key': 'Disorderly Conduct'},
#   {'value': 33,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 32,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 6,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 9,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 0, 'data_year': 2019, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 0, 'data_year': 2019, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 1,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 0, 'data_year': 2019, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Gambling - Total'},
#   {'value': 0, 'data_year': 2019, 'month_num': 0, 'key': 'Gambling - Total'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 0,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 13, 'data_year': 2018, 'month_num': 0, 'key': 'Larceny - Theft'},
#   {'value': 12, 'data_year': 2019, 'month_num': 0, 'key': 'Larceny - Theft'},
#   {'value': 17, 'data_year': 2018, 'month_num': 0, 'key': 'Liquor Laws'},
#   {'value': 4, 'data_year': 2019, 'month_num': 0, 'key': 'Liquor Laws'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Manslaughter by Negligence'},
#   {'value': 0,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Manslaughter by Negligence'},
#   {'value': 6,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Motor Vehicle Theft'},
#   {'value': 5,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Motor Vehicle Theft'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Murder and Nonnegligent Manslaughter'},
#   {'value': 0,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Murder and Nonnegligent Manslaughter'},
#   {'value': 1,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Offenses Against the Family and Children'},
#   {'value': 0,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Offenses Against the Family and Children'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Prostitution and Commercialized Vice'},
#   {'value': 0,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Prostitution and Commercialized Vice'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Rape'},
#   {'value': 2, 'data_year': 2019, 'month_num': 0, 'key': 'Rape'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Robbery'},
#   {'value': 5, 'data_year': 2019, 'month_num': 0, 'key': 'Robbery'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)'},
#   {'value': 2,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)'},
#   {'value': 31, 'data_year': 2018, 'month_num': 0, 'key': 'Simple Assault'},
#   {'value': 33, 'data_year': 2019, 'month_num': 0, 'key': 'Simple Assault'},
#   {'value': 1,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 0,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 0, 'data_year': 2019, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 0, 'data_year': 2019, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 3, 'data_year': 2018, 'month_num': 0, 'key': 'Vandalism'},
#   {'value': 4, 'data_year': 2019, 'month_num': 0, 'key': 'Vandalism'},
#   {'value': 7,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Weapons: Carrying, Possessing, Etc.'},
#   {'value': 1,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Weapons: Carrying, Possessing, Etc.'}],
#  'precise_data': []}
# {'ui_type': 'basic_table',
#  'noun': 'Offense',
#  'category': 'Arrestee Offense',
#  'title': 'All Arrest by Offense',
#  'short_title': 'offense',
#  'ui_restriction': None,
#  'keys': ['Aggravated Assault',
#   'All Other Offenses (Except Traffic)',
#   'Arson',
#   'Burglary',
#   'Curfew and Loitering Law Violations',
#   'Disorderly Conduct',
#   'Driving Under the Influence',
#   'Drug Abuse Violations - Grand Total',
#   'Drunkenness',
#   'Embezzlement',
#   'Forgery and Counterfeiting',
#   'Fraud',
#   'Gambling - Total',
#   'Human Trafficking - Commercial Sex Acts',
#   'Human Trafficking - Involuntary Servitude',
#   'Larceny - Theft',
#   'Liquor Laws',
#   'Manslaughter by Negligence',
#   'Motor Vehicle Theft',
#   'Murder and Nonnegligent Manslaughter',
#   'Offenses Against the Family and Children',
#   'Prostitution and Commercialized Vice',
#   'Rape',
#   'Robbery',
#   'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)',
#   'Simple Assault',
#   'Stolen Property: Buying, Receiving, Possessing',
#   'Suspicion',
#   'Vagrancy',
#   'Vandalism',
#   'Weapons: Carrying, Possessing, Etc.'],
#  'data': [{'value': 47,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 259,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 1, 'data_year': 2018, 'month_num': 0, 'key': 'Arson'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 1,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 150,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 45,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 4,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 1,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Gambling - Total'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 11, 'data_year': 2018, 'month_num': 0, 'key': 'Larceny - Theft'},
#   {'value': 20, 'data_year': 2018, 'month_num': 0, 'key': 'Liquor Laws'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Manslaughter by Negligence'},
#   {'value': 3,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Motor Vehicle Theft'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Murder and Nonnegligent Manslaughter'},
#   {'value': 16,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Offenses Against the Family and Children'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Prostitution and Commercialized Vice'},
#   {'value': 16, 'data_year': 2018, 'month_num': 0, 'key': 'Rape'},
#   {'value': 1, 'data_year': 2018, 'month_num': 0, 'key': 'Robbery'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)'},
#   {'value': 165, 'data_year': 2018, 'month_num': 0, 'key': 'Simple Assault'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Vandalism'},
#   {'value': 2,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Weapons: Carrying, Possessing, Etc.'}],
#  'precise_data': []}
# {'ui_type': 'basic_table',
#  'noun': 'Offense',
#  'category': 'Arrestee Offense',
#  'title': 'All Arrest by Offense',
#  'short_title': 'offense',
#  'ui_restriction': None,
#  'keys': ['Aggravated Assault',
#   'All Other Offenses (Except Traffic)',
#   'Arson',
#   'Burglary',
#   'Curfew and Loitering Law Violations',
#   'Disorderly Conduct',
#   'Driving Under the Influence',
#   'Drug Abuse Violations - Grand Total',
#   'Drunkenness',
#   'Embezzlement',
#   'Forgery and Counterfeiting',
#   'Fraud',
#   'Gambling - Total',
#   'Human Trafficking - Commercial Sex Acts',
#   'Human Trafficking - Involuntary Servitude',
#   'Larceny - Theft',
#   'Liquor Laws',
#   'Manslaughter by Negligence',
#   'Motor Vehicle Theft',
#   'Murder and Nonnegligent Manslaughter',
#   'Offenses Against the Family and Children',
#   'Prostitution and Commercialized Vice',
#   'Rape',
#   'Robbery',
#   'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)',
#   'Simple Assault',
#   'Stolen Property: Buying, Receiving, Possessing',
#   'Suspicion',
#   'Vagrancy',
#   'Vandalism',
#   'Weapons: Carrying, Possessing, Etc.'],
#  'data': [{'value': 5,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 22,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Arson'},
#   {'value': 3, 'data_year': 2018, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 2, 'data_year': 2018, 'month_num': 0, 'key': 'Disorderly Conduct'},
#   {'value': 13,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 3,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Gambling - Total'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Larceny - Theft'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Liquor Laws'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Manslaughter by Negligence'},
#   {'value': 3,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Motor Vehicle Theft'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Murder and Nonnegligent Manslaughter'},
#   {'value': 1,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Offenses Against the Family and Children'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Prostitution and Commercialized Vice'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Rape'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Robbery'},
#   {'value': 1,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)'},
#   {'value': 12, 'data_year': 2018, 'month_num': 0, 'key': 'Simple Assault'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Vandalism'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Weapons: Carrying, Possessing, Etc.'}],
#  'precise_data': []}
# {'ui_type': 'basic_table',
#  'noun': 'Offense',
#  'category': 'Arrestee Offense',
#  'title': 'All Arrest by Offense',
#  'short_title': 'offense',
#  'ui_restriction': None,
#  'keys': ['Aggravated Assault',
#   'All Other Offenses (Except Traffic)',
#   'Arson',
#   'Burglary',
#   'Curfew and Loitering Law Violations',
#   'Disorderly Conduct',
#   'Driving Under the Influence',
#   'Drug Abuse Violations - Grand Total',
#   'Drunkenness',
#   'Embezzlement',
#   'Forgery and Counterfeiting',
#   'Fraud',
#   'Gambling - Total',
#   'Human Trafficking - Commercial Sex Acts',
#   'Human Trafficking - Involuntary Servitude',
#   'Larceny - Theft',
#   'Liquor Laws',
#   'Manslaughter by Negligence',
#   'Motor Vehicle Theft',
#   'Murder and Nonnegligent Manslaughter',
#   'Offenses Against the Family and Children',
#   'Prostitution and Commercialized Vice',
#   'Rape',
#   'Robbery',
#   'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)',
#   'Simple Assault',
#   'Stolen Property: Buying, Receiving, Possessing',
#   'Suspicion',
#   'Vagrancy',
#   'Vandalism',
#   'Weapons: Carrying, Possessing, Etc.'],
#  'data': [{'value': 5,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 2, 'data_year': 2019, 'month_num': 0, 'key': 'Aggravated Assault'},
#   {'value': 22,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 7,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Arson'},
#   {'value': 0, 'data_year': 2019, 'month_num': 0, 'key': 'Arson'},
#   {'value': 2, 'data_year': 2018, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 3, 'data_year': 2019, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 0,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 8, 'data_year': 2018, 'month_num': 0, 'key': 'Disorderly Conduct'},
#   {'value': 4, 'data_year': 2019, 'month_num': 0, 'key': 'Disorderly Conduct'},
#   {'value': 33,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 8,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 16,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 2,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 1, 'data_year': 2019, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 0, 'data_year': 2019, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 0,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 2, 'data_year': 2018, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 0, 'data_year': 2019, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Gambling - Total'},
#   {'value': 0, 'data_year': 2019, 'month_num': 0, 'key': 'Gambling - Total'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 0,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 12, 'data_year': 2018, 'month_num': 0, 'key': 'Larceny - Theft'},
#   {'value': 13, 'data_year': 2019, 'month_num': 0, 'key': 'Larceny - Theft'},
#   {'value': 21, 'data_year': 2018, 'month_num': 0, 'key': 'Liquor Laws'},
#   {'value': 9, 'data_year': 2019, 'month_num': 0, 'key': 'Liquor Laws'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Manslaughter by Negligence'},
#   {'value': 0,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Manslaughter by Negligence'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Motor Vehicle Theft'},
#   {'value': 2,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Motor Vehicle Theft'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Murder and Nonnegligent Manslaughter'},
#   {'value': 0,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Murder and Nonnegligent Manslaughter'},
#   {'value': 1,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Offenses Against the Family and Children'},
#   {'value': 0,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Offenses Against the Family and Children'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Prostitution and Commercialized Vice'},
#   {'value': 0,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Prostitution and Commercialized Vice'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Rape'},
#   {'value': 1, 'data_year': 2019, 'month_num': 0, 'key': 'Rape'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Robbery'},
#   {'value': 0, 'data_year': 2019, 'month_num': 0, 'key': 'Robbery'},
#   {'value': 1,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)'},
#   {'value': 0,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)'},
#   {'value': 23, 'data_year': 2018, 'month_num': 0, 'key': 'Simple Assault'},
#   {'value': 8, 'data_year': 2019, 'month_num': 0, 'key': 'Simple Assault'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 0,
#    'data_year': 2019,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 0, 'data_year': 2019, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 0, 'data_year': 2019, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 9, 'data_year': 2018, 'month_num': 0, 'key': 'Vandalism'},
#   {'value': 3, 'data_year': 2019, 'month_num': 0, 'key': 'Vandalism'},
#   {'value': 3,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Weapons: Carrying, Possessing, Etc.'},
#   {'value': 1,
#    'data_year': 2019,
#    'month_num': 0,
# ...
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Vandalism'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Weapons: Carrying, Possessing, Etc.'}],
#  'precise_data': []}
# {'ui_type': 'basic_table',
#  'noun': 'Offense',
#  'category': 'Arrestee Offense',
#  'title': 'All Arrest by Offense',
#  'short_title': 'offense',
#  'ui_restriction': None,
#  'keys': ['Aggravated Assault',
#   'All Other Offenses (Except Traffic)',
#   'Arson',
#   'Burglary',
#   'Curfew and Loitering Law Violations',
#   'Disorderly Conduct',
#   'Driving Under the Influence',
#   'Drug Abuse Violations - Grand Total',
#   'Drunkenness',
#   'Embezzlement',
#   'Forgery and Counterfeiting',
#   'Fraud',
#   'Gambling - Total',
#   'Human Trafficking - Commercial Sex Acts',
#   'Human Trafficking - Involuntary Servitude',
#   'Larceny - Theft',
#   'Liquor Laws',
#   'Manslaughter by Negligence',
#   'Motor Vehicle Theft',
#   'Murder and Nonnegligent Manslaughter',
#   'Offenses Against the Family and Children',
#   'Prostitution and Commercialized Vice',
#   'Rape',
#   'Robbery',
#   'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)',
#   'Simple Assault',
#   'Stolen Property: Buying, Receiving, Possessing',
#   'Suspicion',
#   'Vagrancy',
#   'Vandalism',
#   'Weapons: Carrying, Possessing, Etc.'],
#  'data': [{'value': 2,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 69,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Arson'},
#   {'value': 2, 'data_year': 2018, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 2, 'data_year': 2018, 'month_num': 0, 'key': 'Disorderly Conduct'},
#   {'value': 19,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 87,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 7, 'data_year': 2018, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Gambling - Total'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Larceny - Theft'},
#   {'value': 1, 'data_year': 2018, 'month_num': 0, 'key': 'Liquor Laws'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Manslaughter by Negligence'},
#   {'value': 1,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Motor Vehicle Theft'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Murder and Nonnegligent Manslaughter'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Offenses Against the Family and Children'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Prostitution and Commercialized Vice'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Rape'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Robbery'},
#   {'value': 1,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)'},
#   {'value': 9, 'data_year': 2018, 'month_num': 0, 'key': 'Simple Assault'},
#   {'value': 2,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 2, 'data_year': 2018, 'month_num': 0, 'key': 'Vandalism'},
#   {'value': 5,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Weapons: Carrying, Possessing, Etc.'}],
#  'precise_data': []}
# {'ui_type': 'basic_table',
#  'noun': 'Offense',
#  'category': 'Arrestee Offense',
#  'title': 'All Arrest by Offense',
#  'short_title': 'offense',
#  'ui_restriction': None,
#  'keys': ['Aggravated Assault',
#   'All Other Offenses (Except Traffic)',
#   'Arson',
#   'Burglary',
#   'Curfew and Loitering Law Violations',
#   'Disorderly Conduct',
#   'Driving Under the Influence',
#   'Drug Abuse Violations - Grand Total',
#   'Drunkenness',
#   'Embezzlement',
#   'Forgery and Counterfeiting',
#   'Fraud',
#   'Gambling - Total',
#   'Human Trafficking - Commercial Sex Acts',
#   'Human Trafficking - Involuntary Servitude',
#   'Larceny - Theft',
#   'Liquor Laws',
#   'Manslaughter by Negligence',
#   'Motor Vehicle Theft',
#   'Murder and Nonnegligent Manslaughter',
#   'Offenses Against the Family and Children',
#   'Prostitution and Commercialized Vice',
#   'Rape',
#   'Robbery',
#   'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)',
#   'Simple Assault',
#   'Stolen Property: Buying, Receiving, Possessing',
#   'Suspicion',
#   'Vagrancy',
#   'Vandalism',
#   'Weapons: Carrying, Possessing, Etc.'],
#  'data': [],
#  'precise_data': []}
# {'ui_type': 'basic_table',
#  'noun': 'Offense',
#  'category': 'Arrestee Offense',
#  'title': 'All Arrest by Offense',
#  'short_title': 'offense',
#  'ui_restriction': None,
#  'keys': ['Aggravated Assault',
#   'All Other Offenses (Except Traffic)',
#   'Arson',
#   'Burglary',
#   'Curfew and Loitering Law Violations',
#   'Disorderly Conduct',
#   'Driving Under the Influence',
#   'Drug Abuse Violations - Grand Total',
#   'Drunkenness',
#   'Embezzlement',
#   'Forgery and Counterfeiting',
#   'Fraud',
#   'Gambling - Total',
#   'Human Trafficking - Commercial Sex Acts',
#   'Human Trafficking - Involuntary Servitude',
#   'Larceny - Theft',
#   'Liquor Laws',
#   'Manslaughter by Negligence',
#   'Motor Vehicle Theft',
#   'Murder and Nonnegligent Manslaughter',
#   'Offenses Against the Family and Children',
#   'Prostitution and Commercialized Vice',
#   'Rape',
#   'Robbery',
#   'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)',
#   'Simple Assault',
#   'Stolen Property: Buying, Receiving, Possessing',
#   'Suspicion',
#   'Vagrancy',
#   'Vandalism',
#   'Weapons: Carrying, Possessing, Etc.'],
#  'data': [],
#  'precise_data': []}
# {'ui_type': 'basic_table',
#  'noun': 'Offense',
#  'category': 'Arrestee Offense',
#  'title': 'All Arrest by Offense',
#  'short_title': 'offense',
#  'ui_restriction': None,
#  'keys': ['Aggravated Assault',
#   'All Other Offenses (Except Traffic)',
#   'Arson',
#   'Burglary',
#   'Curfew and Loitering Law Violations',
#   'Disorderly Conduct',
#   'Driving Under the Influence',
#   'Drug Abuse Violations - Grand Total',
#   'Drunkenness',
#   'Embezzlement',
#   'Forgery and Counterfeiting',
#   'Fraud',
#   'Gambling - Total',
#   'Human Trafficking - Commercial Sex Acts',
#   'Human Trafficking - Involuntary Servitude',
#   'Larceny - Theft',
#   'Liquor Laws',
#   'Manslaughter by Negligence',
#   'Motor Vehicle Theft',
#   'Murder and Nonnegligent Manslaughter',
#   'Offenses Against the Family and Children',
#   'Prostitution and Commercialized Vice',
#   'Rape',
#   'Robbery',
#   'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)',
#   'Simple Assault',
#   'Stolen Property: Buying, Receiving, Possessing',
#   'Suspicion',
#   'Vagrancy',
#   'Vandalism',
#   'Weapons: Carrying, Possessing, Etc.'],
#  'data': [{'value': 2,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 41,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Arson'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 1, 'data_year': 2018, 'month_num': 0, 'key': 'Disorderly Conduct'},
#   {'value': 3,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 3,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 2, 'data_year': 2018, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Gambling - Total'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Larceny - Theft'},
#   {'value': 1, 'data_year': 2018, 'month_num': 0, 'key': 'Liquor Laws'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Manslaughter by Negligence'},
#   {'value': 1,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Motor Vehicle Theft'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Murder and Nonnegligent Manslaughter'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Offenses Against the Family and Children'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Prostitution and Commercialized Vice'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Rape'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Robbery'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)'},
#   {'value': 4, 'data_year': 2018, 'month_num': 0, 'key': 'Simple Assault'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Vandalism'},
#   {'value': 7,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Weapons: Carrying, Possessing, Etc.'}],
#  'precise_data': []}
# {'ui_type': 'basic_table',
#  'noun': 'Offense',
#  'category': 'Arrestee Offense',
#  'title': 'All Arrest by Offense',
#  'short_title': 'offense',
#  'ui_restriction': None,
#  'keys': ['Aggravated Assault',
#   'All Other Offenses (Except Traffic)',
#   'Arson',
#   'Burglary',
#   'Curfew and Loitering Law Violations',
#   'Disorderly Conduct',
#   'Driving Under the Influence',
#   'Drug Abuse Violations - Grand Total',
#   'Drunkenness',
#   'Embezzlement',
#   'Forgery and Counterfeiting',
#   'Fraud',
#   'Gambling - Total',
#   'Human Trafficking - Commercial Sex Acts',
#   'Human Trafficking - Involuntary Servitude',
#   'Larceny - Theft',
#   'Liquor Laws',
#   'Manslaughter by Negligence',
#   'Motor Vehicle Theft',
#   'Murder and Nonnegligent Manslaughter',
#   'Offenses Against the Family and Children',
#   'Prostitution and Commercialized Vice',
#   'Rape',
#   'Robbery',
#   'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)',
#   'Simple Assault',
#   'Stolen Property: Buying, Receiving, Possessing',
#   'Suspicion',
#   'Vagrancy',
#   'Vandalism',
#   'Weapons: Carrying, Possessing, Etc.'],
#  'data': [],
#  'precise_data': []}
# {'ui_type': 'basic_table',
#  'noun': 'Offense',
#  'category': 'Arrestee Offense',
#  'title': 'All Arrest by Offense',
#  'short_title': 'offense',
#  'ui_restriction': None,
#  'keys': ['Aggravated Assault',
#   'All Other Offenses (Except Traffic)',
#   'Arson',
#   'Burglary',
#   'Curfew and Loitering Law Violations',
#   'Disorderly Conduct',
#   'Driving Under the Influence',
#   'Drug Abuse Violations - Grand Total',
#   'Drunkenness',
#   'Embezzlement',
#   'Forgery and Counterfeiting',
#   'Fraud',
#   'Gambling - Total',
#   'Human Trafficking - Commercial Sex Acts',
#   'Human Trafficking - Involuntary Servitude',
#   'Larceny - Theft',
#   'Liquor Laws',
#   'Manslaughter by Negligence',
#   'Motor Vehicle Theft',
#   'Murder and Nonnegligent Manslaughter',
#   'Offenses Against the Family and Children',
#   'Prostitution and Commercialized Vice',
#   'Rape',
#   'Robbery',
#   'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)',
#   'Simple Assault',
#   'Stolen Property: Buying, Receiving, Possessing',
#   'Suspicion',
#   'Vagrancy',
#   'Vandalism',
#   'Weapons: Carrying, Possessing, Etc.'],
#  'data': [],
#  'precise_data': []}
# {'ui_type': 'basic_table',
#  'noun': 'Offense',
#  'category': 'Arrestee Offense',
#  'title': 'All Arrest by Offense',
#  'short_title': 'offense',
#  'ui_restriction': None,
#  'keys': ['Aggravated Assault',
#   'All Other Offenses (Except Traffic)',
#   'Arson',
#   'Burglary',
#   'Curfew and Loitering Law Violations',
#   'Disorderly Conduct',
#   'Driving Under the Influence',
#   'Drug Abuse Violations - Grand Total',
#   'Drunkenness',
#   'Embezzlement',
#   'Forgery and Counterfeiting',
#   'Fraud',
#   'Gambling - Total',
#   'Human Trafficking - Commercial Sex Acts',
#   'Human Trafficking - Involuntary Servitude',
#   'Larceny - Theft',
#   'Liquor Laws',
#   'Manslaughter by Negligence',
#   'Motor Vehicle Theft',
#   'Murder and Nonnegligent Manslaughter',
#   'Offenses Against the Family and Children',
#   'Prostitution and Commercialized Vice',
#   'Rape',
#   'Robbery',
#   'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)',
#   'Simple Assault',
#   'Stolen Property: Buying, Receiving, Possessing',
#   'Suspicion',
#   'Vagrancy',
#   'Vandalism',
#   'Weapons: Carrying, Possessing, Etc.'],
#  'data': [],
#  'precise_data': []}
# {'ui_type': 'basic_table',
#  'noun': 'Offense',
#  'category': 'Arrestee Offense',
#  'title': 'All Arrest by Offense',
#  'short_title': 'offense',
#  'ui_restriction': None,
#  'keys': ['Aggravated Assault',
#   'All Other Offenses (Except Traffic)',
#   'Arson',
#   'Burglary',
#   'Curfew and Loitering Law Violations',
#   'Disorderly Conduct',
#   'Driving Under the Influence',
#   'Drug Abuse Violations - Grand Total',
#   'Drunkenness',
#   'Embezzlement',
#   'Forgery and Counterfeiting',
#   'Fraud',
#   'Gambling - Total',
#   'Human Trafficking - Commercial Sex Acts',
#   'Human Trafficking - Involuntary Servitude',
#   'Larceny - Theft',
#   'Liquor Laws',
#   'Manslaughter by Negligence',
#   'Motor Vehicle Theft',
#   'Murder and Nonnegligent Manslaughter',
#   'Offenses Against the Family and Children',
#   'Prostitution and Commercialized Vice',
#   'Rape',
#   'Robbery',
#   'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)',
#   'Simple Assault',
#   'Stolen Property: Buying, Receiving, Possessing',
#   'Suspicion',
#   'Vagrancy',
#   'Vandalism',
#   'Weapons: Carrying, Possessing, Etc.'],
#  'data': [],
#  'precise_data': []}
# {'ui_type': 'basic_table',
#  'noun': 'Offense',
#  'category': 'Arrestee Offense',
#  'title': 'All Arrest by Offense',
#  'short_title': 'offense',
#  'ui_restriction': None,
#  'keys': ['Aggravated Assault',
#   'All Other Offenses (Except Traffic)',
#   'Arson',
#   'Burglary',
#   'Curfew and Loitering Law Violations',
#   'Disorderly Conduct',
#   'Driving Under the Influence',
#   'Drug Abuse Violations - Grand Total',
#   'Drunkenness',
#   'Embezzlement',
#   'Forgery and Counterfeiting',
#   'Fraud',
#   'Gambling - Total',
#   'Human Trafficking - Commercial Sex Acts',
#   'Human Trafficking - Involuntary Servitude',
#   'Larceny - Theft',
#   'Liquor Laws',
#   'Manslaughter by Negligence',
#   'Motor Vehicle Theft',
#   'Murder and Nonnegligent Manslaughter',
#   'Offenses Against the Family and Children',
#   'Prostitution and Commercialized Vice',
#   'Rape',
#   'Robbery',
#   'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)',
#   'Simple Assault',
#   'Stolen Property: Buying, Receiving, Possessing',
#   'Suspicion',
#   'Vagrancy',
#   'Vandalism',
#   'Weapons: Carrying, Possessing, Etc.'],
#  'data': [],
#  'precise_data': []}

# %%
agencies = requests.get('https://api.usa.gov/crime/fbi/sapi/api/nibrs/property-crime',auth=('key',apikey))
data = json.loads(agencies.content)
# pd.DataFrame(data)
data
# Out:
# {'error': {'code': 'API_KEY_INVALID',
#   'message': 'An invalid api_key was supplied. Get one at https://api.usa.gov:443'}}

# %% [markdown]
# # Supervised models

# %% [markdown]
# ## KNN classification

# %% [markdown]
# ### Model development

# %% [markdown]
# ### Visualization

# %% [markdown]
# ### Analysis

# %% [markdown]
# ## Logistic regression

# %% [markdown]
# ### Model development

# %% [markdown]
# ### Visualization

# %% [markdown]
# ### Analysis

# %% [markdown]
# ## Linear regression

# %% [markdown]
# ### Model development

# %% [markdown]
# ### Visualization

# %% [markdown]
# ### Analysis

# %% [markdown]
# ## OLS regression

# %% [markdown]
# ### Model development

# %%
### Example code ####

#`smf.ols(formula="y ~ treatment + x1 + x2 ...")#
#"fixed effect for var_x", you can add a `+C(var_x)`
covariates = ['Intercept','treat1','treat2','treat3','water_2006','apr_may_07']
modelA = smf.ols(formula='summer_07 ~ treat1 + treat2 + treat3 + water_2006 + apr_may_07', data=a2).fit()
modelB = smf.ols(formula='summer_07 ~ treat1 + treat2 + treat3 + water_2006 + apr_may_07 +C(route)', data=a2).fit()
# Q3_table = Stargazer([modelA,modelB])
# Q3_table.covariate_order(covariates)
# Q3_table

# %% [markdown]
# ### Visualization

# %% [markdown]
# ### Analysis

# %% [markdown]
# # Unsupervised models

# %% [markdown]
# ## PCA

# %% [markdown]
# ### Model development

# %% [markdown]
# ### Visualization

# %% [markdown]
# ### Analysis

# %% [markdown]
# ## DBSCAN

# %% [markdown]
# ### Model development

# %% [markdown]
# ### Visualization

# %% [markdown]
# ### Analysis
